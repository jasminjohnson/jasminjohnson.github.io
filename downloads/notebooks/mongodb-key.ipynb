# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # MongoDB Example - for Accountant reinsurance loss data analysis

# %% [markdown]
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# MongoDB is a document-oriented database. Instead of storing your data in tables made out of individual rows,
# like a relational database does, it stores your data in collections made out of individual documents.
# In MongoDB, a document is a big JSON blob with no particular format or schema.
#
# You can have all your data in one single table or collection.
#
# <!-- PELICAN_END_SUMMARY -->

# %% [markdown]
# ### MongoDB for Reinsurance Data Analysis
# - Create sample data in MongoDB
#   - reinsurance treaty by reinsurer/year/treaty type
# - Read webpage data into MongoDB and
#   - example : read twitter page about what type of insurance people are interesting buying
# - Retrieve from MongoDB to Excel for data analysis
# - Read investment gain and loss from broker website into MongoDB for analysis
# - how to use BSON-NumPy to pull data out of Mongo and into pandas

# %% [markdown]
# ### *Making a Connection with MongoClient*
# -  Below link is an introduction tutorial to working with MongoDB and PyMongo
# -  ref: http://api.mongodb.com/python/current/tutorial.html

# %%
# Making a Connection with MongoClient
# Import pymongo
import pymongo

# The first step when working with PyMongo is to create a MongoClient to the running mongod instance
from pymongo import MongoClient

# Connect on the default host and port.
client = MongoClient()

# We can also specify the host and port explicitly
client = MongoClient('localhost', 27017)

# %% [markdown]
# #### *Getting a Database*
# - A single instance of MongoDB can support multiple independent databases.
# - When working with PyMongo you access databases using attribute style access on MongoClient instances.
# - database name can not use attribute style access (like sample-data), but sample_data is okay

# %%
db = client.test_database

collection = db.test_collection

# cant use attribute style
# you can use dictionary style access instead
db = client['test-database']

collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test_database'), 'test_collection')

# %% [markdown]
# #### *Document*
# - Data in MongoDB is represented (and stored) using JSON-style documents.
# - In PyMongo we use dictionaries to represent documents.
# - As an example, the following dictionary might be used to represent a reinsurance treaty type by reinsurer and year:
# - Documents can contain native Python types (like datetime.datetime instances) which will be automatically converted to and from the appropriate BSON types.

# %%
import datetime
post = {"reinsurer": "AIG",
        "treaty": "XOL layer",
        "tags": ["mongodb", "python", "pymongo"],
        "date": datetime.datetime.utcnow()}

# %% [markdown]
# #### *Inserting a Document*
# - When a document is inserted a special key, "_id", is automatically added if the document doesn’t already contain an "_id" key.
# - The value of "_id" must be unique across the collection. insert_one() returns an instance of InsertOneResult.

# %%
# To insert a document into a collection we can use the insert_one() method:
posts = db.posts
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('5b758de4760df70ecc217d14')

# %% [markdown]
# #### * After inserting the first document, the posts collection has actually been created on the server.*
# - We can verify this by listing all of the collections in our database:

# %%
db.collection_names(include_system_collections=False)
# Out:
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ['posts', 'profiles']

# %%
post2 = {"reinsurer": "Swiss Re",
        "treaty": "Clash Layer",
        "tags": ["mongodb", "python", "pymongo"],
        "date": datetime.datetime.utcnow()}

post_id = posts.insert_one(post2).inserted_id
post_id
# Out:
# ObjectId('5b758e80760df70ecc217d15')

# %% [markdown]
# #### * Getting a Single Document With find_one()*
# - The most basic type of query that can be performed in MongoDB is find_one().
# - This method returns a single document matching a query (or None if there are no matches).
# - It is useful when you know there is only one matching document, or
# - are only interested in the first match. Here we use find_one() to get the first document from the posts collection:

# %%
import pprint
pprint.pprint(posts.find_one())
# Out:
# {'_id': ObjectId('5b733f8da68b144b14aa4fda'),
#  'date': datetime.datetime(2018, 8, 14, 20, 45, 55, 156000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}

# %%
pprint.pprint(posts.find_one({"reinsurer": "AIG"}))
# Out:
# {'_id': ObjectId('5b733f8da68b144b14aa4fda'),
#  'date': datetime.datetime(2018, 8, 14, 20, 45, 55, 156000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}

# %%
pprint.pprint(posts.find_one({"reinsurer": "ACE"}))
# Out:
# None

# %% [markdown]
# #### * Querying By ObjectId*
# - We can also find a post by its _id, which in our example is an ObjectId:

# %%
post_id  ##output is an object
# Out:
# ObjectId('5b747db8760df74924ecbe29')

# %%
pprint.pprint(posts.find_one({"_id": post_id}))
# Out:
# {'_id': ObjectId('5b747db8760df74924ecbe29'),
#  'date': datetime.datetime(2018, 8, 15, 19, 23, 36, 998000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}

# %% [markdown]
# #### * Note that an ObjectId is not the same as its string representation:*

# %%
post_id_as_str = str(post_id)
post_id_as_str  ## output is a string
# Out:
# '5b747db8760df74924ecbe29'

# %%
posts.find_one({"_id": post_id_as_str}) # No result

# %% [markdown]
# #### *Get URL data*
# - A common task in web applications is to get an ObjectId from the request URL and find the matching document.
# - It’s necessary in this case to convert the ObjectId from a string before passing it to find_one:

# %%
# follow up @8/14/18
from bson.objectid import ObjectId

# The web framework gets post_id from the URL and passes it as a string
def get(post_id):
    # Convert from string to ObjectId:
    document = client.db.collection.find_one({'_id': ObjectId(post_id)})

# %% [markdown]
# #### * A Note On Unicode Strings*
# - You probably noticed that the regular Python strings we stored earlier look different when retrieved from the server (e.g. u’AIG’ instead of ‘AIG’).
# - A short explanation is in order.
# - MongoDB stores data in BSON format. BSON strings are UTF-8 encoded so PyMongo must ensure that any strings it stores contain only valid UTF-8 data.
# - Regular strings (<type ‘str’>) are validated and stored unaltered. Unicode strings (<type ‘unicode’>) are encoded UTF-8 first.
# - The reason our example string is represented in the Python shell as u’AIG’ instead of ‘AIG’
# - is that PyMongo decodes each BSON string to a Python unicode string, not a regular str.

# %% [markdown]
# #### * Bulk Inserts*
# - we can also perform bulk insert operations, by passing a list as the first argument to insert_many().
# - This will insert each document in the list, sending only a single command to the server:
# - different shape, but can handle with new title,can add to the collection... because its not a table

# %%
# new_posts[1] has a different “shape” than the other posts 
# there is no "tags" field and we’ve added a new field, "retenion". 
# This is what we mean when we say that MongoDB is schema-free.

new_posts = [{"reinsurer": "AIG",
              "treaty": "XOL Layer 2018",
              "tags": ["bulk", "insert"],
              "date": datetime.datetime(2018, 11, 12, 11, 14)},
              {"reinsurer": "Munich Re",
               "treaty": "QS 2018",
               "retenion": "QS 20% for US business",
               "date": datetime.datetime(2018, 11, 10, 10, 45)}]

result = posts.insert_many(new_posts)
result.inserted_ids
# Out:
# [ObjectId('5b747dcf760df74924ecbe2a'), ObjectId('5b747dcf760df74924ecbe2b')]

# %% [markdown]
# #### * The result from insert_many() now returns two ObjectId instances, one for each inserted document.*
# - new_posts[1] has a different “shape” than the other posts - there is no "tags" field and we’ve added a new field, "title".
# - This is what we mean when we say that MongoDB is schema-free.

# %%
for post in posts.find():
     pprint.pprint(post)
# Out:
# {'_id': ObjectId('5b733f8da68b144b14aa4fda'),
#  'date': datetime.datetime(2018, 8, 14, 20, 45, 55, 156000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b733fb2a68b144b14aa4fdb'),
#  'date': datetime.datetime(2018, 8, 14, 20, 46, 42, 222000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b7340e5a68b144b14aa4fdc'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b7340e5a68b144b14aa4fdd'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b74590c760df751508616c1'),
#  'date': datetime.datetime(2018, 8, 15, 16, 47, 4, 939000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b74594e760df751508616c2'),
#  'date': datetime.datetime(2018, 8, 15, 16, 48, 14, 644000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b745967760df751508616c3'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b745967760df751508616c4'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b747db3760df74924ecbe28'),
#  'date': datetime.datetime(2018, 8, 15, 19, 23, 28, 222000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b747db8760df74924ecbe29'),
#  'date': datetime.datetime(2018, 8, 15, 19, 23, 36, 998000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b747dcf760df74924ecbe2a'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b747dcf760df74924ecbe2b'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}

# %%
#### **Below is the screenshot of the MongoDB structures showing list of dataset**
<img src="/images/MongoDB1.png" alt="[img: MongoDB view]" title="MongoDB View" />
# Out:
#   File "<ipython-input-20-ea8111e655ce>", line 3
#     <img src="/images/SQLflowchart.png" alt="[img: SQL flowchart]" title="SQLite flowchart" />
#     ^
# SyntaxError: invalid syntax

# %%
# different than find_one
for post in posts.find({"reinsurer": "AIG"}):
    pprint.pprint(post)
# Out:
# {'_id': ObjectId('5b733f8da68b144b14aa4fda'),
#  'date': datetime.datetime(2018, 8, 14, 20, 45, 55, 156000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7340e5a68b144b14aa4fdc'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b74590c760df751508616c1'),
#  'date': datetime.datetime(2018, 8, 15, 16, 47, 4, 939000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b745967760df751508616c3'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b747db3760df74924ecbe28'),
#  'date': datetime.datetime(2018, 8, 15, 19, 23, 28, 222000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b747dcf760df74924ecbe2a'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}

# %%
pprint.pprint(posts.find_one({"reinsurer": "AIG"}))
# Out:
# {'_id': ObjectId('5b733f8da68b144b14aa4fda'),
#  'date': datetime.datetime(2018, 8, 14, 20, 45, 55, 156000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}

# %% [markdown]
# #### * Counting*
# - If we just want to know how many documents match a query we can perform a count() operation instead of a full query.
# - We can get a count of all of the documents in a collection:

# %%
posts.count()
# Out:
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 12

# %%
posts.find({"reinsurer": "AIG"}).count()
# Out:
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 6

# %% [markdown]
# #### * Range Queries*
# - MongoDB supports many different types of advanced queries.
# - As an example, lets perform a query where we limit results to posts older than a certain date,
# - but also sort the results by author:

# %%
d = datetime.datetime(2018, 11, 12, 12)
for post in posts.find({"date": {"$lt": d}}).sort("reinsurer"):
    pprint.pprint(post)
# Out:
# {'_id': ObjectId('5b733f8da68b144b14aa4fda'),
#  'date': datetime.datetime(2018, 8, 14, 20, 45, 55, 156000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7340e5a68b144b14aa4fdc'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b74590c760df751508616c1'),
#  'date': datetime.datetime(2018, 8, 15, 16, 47, 4, 939000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b745967760df751508616c3'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b747db3760df74924ecbe28'),
#  'date': datetime.datetime(2018, 8, 15, 19, 23, 28, 222000),
#  'reinsurer': 'AIG',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b747dcf760df74924ecbe2a'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b7340e5a68b144b14aa4fdd'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b745967760df751508616c4'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b747dcf760df74924ecbe2b'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b733fb2a68b144b14aa4fdb'),
#  'date': datetime.datetime(2018, 8, 14, 20, 46, 42, 222000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b74594e760df751508616c2'),
#  'date': datetime.datetime(2018, 8, 15, 16, 48, 14, 644000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b747db8760df74924ecbe29'),
#  'date': datetime.datetime(2018, 8, 15, 19, 23, 36, 998000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'treaty': 'Clash Layer'}

# %% [markdown]
# #### * Indexing*
# - Adding indexes can help accelerate certain queries and can also add additional functionality to querying and storing documents.
# - In this example, we’ll demonstrate how to create a unique index on a key that rejects documents whose value for that key already exists in the index.
# - First, we’ll need to create the index:

# %%
 result = db.profiles.create_index([('user_id', pymongo.ASCENDING)],
                                  unique=True)
 sorted(list(db.profiles.index_information()))
# Out:
# ['_id_', 'user_id_1']

# %% [markdown]
# #### *Notice that we have two indexes now*
# - one is the index on _id that MongoDB creates automatically,
# - and the other is the index on user_id we just created.

# %%
 # set up some user profiles:

user_profiles = [
    {'user_id': 218, 'reinsurer': 'Partner Re'},
    {'user_id': 219, 'reinsurer': 'General Re'}]
result = db.profiles.insert_many(user_profiles)

# %%
 # DuplicateKeyError: E11000 duplicate key error collection: test_database.profiles index: user_id_1 dup key: { : 212 }
 new_profile = {'user_id': 213, 'reinsurer': 'XL American'}
 duplicate_profile = {'user_id': 212, 'reinsurer': 'SCOR S.E'}
 result = db.profiles.insert_one(new_profile)  # This is fine.
 result = db.profiles.insert_one(duplicate_profile)

# %% [markdown]
# #### * Convert Excel to MongoDB*
# - https://stackoverflow.com/questions/21901209/convert-excel-to-mongodb
# - I want to move data from Excel files into MongoDB.
# - The Excel data is updated daily so I want to add the new data on daily reads.
# - I'm using Python and so far have only been trying to make a Python dictionary object to represent the Excel data
# - just to understand how MongoDB is storing its data but feel that I misunderstand some vital points.

# %% [markdown]
# #### *Collection data from twitter into MongoDB*
# - ref:  http://pythondata.com/collecting-storing-tweets-with-python-and-mongodb/

# %%
# from __future__ import print_function
# import tweepy
# import json
# from pymongo import MongoClient
 
# MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
#                                              # and a database called 'twitterdb'
 
# WORDS = ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
 
# CONSUMER_KEY = "8hXSibjBqguYXf4vVNDliDCOY"
# CONSUMER_SECRET = "fUwZ4PJbK8wwaTpF5uEz6xniac9P5ACzXIMsk7pCSAiUHjViJA"
# ACCESS_TOKEN = "2994396687-mpkDqjV6xQzfhtqvDncWy2JjAiORScTtbOOwRqD"
# ACCESS_TOKEN_SECRET = "bfqOVgKhkW9r9fiRFNIGNp70Wottrc3E5zoBNCi7xthtQ"
 
 
# class StreamListener(tweepy.StreamListener):    
#     #This is a class provided by tweepy to access the Twitter Streaming API. 
 
#     def on_connect(self):
#         # Called initially to connect to the Streaming API
#         print("You are now connected to the streaming API.")
 
#     def on_error(self, status_code):
#         # On error - if an error occurs, display the error / status code
#         print('An Error has occured: ' + repr(status_code))
#         return False
 
#     def on_data(self, data):
#         #This is the meat of the script...it connects to your mongoDB and stores the tweet
#         try:
#             client = MongoClient(MONGO_HOST)
            
#             # Use twitterdb database. If it doesn't exist, it will be created.
#             db = client.twitterdb
    
#             # Decode the JSON from Twitter
#             datajson = json.loads(data)
            
#             #grab the 'created_at' data from the Tweet to use for display
#             created_at = datajson['created_at']
 
#             #print out a message to the screen that we have collected a tweet
#             print("Tweet collected at " + str(created_at))
            
#             #insert the data into the mongoDB into a collection called twitter_search
#             #if twitter_search doesn't exist, it will be created.
#             db.twitter_search.insert(datajson)
#         except Exception as e:
#            print(e)
 
# auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
# auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
# #Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
# listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
# streamer = tweepy.Stream(auth=auth, listener=listener)
# print("Tracking: " + str(WORDS))
# streamer.filter(track=WORDS)
# Out:
# Tracking: ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
# You are now connected to the streaming API.
# Tweet collected at Wed Aug 15 19:29:12 +0000 2018
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:48: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Tweet collected at Wed Aug 15 19:29:13 +0000 2018
# Tweet collected at Wed Aug 15 19:29:13 +0000 2018
# Tweet collected at Wed Aug 15 19:29:16 +0000 2018
# Tweet collected at Wed Aug 15 19:29:16 +0000 2018
# Tweet collected at Wed Aug 15 19:29:17 +0000 2018
# Tweet collected at Wed Aug 15 19:29:19 +0000 2018
# Tweet collected at Wed Aug 15 19:29:21 +0000 2018
# Tweet collected at Wed Aug 15 19:29:22 +0000 2018
# Tweet collected at Wed Aug 15 19:29:25 +0000 2018
# Tweet collected at Wed Aug 15 19:29:26 +0000 2018
# Tweet collected at Wed Aug 15 19:29:28 +0000 2018
# Tweet collected at Wed Aug 15 19:29:34 +0000 2018
# Tweet collected at Wed Aug 15 19:29:38 +0000 2018
# Tweet collected at Wed Aug 15 19:29:39 +0000 2018
# Tweet collected at Wed Aug 15 19:29:41 +0000 2018
# Tweet collected at Wed Aug 15 19:29:44 +0000 2018
# Tweet collected at Wed Aug 15 19:29:49 +0000 2018
# Tweet collected at Wed Aug 15 19:29:49 +0000 2018
# Tweet collected at Wed Aug 15 19:29:53 +0000 2018
# Tweet collected at Wed Aug 15 19:29:55 +0000 2018
# Tweet collected at Wed Aug 15 19:29:56 +0000 2018
# Tweet collected at Wed Aug 15 19:30:00 +0000 2018
# Tweet collected at Wed Aug 15 19:30:00 +0000 2018
# Tweet collected at Wed Aug 15 19:30:00 +0000 2018
# Tweet collected at Wed Aug 15 19:30:00 +0000 2018
# Tweet collected at Wed Aug 15 19:30:01 +0000 2018
# Tweet collected at Wed Aug 15 19:30:04 +0000 2018
# Tweet collected at Wed Aug 15 19:30:04 +0000 2018
# Tweet collected at Wed Aug 15 19:30:05 +0000 2018
# Tweet collected at Wed Aug 15 19:30:05 +0000 2018
# Tweet collected at Wed Aug 15 19:30:06 +0000 2018
# Tweet collected at Wed Aug 15 19:30:06 +0000 2018
# Tweet collected at Wed Aug 15 19:30:07 +0000 2018
# Tweet collected at Wed Aug 15 19:30:07 +0000 2018
# Tweet collected at Wed Aug 15 19:30:08 +0000 2018
# Tweet collected at Wed Aug 15 19:30:09 +0000 2018
# Tweet collected at Wed Aug 15 19:30:09 +0000 2018
# Tweet collected at Wed Aug 15 19:30:09 +0000 2018
# Tweet collected at Wed Aug 15 19:30:11 +0000 2018
# Tweet collected at Wed Aug 15 19:30:12 +0000 2018
# Tweet collected at Wed Aug 15 19:30:13 +0000 2018
# Tweet collected at Wed Aug 15 19:30:13 +0000 2018
# Tweet collected at Wed Aug 15 19:30:13 +0000 2018
# Tweet collected at Wed Aug 15 19:30:14 +0000 2018
# Tweet collected at Wed Aug 15 19:30:15 +0000 2018
# Tweet collected at Wed Aug 15 19:30:15 +0000 2018
# Tweet collected at Wed Aug 15 19:30:15 +0000 2018
# Tweet collected at Wed Aug 15 19:30:16 +0000 2018
# Tweet collected at Wed Aug 15 19:30:17 +0000 2018
# Tweet collected at Wed Aug 15 19:30:17 +0000 2018
# Tweet collected at Wed Aug 15 19:30:17 +0000 2018
# Tweet collected at Wed Aug 15 19:30:18 +0000 2018
# Tweet collected at Wed Aug 15 19:30:19 +0000 2018
# Tweet collected at Wed Aug 15 19:30:19 +0000 2018
# Tweet collected at Wed Aug 15 19:30:19 +0000 2018
# Tweet collected at Wed Aug 15 19:30:19 +0000 2018
# Tweet collected at Wed Aug 15 19:30:19 +0000 2018
# Tweet collected at Wed Aug 15 19:30:20 +0000 2018
# Tweet collected at Wed Aug 15 19:30:20 +0000 2018
# Tweet collected at Wed Aug 15 19:30:21 +0000 2018
# Tweet collected at Wed Aug 15 19:30:22 +0000 2018
# Tweet collected at Wed Aug 15 19:30:23 +0000 2018
# Tweet collected at Wed Aug 15 19:30:24 +0000 2018
# Tweet collected at Wed Aug 15 19:30:25 +0000 2018
# Tweet collected at Wed Aug 15 19:30:25 +0000 2018
# Tweet collected at Wed Aug 15 19:30:26 +0000 2018
# Tweet collected at Wed Aug 15 19:30:27 +0000 2018
# Tweet collected at Wed Aug 15 19:30:29 +0000 2018
# Tweet collected at Wed Aug 15 19:30:29 +0000 2018
# Tweet collected at Wed Aug 15 19:30:30 +0000 2018
# Tweet collected at Wed Aug 15 19:30:32 +0000 2018
# Tweet collected at Wed Aug 15 19:30:33 +0000 2018
# Tweet collected at Wed Aug 15 19:30:33 +0000 2018
# Tweet collected at Wed Aug 15 19:30:34 +0000 2018
# Tweet collected at Wed Aug 15 19:30:35 +0000 2018
# Tweet collected at Wed Aug 15 19:30:35 +0000 2018
# Tweet collected at Wed Aug 15 19:30:38 +0000 2018
# Tweet collected at Wed Aug 15 19:30:38 +0000 2018
# Tweet collected at Wed Aug 15 19:30:40 +0000 2018
# Tweet collected at Wed Aug 15 19:30:41 +0000 2018
# Tweet collected at Wed Aug 15 19:30:43 +0000 2018
# Tweet collected at Wed Aug 15 19:30:44 +0000 2018
# Tweet collected at Wed Aug 15 19:30:44 +0000 2018
# Tweet collected at Wed Aug 15 19:30:46 +0000 2018
# Tweet collected at Wed Aug 15 19:30:48 +0000 2018
# Tweet collected at Wed Aug 15 19:30:48 +0000 2018
# Tweet collected at Wed Aug 15 19:30:49 +0000 2018
# Tweet collected at Wed Aug 15 19:30:51 +0000 2018
# Tweet collected at Wed Aug 15 19:30:51 +0000 2018
# Tweet collected at Wed Aug 15 19:30:52 +0000 2018
# Tweet collected at Wed Aug 15 19:30:52 +0000 2018
# Tweet collected at Wed Aug 15 19:30:53 +0000 2018
# Tweet collected at Wed Aug 15 19:30:56 +0000 2018
# Tweet collected at Wed Aug 15 19:30:59 +0000 2018
# Tweet collected at Wed Aug 15 19:31:00 +0000 2018
# Tweet collected at Wed Aug 15 19:31:01 +0000 2018
# Tweet collected at Wed Aug 15 19:31:01 +0000 2018
# Tweet collected at Wed Aug 15 19:31:02 +0000 2018
# Tweet collected at Wed Aug 15 19:31:03 +0000 2018
# Tweet collected at Wed Aug 15 19:31:04 +0000 2018
# Tweet collected at Wed Aug 15 19:31:05 +0000 2018
# Tweet collected at Wed Aug 15 19:31:08 +0000 2018
# Tweet collected at Wed Aug 15 19:31:08 +0000 2018
# Tweet collected at Wed Aug 15 19:31:09 +0000 2018
# Tweet collected at Wed Aug 15 19:31:12 +0000 2018
# Tweet collected at Wed Aug 15 19:31:12 +0000 2018
# Tweet collected at Wed Aug 15 19:31:13 +0000 2018
# Tweet collected at Wed Aug 15 19:31:13 +0000 2018
# Tweet collected at Wed Aug 15 19:31:14 +0000 2018
# Tweet collected at Wed Aug 15 19:31:17 +0000 2018
# Tweet collected at Wed Aug 15 19:31:17 +0000 2018
# Tweet collected at Wed Aug 15 19:31:19 +0000 2018
# Tweet collected at Wed Aug 15 19:31:20 +0000 2018
# Tweet collected at Wed Aug 15 19:31:20 +0000 2018
# Tweet collected at Wed Aug 15 19:31:21 +0000 2018
# Tweet collected at Wed Aug 15 19:31:24 +0000 2018
# Tweet collected at Wed Aug 15 19:31:24 +0000 2018
# Tweet collected at Wed Aug 15 19:31:25 +0000 2018
# Tweet collected at Wed Aug 15 19:31:25 +0000 2018
# Tweet collected at Wed Aug 15 19:31:27 +0000 2018
# Tweet collected at Wed Aug 15 19:31:28 +0000 2018
# Tweet collected at Wed Aug 15 19:31:29 +0000 2018
# Tweet collected at Wed Aug 15 19:31:29 +0000 2018
# Tweet collected at Wed Aug 15 19:31:30 +0000 2018
# Tweet collected at Wed Aug 15 19:31:32 +0000 2018
# Tweet collected at Wed Aug 15 19:31:33 +0000 2018
# Tweet collected at Wed Aug 15 19:31:34 +0000 2018
# Tweet collected at Wed Aug 15 19:31:34 +0000 2018
# Tweet collected at Wed Aug 15 19:31:34 +0000 2018
# Tweet collected at Wed Aug 15 19:31:35 +0000 2018
# Tweet collected at Wed Aug 15 19:31:35 +0000 2018
# Tweet collected at Wed Aug 15 19:31:36 +0000 2018
# Tweet collected at Wed Aug 15 19:31:37 +0000 2018
# Tweet collected at Wed Aug 15 19:31:37 +0000 2018
# Tweet collected at Wed Aug 15 19:31:39 +0000 2018
# Tweet collected at Wed Aug 15 19:31:41 +0000 2018
# Tweet collected at Wed Aug 15 19:31:44 +0000 2018
# Tweet collected at Wed Aug 15 19:31:45 +0000 2018
# Tweet collected at Wed Aug 15 19:31:45 +0000 2018
# Tweet collected at Wed Aug 15 19:31:47 +0000 2018
# Tweet collected at Wed Aug 15 19:31:48 +0000 2018
# Tweet collected at Wed Aug 15 19:31:50 +0000 2018
# Tweet collected at Wed Aug 15 19:31:57 +0000 2018
# Tweet collected at Wed Aug 15 19:31:59 +0000 2018
# Tweet collected at Wed Aug 15 19:32:00 +0000 2018
# Tweet collected at Wed Aug 15 19:32:01 +0000 2018
# Tweet collected at Wed Aug 15 19:32:04 +0000 2018
# Tweet collected at Wed Aug 15 19:32:05 +0000 2018
# Tweet collected at Wed Aug 15 19:32:04 +0000 2018
# Tweet collected at Wed Aug 15 19:32:05 +0000 2018
# Tweet collected at Wed Aug 15 19:32:05 +0000 2018
# Tweet collected at Wed Aug 15 19:32:11 +0000 2018
# Tweet collected at Wed Aug 15 19:32:14 +0000 2018
# Tweet collected at Wed Aug 15 19:32:14 +0000 2018
# Tweet collected at Wed Aug 15 19:32:21 +0000 2018
# Tweet collected at Wed Aug 15 19:32:23 +0000 2018
# Tweet collected at Wed Aug 15 19:32:23 +0000 2018
# Tweet collected at Wed Aug 15 19:32:25 +0000 2018
# Tweet collected at Wed Aug 15 19:32:28 +0000 2018
# Tweet collected at Wed Aug 15 19:32:31 +0000 2018
# Tweet collected at Wed Aug 15 19:32:32 +0000 2018
# Tweet collected at Wed Aug 15 19:32:35 +0000 2018
# Tweet collected at Wed Aug 15 19:32:37 +0000 2018
# Tweet collected at Wed Aug 15 19:32:38 +0000 2018
# Tweet collected at Wed Aug 15 19:32:41 +0000 2018
# Tweet collected at Wed Aug 15 19:32:41 +0000 2018
# Tweet collected at Wed Aug 15 19:32:42 +0000 2018
# Tweet collected at Wed Aug 15 19:32:44 +0000 2018
# Tweet collected at Wed Aug 15 19:32:49 +0000 2018
# Tweet collected at Wed Aug 15 19:32:54 +0000 2018
# Tweet collected at Wed Aug 15 19:32:56 +0000 2018
# Tweet collected at Wed Aug 15 19:32:56 +0000 2018
# Tweet collected at Wed Aug 15 19:32:58 +0000 2018
# Tweet collected at Wed Aug 15 19:33:00 +0000 2018
# Tweet collected at Wed Aug 15 19:33:00 +0000 2018
# Tweet collected at Wed Aug 15 19:33:00 +0000 2018
# Tweet collected at Wed Aug 15 19:33:00 +0000 2018
# Tweet collected at Wed Aug 15 19:33:00 +0000 2018
# Tweet collected at Wed Aug 15 19:33:01 +0000 2018
# Tweet collected at Wed Aug 15 19:33:01 +0000 2018
# Tweet collected at Wed Aug 15 19:33:02 +0000 2018
# Tweet collected at Wed Aug 15 19:33:06 +0000 2018
# Tweet collected at Wed Aug 15 19:33:07 +0000 2018
# Tweet collected at Wed Aug 15 19:33:08 +0000 2018
# Tweet collected at Wed Aug 15 19:33:10 +0000 2018
# Tweet collected at Wed Aug 15 19:33:13 +0000 2018
# Tweet collected at Wed Aug 15 19:33:13 +0000 2018
# Tweet collected at Wed Aug 15 19:33:15 +0000 2018
# Tweet collected at Wed Aug 15 19:33:16 +0000 2018
# Tweet collected at Wed Aug 15 19:33:19 +0000 2018
# Tweet collected at Wed Aug 15 19:33:19 +0000 2018
# Tweet collected at Wed Aug 15 19:33:25 +0000 2018
# Tweet collected at Wed Aug 15 19:33:26 +0000 2018
# Tweet collected at Wed Aug 15 19:33:28 +0000 2018
# Tweet collected at Wed Aug 15 19:33:31 +0000 2018
# Tweet collected at Wed Aug 15 19:33:32 +0000 2018
# Tweet collected at Wed Aug 15 19:33:34 +0000 2018
# Tweet collected at Wed Aug 15 19:33:36 +0000 2018
# Tweet collected at Wed Aug 15 19:33:37 +0000 2018
# Tweet collected at Wed Aug 15 19:33:38 +0000 2018
# Tweet collected at Wed Aug 15 19:33:39 +0000 2018
# Tweet collected at Wed Aug 15 19:33:43 +0000 2018
# Tweet collected at Wed Aug 15 19:33:46 +0000 2018
# Tweet collected at Wed Aug 15 19:33:45 +0000 2018
# Tweet collected at Wed Aug 15 19:33:48 +0000 2018
# Tweet collected at Wed Aug 15 19:33:56 +0000 2018
# Tweet collected at Wed Aug 15 19:33:58 +0000 2018
# Tweet collected at Wed Aug 15 19:33:59 +0000 2018
# Tweet collected at Wed Aug 15 19:33:59 +0000 2018
# Tweet collected at Wed Aug 15 19:34:01 +0000 2018
# Tweet collected at Wed Aug 15 19:34:03 +0000 2018
# Tweet collected at Wed Aug 15 19:34:05 +0000 2018
# Tweet collected at Wed Aug 15 19:34:06 +0000 2018
# Tweet collected at Wed Aug 15 19:34:09 +0000 2018
# Tweet collected at Wed Aug 15 19:34:11 +0000 2018
# Tweet collected at Wed Aug 15 19:34:13 +0000 2018
# Tweet collected at Wed Aug 15 19:34:14 +0000 2018
# Tweet collected at Wed Aug 15 19:34:14 +0000 2018
# Tweet collected at Wed Aug 15 19:34:15 +0000 2018
# Tweet collected at Wed Aug 15 19:34:17 +0000 2018
# Tweet collected at Wed Aug 15 19:34:18 +0000 2018
# Tweet collected at Wed Aug 15 19:34:18 +0000 2018
# Tweet collected at Wed Aug 15 19:34:20 +0000 2018
# Tweet collected at Wed Aug 15 19:34:21 +0000 2018
# Tweet collected at Wed Aug 15 19:34:24 +0000 2018
# Tweet collected at Wed Aug 15 19:34:25 +0000 2018
# Tweet collected at Wed Aug 15 19:34:25 +0000 2018
# Tweet collected at Wed Aug 15 19:34:27 +0000 2018
# Tweet collected at Wed Aug 15 19:34:33 +0000 2018
# Tweet collected at Wed Aug 15 19:34:33 +0000 2018
# Tweet collected at Wed Aug 15 19:34:34 +0000 2018
# Tweet collected at Wed Aug 15 19:34:34 +0000 2018
# Tweet collected at Wed Aug 15 19:34:37 +0000 2018
# Tweet collected at Wed Aug 15 19:34:37 +0000 2018
# Tweet collected at Wed Aug 15 19:34:38 +0000 2018
# Tweet collected at Wed Aug 15 19:34:38 +0000 2018
# Tweet collected at Wed Aug 15 19:34:39 +0000 2018
# Tweet collected at Wed Aug 15 19:34:46 +0000 2018
# Tweet collected at Wed Aug 15 19:34:47 +0000 2018
# Tweet collected at Wed Aug 15 19:34:47 +0000 2018
# Tweet collected at Wed Aug 15 19:34:48 +0000 2018
# Tweet collected at Wed Aug 15 19:34:49 +0000 2018
# Tweet collected at Wed Aug 15 19:34:50 +0000 2018
# Tweet collected at Wed Aug 15 19:34:51 +0000 2018
# Tweet collected at Wed Aug 15 19:34:51 +0000 2018
# Tweet collected at Wed Aug 15 19:34:54 +0000 2018
# Tweet collected at Wed Aug 15 19:34:55 +0000 2018
# Tweet collected at Wed Aug 15 19:34:56 +0000 2018
# Tweet collected at Wed Aug 15 19:34:58 +0000 2018
# Tweet collected at Wed Aug 15 19:34:59 +0000 2018
# Tweet collected at Wed Aug 15 19:34:59 +0000 2018
# Tweet collected at Wed Aug 15 19:34:59 +0000 2018
# Tweet collected at Wed Aug 15 19:34:59 +0000 2018
# Tweet collected at Wed Aug 15 19:35:00 +0000 2018
# Tweet collected at Wed Aug 15 19:35:02 +0000 2018
# Tweet collected at Wed Aug 15 19:35:04 +0000 2018
# Tweet collected at Wed Aug 15 19:35:07 +0000 2018
# Tweet collected at Wed Aug 15 19:35:08 +0000 2018
# Tweet collected at Wed Aug 15 19:35:08 +0000 2018
# Tweet collected at Wed Aug 15 19:35:08 +0000 2018
# Tweet collected at Wed Aug 15 19:35:09 +0000 2018
# Tweet collected at Wed Aug 15 19:35:09 +0000 2018
# Tweet collected at Wed Aug 15 19:35:12 +0000 2018
# Tweet collected at Wed Aug 15 19:35:12 +0000 2018
# Tweet collected at Wed Aug 15 19:35:14 +0000 2018
# Tweet collected at Wed Aug 15 19:35:16 +0000 2018
# Tweet collected at Wed Aug 15 19:35:16 +0000 2018
# Tweet collected at Wed Aug 15 19:35:17 +0000 2018
# Tweet collected at Wed Aug 15 19:35:17 +0000 2018
# Tweet collected at Wed Aug 15 19:35:18 +0000 2018
# Tweet collected at Wed Aug 15 19:35:19 +0000 2018
# Tweet collected at Wed Aug 15 19:35:19 +0000 2018
# Tweet collected at Wed Aug 15 19:35:20 +0000 2018
# Tweet collected at Wed Aug 15 19:35:20 +0000 2018
# Tweet collected at Wed Aug 15 19:35:22 +0000 2018
# Tweet collected at Wed Aug 15 19:35:23 +0000 2018
# Tweet collected at Wed Aug 15 19:35:28 +0000 2018
# Tweet collected at Wed Aug 15 19:35:29 +0000 2018
# Tweet collected at Wed Aug 15 19:35:30 +0000 2018
# Tweet collected at Wed Aug 15 19:35:30 +0000 2018
# Tweet collected at Wed Aug 15 19:35:35 +0000 2018
# Tweet collected at Wed Aug 15 19:35:35 +0000 2018
# Tweet collected at Wed Aug 15 19:35:36 +0000 2018
# Tweet collected at Wed Aug 15 19:35:36 +0000 2018
# Tweet collected at Wed Aug 15 19:35:37 +0000 2018
# Tweet collected at Wed Aug 15 19:35:37 +0000 2018
# Tweet collected at Wed Aug 15 19:35:37 +0000 2018
# Tweet collected at Wed Aug 15 19:35:38 +0000 2018
# Tweet collected at Wed Aug 15 19:35:39 +0000 2018
# Tweet collected at Wed Aug 15 19:35:41 +0000 2018
# Tweet collected at Wed Aug 15 19:35:44 +0000 2018
# Tweet collected at Wed Aug 15 19:35:44 +0000 2018
# Tweet collected at Wed Aug 15 19:35:46 +0000 2018
# Tweet collected at Wed Aug 15 19:35:49 +0000 2018
# Tweet collected at Wed Aug 15 19:35:49 +0000 2018
# Tweet collected at Wed Aug 15 19:35:50 +0000 2018
# Tweet collected at Wed Aug 15 19:35:50 +0000 2018
# Tweet collected at Wed Aug 15 19:35:50 +0000 2018
# Tweet collected at Wed Aug 15 19:35:51 +0000 2018
# Tweet collected at Wed Aug 15 19:35:54 +0000 2018
# Tweet collected at Wed Aug 15 19:35:55 +0000 2018
# Tweet collected at Wed Aug 15 19:35:57 +0000 2018
# Tweet collected at Wed Aug 15 19:35:58 +0000 2018
# Tweet collected at Wed Aug 15 19:36:01 +0000 2018
# Tweet collected at Wed Aug 15 19:36:01 +0000 2018
# Tweet collected at Wed Aug 15 19:36:02 +0000 2018
# Tweet collected at Wed Aug 15 19:36:02 +0000 2018
# Tweet collected at Wed Aug 15 19:36:03 +0000 2018
# Tweet collected at Wed Aug 15 19:36:07 +0000 2018
# Tweet collected at Wed Aug 15 19:36:10 +0000 2018
# Tweet collected at Wed Aug 15 19:36:11 +0000 2018
# Tweet collected at Wed Aug 15 19:36:11 +0000 2018
# Tweet collected at Wed Aug 15 19:36:19 +0000 2018
# Tweet collected at Wed Aug 15 19:36:21 +0000 2018
# Tweet collected at Wed Aug 15 19:36:26 +0000 2018
# Tweet collected at Wed Aug 15 19:36:27 +0000 2018
# Tweet collected at Wed Aug 15 19:36:28 +0000 2018
# Tweet collected at Wed Aug 15 19:36:29 +0000 2018
# Tweet collected at Wed Aug 15 19:36:32 +0000 2018
# Tweet collected at Wed Aug 15 19:36:35 +0000 2018
# Tweet collected at Wed Aug 15 19:36:36 +0000 2018
# Tweet collected at Wed Aug 15 19:36:36 +0000 2018
# Tweet collected at Wed Aug 15 19:36:37 +0000 2018
# Tweet collected at Wed Aug 15 19:36:37 +0000 2018
# Tweet collected at Wed Aug 15 19:36:39 +0000 2018
# Tweet collected at Wed Aug 15 19:36:40 +0000 2018
# Tweet collected at Wed Aug 15 19:36:39 +0000 2018
# Tweet collected at Wed Aug 15 19:36:41 +0000 2018
# Tweet collected at Wed Aug 15 19:36:44 +0000 2018
# Tweet collected at Wed Aug 15 19:36:44 +0000 2018
# Tweet collected at Wed Aug 15 19:36:49 +0000 2018
# Tweet collected at Wed Aug 15 19:36:51 +0000 2018
# Tweet collected at Wed Aug 15 19:36:52 +0000 2018
# Tweet collected at Wed Aug 15 19:36:53 +0000 2018
# Tweet collected at Wed Aug 15 19:36:54 +0000 2018
# Tweet collected at Wed Aug 15 19:37:00 +0000 2018
# Tweet collected at Wed Aug 15 19:37:00 +0000 2018
# Tweet collected at Wed Aug 15 19:37:01 +0000 2018
# Tweet collected at Wed Aug 15 19:37:01 +0000 2018
# Tweet collected at Wed Aug 15 19:37:05 +0000 2018
# Tweet collected at Wed Aug 15 19:37:04 +0000 2018
# Tweet collected at Wed Aug 15 19:37:06 +0000 2018
# Tweet collected at Wed Aug 15 19:37:06 +0000 2018
# Tweet collected at Wed Aug 15 19:37:07 +0000 2018
# Tweet collected at Wed Aug 15 19:37:09 +0000 2018
# Tweet collected at Wed Aug 15 19:37:10 +0000 2018
# Tweet collected at Wed Aug 15 19:37:10 +0000 2018
# Tweet collected at Wed Aug 15 19:37:11 +0000 2018
# Tweet collected at Wed Aug 15 19:37:12 +0000 2018
# Tweet collected at Wed Aug 15 19:37:19 +0000 2018
# Tweet collected at Wed Aug 15 19:37:21 +0000 2018
# Tweet collected at Wed Aug 15 19:37:22 +0000 2018
# Tweet collected at Wed Aug 15 19:37:23 +0000 2018
# Tweet collected at Wed Aug 15 19:37:26 +0000 2018
# Tweet collected at Wed Aug 15 19:37:26 +0000 2018
# Tweet collected at Wed Aug 15 19:37:26 +0000 2018
# Tweet collected at Wed Aug 15 19:37:27 +0000 2018
# Tweet collected at Wed Aug 15 19:37:28 +0000 2018
# Tweet collected at Wed Aug 15 19:37:29 +0000 2018
# Tweet collected at Wed Aug 15 19:37:30 +0000 2018
# Tweet collected at Wed Aug 15 19:37:31 +0000 2018
# Tweet collected at Wed Aug 15 19:37:32 +0000 2018
# Tweet collected at Wed Aug 15 19:37:35 +0000 2018
# Tweet collected at Wed Aug 15 19:37:36 +0000 2018
# Tweet collected at Wed Aug 15 19:37:40 +0000 2018
# Tweet collected at Wed Aug 15 19:37:44 +0000 2018
# Tweet collected at Wed Aug 15 19:37:45 +0000 2018
# Tweet collected at Wed Aug 15 19:37:48 +0000 2018
# Tweet collected at Wed Aug 15 19:37:48 +0000 2018
# Tweet collected at Wed Aug 15 19:37:50 +0000 2018
# Tweet collected at Wed Aug 15 19:37:58 +0000 2018
# Tweet collected at Wed Aug 15 19:37:59 +0000 2018
# Tweet collected at Wed Aug 15 19:38:00 +0000 2018
# Tweet collected at Wed Aug 15 19:38:01 +0000 2018
# Tweet collected at Wed Aug 15 19:38:02 +0000 2018
# Tweet collected at Wed Aug 15 19:38:03 +0000 2018
# Tweet collected at Wed Aug 15 19:38:03 +0000 2018
# Tweet collected at Wed Aug 15 19:38:03 +0000 2018
# Tweet collected at Wed Aug 15 19:38:04 +0000 2018
# Tweet collected at Wed Aug 15 19:38:08 +0000 2018
# Tweet collected at Wed Aug 15 19:38:10 +0000 2018
# Tweet collected at Wed Aug 15 19:38:11 +0000 2018
# Tweet collected at Wed Aug 15 19:38:11 +0000 2018
# Tweet collected at Wed Aug 15 19:38:13 +0000 2018
# Tweet collected at Wed Aug 15 19:38:17 +0000 2018
# Tweet collected at Wed Aug 15 19:38:17 +0000 2018
# Tweet collected at Wed Aug 15 19:38:18 +0000 2018
# Tweet collected at Wed Aug 15 19:38:18 +0000 2018
# Tweet collected at Wed Aug 15 19:38:21 +0000 2018
# Tweet collected at Wed Aug 15 19:38:22 +0000 2018
# Tweet collected at Wed Aug 15 19:38:24 +0000 2018
# Tweet collected at Wed Aug 15 19:38:28 +0000 2018
# Tweet collected at Wed Aug 15 19:38:30 +0000 2018
# Tweet collected at Wed Aug 15 19:38:31 +0000 2018
# Tweet collected at Wed Aug 15 19:38:31 +0000 2018
# Tweet collected at Wed Aug 15 19:38:32 +0000 2018
# Tweet collected at Wed Aug 15 19:38:33 +0000 2018
# Tweet collected at Wed Aug 15 19:38:36 +0000 2018
# Tweet collected at Wed Aug 15 19:38:37 +0000 2018
# Tweet collected at Wed Aug 15 19:38:37 +0000 2018
# Tweet collected at Wed Aug 15 19:38:37 +0000 2018
# Tweet collected at Wed Aug 15 19:38:38 +0000 2018
# Tweet collected at Wed Aug 15 19:38:39 +0000 2018
# Tweet collected at Wed Aug 15 19:38:39 +0000 2018
# Tweet collected at Wed Aug 15 19:38:39 +0000 2018
# Tweet collected at Wed Aug 15 19:38:41 +0000 2018
# Tweet collected at Wed Aug 15 19:38:41 +0000 2018
# Tweet collected at Wed Aug 15 19:38:42 +0000 2018
# Tweet collected at Wed Aug 15 19:38:43 +0000 2018
# Tweet collected at Wed Aug 15 19:38:43 +0000 2018
# Tweet collected at Wed Aug 15 19:38:43 +0000 2018
# Tweet collected at Wed Aug 15 19:38:45 +0000 2018
# Tweet collected at Wed Aug 15 19:38:46 +0000 2018
# Tweet collected at Wed Aug 15 19:38:47 +0000 2018
# Tweet collected at Wed Aug 15 19:38:47 +0000 2018
# Tweet collected at Wed Aug 15 19:38:54 +0000 2018
# Tweet collected at Wed Aug 15 19:38:56 +0000 2018
# Tweet collected at Wed Aug 15 19:38:56 +0000 2018
# Tweet collected at Wed Aug 15 19:38:57 +0000 2018
# Tweet collected at Wed Aug 15 19:39:00 +0000 2018
# Tweet collected at Wed Aug 15 19:39:00 +0000 2018
# Tweet collected at Wed Aug 15 19:39:00 +0000 2018
# Tweet collected at Wed Aug 15 19:39:01 +0000 2018
# Tweet collected at Wed Aug 15 19:39:02 +0000 2018
# Tweet collected at Wed Aug 15 19:39:01 +0000 2018
# Tweet collected at Wed Aug 15 19:39:02 +0000 2018
# Tweet collected at Wed Aug 15 19:39:03 +0000 2018
# Tweet collected at Wed Aug 15 19:39:03 +0000 2018
# Tweet collected at Wed Aug 15 19:39:04 +0000 2018
# Tweet collected at Wed Aug 15 19:39:04 +0000 2018
# Tweet collected at Wed Aug 15 19:39:04 +0000 2018
# Tweet collected at Wed Aug 15 19:39:05 +0000 2018
# Tweet collected at Wed Aug 15 19:39:06 +0000 2018
# Tweet collected at Wed Aug 15 19:39:07 +0000 2018
# Tweet collected at Wed Aug 15 19:39:07 +0000 2018
# Tweet collected at Wed Aug 15 19:39:09 +0000 2018
# Tweet collected at Wed Aug 15 19:39:10 +0000 2018
# Tweet collected at Wed Aug 15 19:39:13 +0000 2018
# Tweet collected at Wed Aug 15 19:39:19 +0000 2018
# Tweet collected at Wed Aug 15 19:39:19 +0000 2018
# Tweet collected at Wed Aug 15 19:39:19 +0000 2018
# Tweet collected at Wed Aug 15 19:39:19 +0000 2018
# Tweet collected at Wed Aug 15 19:39:20 +0000 2018
# Tweet collected at Wed Aug 15 19:39:20 +0000 2018
# Tweet collected at Wed Aug 15 19:39:20 +0000 2018
# Tweet collected at Wed Aug 15 19:39:21 +0000 2018
# Tweet collected at Wed Aug 15 19:39:22 +0000 2018
# Tweet collected at Wed Aug 15 19:39:22 +0000 2018
# Tweet collected at Wed Aug 15 19:39:23 +0000 2018
# Tweet collected at Wed Aug 15 19:39:28 +0000 2018
# Tweet collected at Wed Aug 15 19:39:29 +0000 2018
# Tweet collected at Wed Aug 15 19:39:32 +0000 2018
# Tweet collected at Wed Aug 15 19:39:33 +0000 2018
# Tweet collected at Wed Aug 15 19:39:33 +0000 2018
# Tweet collected at Wed Aug 15 19:39:36 +0000 2018
# Tweet collected at Wed Aug 15 19:39:36 +0000 2018
# Tweet collected at Wed Aug 15 19:39:37 +0000 2018
# Tweet collected at Wed Aug 15 19:39:38 +0000 2018
# Tweet collected at Wed Aug 15 19:39:38 +0000 2018
# Tweet collected at Wed Aug 15 19:39:40 +0000 2018
# Tweet collected at Wed Aug 15 19:39:40 +0000 2018
# Tweet collected at Wed Aug 15 19:39:44 +0000 2018
# Tweet collected at Wed Aug 15 19:39:47 +0000 2018
# Tweet collected at Wed Aug 15 19:39:47 +0000 2018
# Tweet collected at Wed Aug 15 19:39:50 +0000 2018
# Tweet collected at Wed Aug 15 19:39:52 +0000 2018
# Tweet collected at Wed Aug 15 19:39:54 +0000 2018
# Tweet collected at Wed Aug 15 19:39:55 +0000 2018
# Tweet collected at Wed Aug 15 19:39:55 +0000 2018
# Tweet collected at Wed Aug 15 19:39:55 +0000 2018
# Tweet collected at Wed Aug 15 19:39:56 +0000 2018
# Tweet collected at Wed Aug 15 19:39:59 +0000 2018
# Tweet collected at Wed Aug 15 19:39:59 +0000 2018
# Tweet collected at Wed Aug 15 19:40:00 +0000 2018
# Tweet collected at Wed Aug 15 19:40:01 +0000 2018
# Tweet collected at Wed Aug 15 19:40:03 +0000 2018
# Tweet collected at Wed Aug 15 19:40:03 +0000 2018
# Tweet collected at Wed Aug 15 19:40:03 +0000 2018
# Tweet collected at Wed Aug 15 19:40:04 +0000 2018
# Tweet collected at Wed Aug 15 19:40:04 +0000 2018
# Tweet collected at Wed Aug 15 19:40:04 +0000 2018
# Tweet collected at Wed Aug 15 19:40:05 +0000 2018
# Tweet collected at Wed Aug 15 19:40:05 +0000 2018
# Tweet collected at Wed Aug 15 19:40:05 +0000 2018
# Tweet collected at Wed Aug 15 19:40:06 +0000 2018
# Tweet collected at Wed Aug 15 19:40:06 +0000 2018
# Tweet collected at Wed Aug 15 19:40:06 +0000 2018
# Tweet collected at Wed Aug 15 19:40:07 +0000 2018
# Tweet collected at Wed Aug 15 19:40:07 +0000 2018
# Tweet collected at Wed Aug 15 19:40:09 +0000 2018
# Tweet collected at Wed Aug 15 19:40:10 +0000 2018
# Tweet collected at Wed Aug 15 19:40:11 +0000 2018
# Tweet collected at Wed Aug 15 19:40:12 +0000 2018
# Tweet collected at Wed Aug 15 19:40:12 +0000 2018
# Tweet collected at Wed Aug 15 19:40:12 +0000 2018
# Tweet collected at Wed Aug 15 19:40:14 +0000 2018
# Tweet collected at Wed Aug 15 19:40:14 +0000 2018
# Tweet collected at Wed Aug 15 19:40:14 +0000 2018
# Tweet collected at Wed Aug 15 19:40:15 +0000 2018
# Tweet collected at Wed Aug 15 19:40:15 +0000 2018
# Tweet collected at Wed Aug 15 19:40:16 +0000 2018
# Tweet collected at Wed Aug 15 19:40:17 +0000 2018
# Tweet collected at Wed Aug 15 19:40:17 +0000 2018
# Tweet collected at Wed Aug 15 19:40:17 +0000 2018
# Tweet collected at Wed Aug 15 19:40:17 +0000 2018
# Tweet collected at Wed Aug 15 19:40:17 +0000 2018
# Tweet collected at Wed Aug 15 19:40:17 +0000 2018
# Tweet collected at Wed Aug 15 19:40:18 +0000 2018
# Tweet collected at Wed Aug 15 19:40:18 +0000 2018
# Tweet collected at Wed Aug 15 19:40:19 +0000 2018
# Tweet collected at Wed Aug 15 19:40:19 +0000 2018
# Tweet collected at Wed Aug 15 19:40:19 +0000 2018
# Tweet collected at Wed Aug 15 19:40:19 +0000 2018
# Tweet collected at Wed Aug 15 19:40:19 +0000 2018
# Tweet collected at Wed Aug 15 19:40:19 +0000 2018
# Tweet collected at Wed Aug 15 19:40:21 +0000 2018
# Tweet collected at Wed Aug 15 19:40:21 +0000 2018
# Tweet collected at Wed Aug 15 19:40:21 +0000 2018
# Tweet collected at Wed Aug 15 19:40:21 +0000 2018
# Tweet collected at Wed Aug 15 19:40:23 +0000 2018
# Tweet collected at Wed Aug 15 19:40:24 +0000 2018
# Tweet collected at Wed Aug 15 19:40:24 +0000 2018
# Tweet collected at Wed Aug 15 19:40:24 +0000 2018
# Tweet collected at Wed Aug 15 19:40:24 +0000 2018
# Tweet collected at Wed Aug 15 19:40:26 +0000 2018
# Tweet collected at Wed Aug 15 19:40:27 +0000 2018
# Tweet collected at Wed Aug 15 19:40:28 +0000 2018
# Tweet collected at Wed Aug 15 19:40:29 +0000 2018
# Tweet collected at Wed Aug 15 19:40:29 +0000 2018
# Tweet collected at Wed Aug 15 19:40:30 +0000 2018
# Tweet collected at Wed Aug 15 19:40:30 +0000 2018
# Tweet collected at Wed Aug 15 19:40:30 +0000 2018
# Tweet collected at Wed Aug 15 19:40:32 +0000 2018
# Tweet collected at Wed Aug 15 19:40:32 +0000 2018
# Tweet collected at Wed Aug 15 19:40:32 +0000 2018
# Tweet collected at Wed Aug 15 19:40:34 +0000 2018
# Tweet collected at Wed Aug 15 19:40:36 +0000 2018
# Tweet collected at Wed Aug 15 19:40:36 +0000 2018
# Tweet collected at Wed Aug 15 19:40:37 +0000 2018
# Tweet collected at Wed Aug 15 19:40:39 +0000 2018
# Tweet collected at Wed Aug 15 19:40:39 +0000 2018
# Tweet collected at Wed Aug 15 19:40:39 +0000 2018
# Tweet collected at Wed Aug 15 19:40:41 +0000 2018
# Tweet collected at Wed Aug 15 19:40:41 +0000 2018
# Tweet collected at Wed Aug 15 19:40:43 +0000 2018
# Tweet collected at Wed Aug 15 19:40:43 +0000 2018
# Tweet collected at Wed Aug 15 19:40:44 +0000 2018
# Tweet collected at Wed Aug 15 19:40:45 +0000 2018
# Tweet collected at Wed Aug 15 19:40:46 +0000 2018
# Tweet collected at Wed Aug 15 19:40:46 +0000 2018
# Tweet collected at Wed Aug 15 19:40:46 +0000 2018
# Tweet collected at Wed Aug 15 19:40:48 +0000 2018
# Tweet collected at Wed Aug 15 19:40:49 +0000 2018
# Tweet collected at Wed Aug 15 19:40:49 +0000 2018
# Tweet collected at Wed Aug 15 19:40:50 +0000 2018
# Tweet collected at Wed Aug 15 19:40:50 +0000 2018
# Tweet collected at Wed Aug 15 19:40:51 +0000 2018
# Tweet collected at Wed Aug 15 19:40:51 +0000 2018
# Tweet collected at Wed Aug 15 19:40:52 +0000 2018
# Tweet collected at Wed Aug 15 19:40:52 +0000 2018
# Tweet collected at Wed Aug 15 19:40:53 +0000 2018
# Tweet collected at Wed Aug 15 19:40:53 +0000 2018
# Tweet collected at Wed Aug 15 19:40:56 +0000 2018
# Tweet collected at Wed Aug 15 19:41:00 +0000 2018
# Tweet collected at Wed Aug 15 19:41:01 +0000 2018
# Tweet collected at Wed Aug 15 19:41:02 +0000 2018
# Tweet collected at Wed Aug 15 19:41:03 +0000 2018
# Tweet collected at Wed Aug 15 19:41:04 +0000 2018
# Tweet collected at Wed Aug 15 19:41:09 +0000 2018
# Tweet collected at Wed Aug 15 19:41:09 +0000 2018
# Tweet collected at Wed Aug 15 19:41:09 +0000 2018
# Tweet collected at Wed Aug 15 19:41:10 +0000 2018
# Tweet collected at Wed Aug 15 19:41:11 +0000 2018
# Tweet collected at Wed Aug 15 19:41:11 +0000 2018
# Tweet collected at Wed Aug 15 19:41:11 +0000 2018
# Tweet collected at Wed Aug 15 19:41:12 +0000 2018
# Tweet collected at Wed Aug 15 19:41:16 +0000 2018
# Tweet collected at Wed Aug 15 19:41:17 +0000 2018
# Tweet collected at Wed Aug 15 19:41:17 +0000 2018
# Tweet collected at Wed Aug 15 19:41:17 +0000 2018
# Tweet collected at Wed Aug 15 19:41:18 +0000 2018
# Tweet collected at Wed Aug 15 19:41:19 +0000 2018
# Tweet collected at Wed Aug 15 19:41:19 +0000 2018
# Tweet collected at Wed Aug 15 19:41:21 +0000 2018
# Tweet collected at Wed Aug 15 19:41:24 +0000 2018
# Tweet collected at Wed Aug 15 19:41:28 +0000 2018
# Tweet collected at Wed Aug 15 19:41:28 +0000 2018
# Tweet collected at Wed Aug 15 19:41:32 +0000 2018
# Tweet collected at Wed Aug 15 19:41:33 +0000 2018
# Tweet collected at Wed Aug 15 19:41:34 +0000 2018
# Tweet collected at Wed Aug 15 19:41:35 +0000 2018
# Tweet collected at Wed Aug 15 19:41:35 +0000 2018
# Tweet collected at Wed Aug 15 19:41:36 +0000 2018
# Tweet collected at Wed Aug 15 19:41:36 +0000 2018
# Tweet collected at Wed Aug 15 19:41:37 +0000 2018
# Tweet collected at Wed Aug 15 19:41:37 +0000 2018
# Tweet collected at Wed Aug 15 19:41:38 +0000 2018
# Tweet collected at Wed Aug 15 19:41:40 +0000 2018
# Tweet collected at Wed Aug 15 19:41:42 +0000 2018
# Tweet collected at Wed Aug 15 19:41:42 +0000 2018
# Tweet collected at Wed Aug 15 19:41:42 +0000 2018
# Tweet collected at Wed Aug 15 19:41:43 +0000 2018
# Tweet collected at Wed Aug 15 19:41:43 +0000 2018
# Tweet collected at Wed Aug 15 19:41:44 +0000 2018
# Tweet collected at Wed Aug 15 19:41:48 +0000 2018
# Tweet collected at Wed Aug 15 19:41:48 +0000 2018
# Tweet collected at Wed Aug 15 19:41:49 +0000 2018
# Tweet collected at Wed Aug 15 19:41:49 +0000 2018
# Tweet collected at Wed Aug 15 19:41:50 +0000 2018
# Tweet collected at Wed Aug 15 19:41:53 +0000 2018
# Tweet collected at Wed Aug 15 19:41:53 +0000 2018
# Tweet collected at Wed Aug 15 19:41:55 +0000 2018
# Tweet collected at Wed Aug 15 19:41:55 +0000 2018
# Tweet collected at Wed Aug 15 19:41:56 +0000 2018
# Tweet collected at Wed Aug 15 19:41:56 +0000 2018
# Tweet collected at Wed Aug 15 19:41:56 +0000 2018
# Tweet collected at Wed Aug 15 19:41:58 +0000 2018
# Tweet collected at Wed Aug 15 19:42:00 +0000 2018
# Tweet collected at Wed Aug 15 19:42:01 +0000 2018
# Tweet collected at Wed Aug 15 19:42:01 +0000 2018
# Tweet collected at Wed Aug 15 19:42:02 +0000 2018
# Tweet collected at Wed Aug 15 19:42:02 +0000 2018
# Tweet collected at Wed Aug 15 19:42:04 +0000 2018
# Tweet collected at Wed Aug 15 19:42:02 +0000 2018
# Tweet collected at Wed Aug 15 19:42:07 +0000 2018
# Tweet collected at Wed Aug 15 19:42:07 +0000 2018
# Tweet collected at Wed Aug 15 19:42:09 +0000 2018
# Tweet collected at Wed Aug 15 19:42:12 +0000 2018
# Tweet collected at Wed Aug 15 19:42:12 +0000 2018
# Tweet collected at Wed Aug 15 19:42:14 +0000 2018
# Tweet collected at Wed Aug 15 19:42:14 +0000 2018
# Tweet collected at Wed Aug 15 19:42:15 +0000 2018
# Tweet collected at Wed Aug 15 19:42:15 +0000 2018
# Tweet collected at Wed Aug 15 19:42:16 +0000 2018
# Tweet collected at Wed Aug 15 19:42:16 +0000 2018
# Tweet collected at Wed Aug 15 19:42:17 +0000 2018
# Tweet collected at Wed Aug 15 19:42:18 +0000 2018
# Tweet collected at Wed Aug 15 19:42:18 +0000 2018
# Tweet collected at Wed Aug 15 19:42:18 +0000 2018
# Tweet collected at Wed Aug 15 19:42:20 +0000 2018
# Tweet collected at Wed Aug 15 19:42:22 +0000 2018
# Tweet collected at Wed Aug 15 19:42:22 +0000 2018
# Tweet collected at Wed Aug 15 19:42:22 +0000 2018
# Tweet collected at Wed Aug 15 19:42:24 +0000 2018
# Tweet collected at Wed Aug 15 19:42:25 +0000 2018
# Tweet collected at Wed Aug 15 19:42:26 +0000 2018
# Tweet collected at Wed Aug 15 19:42:32 +0000 2018
# Tweet collected at Wed Aug 15 19:42:34 +0000 2018
# Tweet collected at Wed Aug 15 19:42:34 +0000 2018
# Tweet collected at Wed Aug 15 19:42:35 +0000 2018
# Tweet collected at Wed Aug 15 19:42:39 +0000 2018
# Tweet collected at Wed Aug 15 19:42:39 +0000 2018
# Tweet collected at Wed Aug 15 19:42:40 +0000 2018
# Tweet collected at Wed Aug 15 19:42:43 +0000 2018
# Tweet collected at Wed Aug 15 19:42:44 +0000 2018
# Tweet collected at Wed Aug 15 19:42:44 +0000 2018
# Tweet collected at Wed Aug 15 19:42:45 +0000 2018
# Tweet collected at Wed Aug 15 19:42:53 +0000 2018
# Tweet collected at Wed Aug 15 19:42:53 +0000 2018
# Tweet collected at Wed Aug 15 19:42:54 +0000 2018
# Tweet collected at Wed Aug 15 19:42:55 +0000 2018
# Tweet collected at Wed Aug 15 19:42:55 +0000 2018
# Tweet collected at Wed Aug 15 19:42:57 +0000 2018
# Tweet collected at Wed Aug 15 19:42:57 +0000 2018
# Tweet collected at Wed Aug 15 19:42:59 +0000 2018
# Tweet collected at Wed Aug 15 19:43:01 +0000 2018
# Tweet collected at Wed Aug 15 19:43:03 +0000 2018
# Tweet collected at Wed Aug 15 19:43:03 +0000 2018
# Tweet collected at Wed Aug 15 19:43:03 +0000 2018
# Tweet collected at Wed Aug 15 19:43:04 +0000 2018
# Tweet collected at Wed Aug 15 19:43:08 +0000 2018
# Tweet collected at Wed Aug 15 19:43:08 +0000 2018
# Tweet collected at Wed Aug 15 19:43:08 +0000 2018
# Tweet collected at Wed Aug 15 19:43:09 +0000 2018
# Tweet collected at Wed Aug 15 19:43:16 +0000 2018
# Tweet collected at Wed Aug 15 19:43:17 +0000 2018
# Tweet collected at Wed Aug 15 19:43:21 +0000 2018
# Tweet collected at Wed Aug 15 19:43:22 +0000 2018
# Tweet collected at Wed Aug 15 19:43:23 +0000 2018
# Tweet collected at Wed Aug 15 19:43:23 +0000 2018
# Tweet collected at Wed Aug 15 19:43:23 +0000 2018
# Tweet collected at Wed Aug 15 19:43:24 +0000 2018
# Tweet collected at Wed Aug 15 19:43:25 +0000 2018
# Tweet collected at Wed Aug 15 19:43:27 +0000 2018
# Tweet collected at Wed Aug 15 19:43:27 +0000 2018
# Tweet collected at Wed Aug 15 19:43:27 +0000 2018
# Tweet collected at Wed Aug 15 19:43:33 +0000 2018
# Tweet collected at Wed Aug 15 19:43:35 +0000 2018
# Tweet collected at Wed Aug 15 19:43:36 +0000 2018
# Tweet collected at Wed Aug 15 19:43:36 +0000 2018
# Tweet collected at Wed Aug 15 19:43:37 +0000 2018
# Tweet collected at Wed Aug 15 19:43:37 +0000 2018
# Tweet collected at Wed Aug 15 19:43:38 +0000 2018
# Tweet collected at Wed Aug 15 19:43:42 +0000 2018
# Tweet collected at Wed Aug 15 19:43:42 +0000 2018
# Tweet collected at Wed Aug 15 19:43:44 +0000 2018
# Tweet collected at Wed Aug 15 19:43:45 +0000 2018
# Tweet collected at Wed Aug 15 19:43:45 +0000 2018
# Tweet collected at Wed Aug 15 19:43:47 +0000 2018
# Tweet collected at Wed Aug 15 19:43:48 +0000 2018
# Tweet collected at Wed Aug 15 19:43:50 +0000 2018
# Tweet collected at Wed Aug 15 19:43:51 +0000 2018
# Tweet collected at Wed Aug 15 19:43:52 +0000 2018
# Tweet collected at Wed Aug 15 19:43:56 +0000 2018
# Tweet collected at Wed Aug 15 19:43:56 +0000 2018
# Tweet collected at Wed Aug 15 19:43:58 +0000 2018
# Tweet collected at Wed Aug 15 19:43:59 +0000 2018
# Tweet collected at Wed Aug 15 19:44:00 +0000 2018
# Tweet collected at Wed Aug 15 19:44:03 +0000 2018
# Tweet collected at Wed Aug 15 19:44:04 +0000 2018
# Tweet collected at Wed Aug 15 19:44:06 +0000 2018
# Tweet collected at Wed Aug 15 19:44:06 +0000 2018
# Tweet collected at Wed Aug 15 19:44:07 +0000 2018
# Tweet collected at Wed Aug 15 19:44:06 +0000 2018
# Tweet collected at Wed Aug 15 19:44:09 +0000 2018
# Tweet collected at Wed Aug 15 19:44:09 +0000 2018
# Tweet collected at Wed Aug 15 19:44:09 +0000 2018
# Tweet collected at Wed Aug 15 19:44:10 +0000 2018
# Tweet collected at Wed Aug 15 19:44:13 +0000 2018
# Tweet collected at Wed Aug 15 19:44:15 +0000 2018
# Tweet collected at Wed Aug 15 19:44:17 +0000 2018
# Tweet collected at Wed Aug 15 19:44:17 +0000 2018
# Tweet collected at Wed Aug 15 19:44:17 +0000 2018
# Tweet collected at Wed Aug 15 19:44:19 +0000 2018
# Tweet collected at Wed Aug 15 19:44:19 +0000 2018
# Tweet collected at Wed Aug 15 19:44:19 +0000 2018
# Tweet collected at Wed Aug 15 19:44:22 +0000 2018
# Tweet collected at Wed Aug 15 19:44:23 +0000 2018
# Tweet collected at Wed Aug 15 19:44:25 +0000 2018
# Tweet collected at Wed Aug 15 19:44:25 +0000 2018
# Tweet collected at Wed Aug 15 19:44:25 +0000 2018
# Tweet collected at Wed Aug 15 19:44:26 +0000 2018
# Tweet collected at Wed Aug 15 19:44:26 +0000 2018
# Tweet collected at Wed Aug 15 19:44:28 +0000 2018
# Tweet collected at Wed Aug 15 19:44:29 +0000 2018
# Tweet collected at Wed Aug 15 19:44:30 +0000 2018
# Tweet collected at Wed Aug 15 19:44:31 +0000 2018
# Tweet collected at Wed Aug 15 19:44:35 +0000 2018
# Tweet collected at Wed Aug 15 19:44:35 +0000 2018
# Tweet collected at Wed Aug 15 19:44:38 +0000 2018
# Tweet collected at Wed Aug 15 19:44:39 +0000 2018
# Tweet collected at Wed Aug 15 19:44:42 +0000 2018
# Tweet collected at Wed Aug 15 19:44:44 +0000 2018
# Tweet collected at Wed Aug 15 19:44:46 +0000 2018
# Tweet collected at Wed Aug 15 19:44:51 +0000 2018
# Tweet collected at Wed Aug 15 19:44:54 +0000 2018
# Tweet collected at Wed Aug 15 19:44:54 +0000 2018
# Tweet collected at Wed Aug 15 19:44:54 +0000 2018
# Tweet collected at Wed Aug 15 19:44:57 +0000 2018
# Tweet collected at Wed Aug 15 19:44:58 +0000 2018
# Tweet collected at Wed Aug 15 19:44:58 +0000 2018
# Tweet collected at Wed Aug 15 19:44:58 +0000 2018
# Tweet collected at Wed Aug 15 19:45:00 +0000 2018
# Tweet collected at Wed Aug 15 19:45:01 +0000 2018
# Tweet collected at Wed Aug 15 19:45:03 +0000 2018
# Tweet collected at Wed Aug 15 19:45:03 +0000 2018
# Tweet collected at Wed Aug 15 19:45:03 +0000 2018
# Tweet collected at Wed Aug 15 19:45:04 +0000 2018
# Tweet collected at Wed Aug 15 19:45:04 +0000 2018
# Tweet collected at Wed Aug 15 19:45:05 +0000 2018
# Tweet collected at Wed Aug 15 19:45:04 +0000 2018
# Tweet collected at Wed Aug 15 19:45:04 +0000 2018
# Tweet collected at Wed Aug 15 19:45:06 +0000 2018
# Tweet collected at Wed Aug 15 19:45:06 +0000 2018
# Tweet collected at Wed Aug 15 19:45:05 +0000 2018
# Tweet collected at Wed Aug 15 19:45:08 +0000 2018
# Tweet collected at Wed Aug 15 19:45:08 +0000 2018
# Tweet collected at Wed Aug 15 19:45:09 +0000 2018
# Tweet collected at Wed Aug 15 19:45:09 +0000 2018
# Tweet collected at Wed Aug 15 19:45:15 +0000 2018
# Tweet collected at Wed Aug 15 19:45:16 +0000 2018
# Tweet collected at Wed Aug 15 19:45:16 +0000 2018
# Tweet collected at Wed Aug 15 19:45:16 +0000 2018
# Tweet collected at Wed Aug 15 19:45:16 +0000 2018
# Tweet collected at Wed Aug 15 19:45:17 +0000 2018
# Tweet collected at Wed Aug 15 19:45:20 +0000 2018
# Tweet collected at Wed Aug 15 19:45:20 +0000 2018
# Tweet collected at Wed Aug 15 19:45:21 +0000 2018
# Tweet collected at Wed Aug 15 19:45:21 +0000 2018
# Tweet collected at Wed Aug 15 19:45:21 +0000 2018
# Tweet collected at Wed Aug 15 19:45:23 +0000 2018
# Tweet collected at Wed Aug 15 19:45:25 +0000 2018
# Tweet collected at Wed Aug 15 19:45:26 +0000 2018
# Tweet collected at Wed Aug 15 19:45:26 +0000 2018
# Tweet collected at Wed Aug 15 19:45:28 +0000 2018
# Tweet collected at Wed Aug 15 19:45:29 +0000 2018
# Tweet collected at Wed Aug 15 19:45:30 +0000 2018
# Tweet collected at Wed Aug 15 19:45:30 +0000 2018
# Tweet collected at Wed Aug 15 19:45:31 +0000 2018
# Tweet collected at Wed Aug 15 19:45:31 +0000 2018
# Tweet collected at Wed Aug 15 19:45:32 +0000 2018
# Tweet collected at Wed Aug 15 19:45:34 +0000 2018
# Tweet collected at Wed Aug 15 19:45:36 +0000 2018
# Tweet collected at Wed Aug 15 19:45:37 +0000 2018
# Tweet collected at Wed Aug 15 19:45:37 +0000 2018
# Tweet collected at Wed Aug 15 19:45:38 +0000 2018
# Tweet collected at Wed Aug 15 19:45:39 +0000 2018
# Tweet collected at Wed Aug 15 19:45:41 +0000 2018
# Tweet collected at Wed Aug 15 19:45:41 +0000 2018
# Tweet collected at Wed Aug 15 19:45:41 +0000 2018
# Tweet collected at Wed Aug 15 19:45:42 +0000 2018
# Tweet collected at Wed Aug 15 19:45:42 +0000 2018
# Tweet collected at Wed Aug 15 19:45:45 +0000 2018
# Tweet collected at Wed Aug 15 19:45:47 +0000 2018
# Tweet collected at Wed Aug 15 19:45:47 +0000 2018
# Tweet collected at Wed Aug 15 19:45:47 +0000 2018
# Tweet collected at Wed Aug 15 19:45:48 +0000 2018
# Tweet collected at Wed Aug 15 19:45:48 +0000 2018
# Tweet collected at Wed Aug 15 19:45:48 +0000 2018
# Tweet collected at Wed Aug 15 19:45:50 +0000 2018
# Tweet collected at Wed Aug 15 19:45:54 +0000 2018
# Tweet collected at Wed Aug 15 19:45:58 +0000 2018
# Tweet collected at Wed Aug 15 19:46:00 +0000 2018
# Tweet collected at Wed Aug 15 19:46:01 +0000 2018
# Tweet collected at Wed Aug 15 19:46:01 +0000 2018
# Tweet collected at Wed Aug 15 19:46:03 +0000 2018
# Tweet collected at Wed Aug 15 19:46:02 +0000 2018
# Tweet collected at Wed Aug 15 19:46:03 +0000 2018
# Tweet collected at Wed Aug 15 19:46:05 +0000 2018
# Tweet collected at Wed Aug 15 19:46:07 +0000 2018
# Tweet collected at Wed Aug 15 19:46:08 +0000 2018
# Tweet collected at Wed Aug 15 19:46:08 +0000 2018
# Tweet collected at Wed Aug 15 19:46:09 +0000 2018
# Tweet collected at Wed Aug 15 19:46:11 +0000 2018
# Tweet collected at Wed Aug 15 19:46:11 +0000 2018
# Tweet collected at Wed Aug 15 19:46:12 +0000 2018
# Tweet collected at Wed Aug 15 19:46:13 +0000 2018
# Tweet collected at Wed Aug 15 19:46:14 +0000 2018
# Tweet collected at Wed Aug 15 19:46:15 +0000 2018
# Tweet collected at Wed Aug 15 19:46:15 +0000 2018
# Tweet collected at Wed Aug 15 19:46:15 +0000 2018
# Tweet collected at Wed Aug 15 19:46:16 +0000 2018
# Tweet collected at Wed Aug 15 19:46:16 +0000 2018
# Tweet collected at Wed Aug 15 19:46:17 +0000 2018
# Tweet collected at Wed Aug 15 19:46:18 +0000 2018
# Tweet collected at Wed Aug 15 19:46:18 +0000 2018
# Tweet collected at Wed Aug 15 19:46:24 +0000 2018
# Tweet collected at Wed Aug 15 19:46:24 +0000 2018
# Tweet collected at Wed Aug 15 19:46:25 +0000 2018
# Tweet collected at Wed Aug 15 19:46:25 +0000 2018
# Tweet collected at Wed Aug 15 19:46:25 +0000 2018
# Tweet collected at Wed Aug 15 19:46:26 +0000 2018
# Tweet collected at Wed Aug 15 19:46:26 +0000 2018
# Tweet collected at Wed Aug 15 19:46:28 +0000 2018
# Tweet collected at Wed Aug 15 19:46:31 +0000 2018
# Tweet collected at Wed Aug 15 19:46:31 +0000 2018
# Tweet collected at Wed Aug 15 19:46:33 +0000 2018
# Tweet collected at Wed Aug 15 19:46:34 +0000 2018
# Tweet collected at Wed Aug 15 19:46:35 +0000 2018
# Tweet collected at Wed Aug 15 19:46:36 +0000 2018
# Tweet collected at Wed Aug 15 19:46:37 +0000 2018
# Tweet collected at Wed Aug 15 19:46:39 +0000 2018
# Tweet collected at Wed Aug 15 19:46:50 +0000 2018
# Tweet collected at Wed Aug 15 19:46:50 +0000 2018
# Tweet collected at Wed Aug 15 19:46:53 +0000 2018
# Tweet collected at Wed Aug 15 19:46:56 +0000 2018
# Tweet collected at Wed Aug 15 19:46:57 +0000 2018
# Tweet collected at Wed Aug 15 19:46:58 +0000 2018
# Tweet collected at Wed Aug 15 19:46:59 +0000 2018
# Tweet collected at Wed Aug 15 19:47:00 +0000 2018
# Tweet collected at Wed Aug 15 19:47:00 +0000 2018
# Tweet collected at Wed Aug 15 19:47:05 +0000 2018
# Tweet collected at Wed Aug 15 19:47:10 +0000 2018
# Tweet collected at Wed Aug 15 19:47:10 +0000 2018
# Tweet collected at Wed Aug 15 19:47:16 +0000 2018
# Tweet collected at Wed Aug 15 19:47:16 +0000 2018
# Tweet collected at Wed Aug 15 19:47:20 +0000 2018
# Tweet collected at Wed Aug 15 19:47:21 +0000 2018
# Tweet collected at Wed Aug 15 19:47:22 +0000 2018
# Tweet collected at Wed Aug 15 19:47:28 +0000 2018
# Tweet collected at Wed Aug 15 19:47:29 +0000 2018
# Tweet collected at Wed Aug 15 19:47:29 +0000 2018
# Tweet collected at Wed Aug 15 19:47:31 +0000 2018
# Tweet collected at Wed Aug 15 19:47:34 +0000 2018
# Tweet collected at Wed Aug 15 19:47:36 +0000 2018
# Tweet collected at Wed Aug 15 19:47:36 +0000 2018
# Tweet collected at Wed Aug 15 19:47:37 +0000 2018
# Tweet collected at Wed Aug 15 19:47:42 +0000 2018
# Tweet collected at Wed Aug 15 19:47:43 +0000 2018
# Tweet collected at Wed Aug 15 19:47:44 +0000 2018
# Tweet collected at Wed Aug 15 19:47:45 +0000 2018
# Tweet collected at Wed Aug 15 19:47:48 +0000 2018
# Tweet collected at Wed Aug 15 19:47:49 +0000 2018
# Tweet collected at Wed Aug 15 19:47:51 +0000 2018
# Tweet collected at Wed Aug 15 19:47:51 +0000 2018
# Tweet collected at Wed Aug 15 19:47:54 +0000 2018
# Tweet collected at Wed Aug 15 19:47:56 +0000 2018
# Tweet collected at Wed Aug 15 19:47:56 +0000 2018
# Tweet collected at Wed Aug 15 19:47:57 +0000 2018
# Tweet collected at Wed Aug 15 19:47:58 +0000 2018
# Tweet collected at Wed Aug 15 19:47:57 +0000 2018
# Tweet collected at Wed Aug 15 19:48:00 +0000 2018
# Tweet collected at Wed Aug 15 19:48:01 +0000 2018
# Tweet collected at Wed Aug 15 19:48:01 +0000 2018
# Tweet collected at Wed Aug 15 19:48:02 +0000 2018
# Tweet collected at Wed Aug 15 19:48:03 +0000 2018
# Tweet collected at Wed Aug 15 19:48:04 +0000 2018
# Tweet collected at Wed Aug 15 19:48:05 +0000 2018
# Tweet collected at Wed Aug 15 19:48:06 +0000 2018
# Tweet collected at Wed Aug 15 19:48:07 +0000 2018
# Tweet collected at Wed Aug 15 19:48:08 +0000 2018
# Tweet collected at Wed Aug 15 19:48:08 +0000 2018
# Tweet collected at Wed Aug 15 19:48:09 +0000 2018
# Tweet collected at Wed Aug 15 19:48:09 +0000 2018
# Tweet collected at Wed Aug 15 19:48:13 +0000 2018
# Tweet collected at Wed Aug 15 19:48:16 +0000 2018
# Tweet collected at Wed Aug 15 19:48:17 +0000 2018
# Tweet collected at Wed Aug 15 19:48:17 +0000 2018
# Tweet collected at Wed Aug 15 19:48:19 +0000 2018
# Tweet collected at Wed Aug 15 19:48:20 +0000 2018
# Tweet collected at Wed Aug 15 19:48:21 +0000 2018
# Tweet collected at Wed Aug 15 19:48:23 +0000 2018
# Tweet collected at Wed Aug 15 19:48:24 +0000 2018
# Tweet collected at Wed Aug 15 19:48:26 +0000 2018
# Tweet collected at Wed Aug 15 19:48:28 +0000 2018
# Tweet collected at Wed Aug 15 19:48:31 +0000 2018
# Tweet collected at Wed Aug 15 19:48:31 +0000 2018
# Tweet collected at Wed Aug 15 19:48:35 +0000 2018
# Tweet collected at Wed Aug 15 19:48:35 +0000 2018
# Tweet collected at Wed Aug 15 19:48:35 +0000 2018
# Tweet collected at Wed Aug 15 19:48:38 +0000 2018
# Tweet collected at Wed Aug 15 19:48:40 +0000 2018
# Tweet collected at Wed Aug 15 19:48:41 +0000 2018
# Tweet collected at Wed Aug 15 19:48:41 +0000 2018
# Tweet collected at Wed Aug 15 19:48:44 +0000 2018
# Tweet collected at Wed Aug 15 19:48:48 +0000 2018
# Tweet collected at Wed Aug 15 19:48:48 +0000 2018
# Tweet collected at Wed Aug 15 19:48:49 +0000 2018
# Tweet collected at Wed Aug 15 19:48:51 +0000 2018
# Tweet collected at Wed Aug 15 19:48:54 +0000 2018
# Tweet collected at Wed Aug 15 19:48:55 +0000 2018
# Tweet collected at Wed Aug 15 19:48:55 +0000 2018
# Tweet collected at Wed Aug 15 19:48:56 +0000 2018
# Tweet collected at Wed Aug 15 19:48:57 +0000 2018
# Tweet collected at Wed Aug 15 19:48:58 +0000 2018
# Tweet collected at Wed Aug 15 19:48:58 +0000 2018
# Tweet collected at Wed Aug 15 19:48:58 +0000 2018
# Tweet collected at Wed Aug 15 19:48:59 +0000 2018
# Tweet collected at Wed Aug 15 19:49:00 +0000 2018
# Tweet collected at Wed Aug 15 19:49:02 +0000 2018
# Tweet collected at Wed Aug 15 19:49:04 +0000 2018
# Tweet collected at Wed Aug 15 19:49:05 +0000 2018
# Tweet collected at Wed Aug 15 19:49:05 +0000 2018
# Tweet collected at Wed Aug 15 19:49:06 +0000 2018
# Tweet collected at Wed Aug 15 19:49:07 +0000 2018
# Tweet collected at Wed Aug 15 19:49:08 +0000 2018
# Tweet collected at Wed Aug 15 19:49:08 +0000 2018
# Tweet collected at Wed Aug 15 19:49:08 +0000 2018
# Tweet collected at Wed Aug 15 19:49:08 +0000 2018
# Tweet collected at Wed Aug 15 19:49:09 +0000 2018
# Tweet collected at Wed Aug 15 19:49:09 +0000 2018
# Tweet collected at Wed Aug 15 19:49:09 +0000 2018
# Tweet collected at Wed Aug 15 19:49:10 +0000 2018
# ...
# Tweet collected at Wed Aug 15 20:01:47 +0000 2018
# Tweet collected at Wed Aug 15 20:01:49 +0000 2018
# Tweet collected at Wed Aug 15 20:01:50 +0000 2018
# Tweet collected at Wed Aug 15 20:01:51 +0000 2018
# Tweet collected at Wed Aug 15 20:01:52 +0000 2018
# Tweet collected at Wed Aug 15 20:01:54 +0000 2018
# Tweet collected at Wed Aug 15 20:01:56 +0000 2018
# Tweet collected at Wed Aug 15 20:01:59 +0000 2018
# Tweet collected at Wed Aug 15 20:01:59 +0000 2018
# Tweet collected at Wed Aug 15 20:01:59 +0000 2018
# Tweet collected at Wed Aug 15 20:02:00 +0000 2018
# Tweet collected at Wed Aug 15 20:02:00 +0000 2018
# Tweet collected at Wed Aug 15 20:02:01 +0000 2018
# Tweet collected at Wed Aug 15 20:02:01 +0000 2018
# Tweet collected at Wed Aug 15 20:02:02 +0000 2018
# Tweet collected at Wed Aug 15 20:02:03 +0000 2018
# Tweet collected at Wed Aug 15 20:02:05 +0000 2018
# Tweet collected at Wed Aug 15 20:02:05 +0000 2018
# Tweet collected at Wed Aug 15 20:02:05 +0000 2018
# Tweet collected at Wed Aug 15 20:02:05 +0000 2018
# Tweet collected at Wed Aug 15 20:02:08 +0000 2018
# Tweet collected at Wed Aug 15 20:02:08 +0000 2018
# Tweet collected at Wed Aug 15 20:02:09 +0000 2018
# Tweet collected at Wed Aug 15 20:02:10 +0000 2018
# Tweet collected at Wed Aug 15 20:02:11 +0000 2018
# Tweet collected at Wed Aug 15 20:02:12 +0000 2018
# Tweet collected at Wed Aug 15 20:02:10 +0000 2018
# Tweet collected at Wed Aug 15 20:02:12 +0000 2018
# Tweet collected at Wed Aug 15 20:02:13 +0000 2018
# Tweet collected at Wed Aug 15 20:02:15 +0000 2018
# Tweet collected at Wed Aug 15 20:02:16 +0000 2018
# Tweet collected at Wed Aug 15 20:02:18 +0000 2018
# Tweet collected at Wed Aug 15 20:02:19 +0000 2018
# Tweet collected at Wed Aug 15 20:02:20 +0000 2018
# Tweet collected at Wed Aug 15 20:02:22 +0000 2018
# Tweet collected at Wed Aug 15 20:02:23 +0000 2018
# Tweet collected at Wed Aug 15 20:02:25 +0000 2018
# Tweet collected at Wed Aug 15 20:02:25 +0000 2018
# Tweet collected at Wed Aug 15 20:02:27 +0000 2018
# Tweet collected at Wed Aug 15 20:02:28 +0000 2018
# Tweet collected at Wed Aug 15 20:02:30 +0000 2018
# Tweet collected at Wed Aug 15 20:02:33 +0000 2018
# Tweet collected at Wed Aug 15 20:02:33 +0000 2018
# Tweet collected at Wed Aug 15 20:02:34 +0000 2018
# Tweet collected at Wed Aug 15 20:02:36 +0000 2018
# Tweet collected at Wed Aug 15 20:02:38 +0000 2018
# Tweet collected at Wed Aug 15 20:02:40 +0000 2018
# Tweet collected at Wed Aug 15 20:02:41 +0000 2018
# Tweet collected at Wed Aug 15 20:02:43 +0000 2018
# Tweet collected at Wed Aug 15 20:02:44 +0000 2018
# Tweet collected at Wed Aug 15 20:02:43 +0000 2018
# Tweet collected at Wed Aug 15 20:02:44 +0000 2018
# Tweet collected at Wed Aug 15 20:02:45 +0000 2018
# Tweet collected at Wed Aug 15 20:02:48 +0000 2018
# Tweet collected at Wed Aug 15 20:02:50 +0000 2018
# Tweet collected at Wed Aug 15 20:02:50 +0000 2018
# Tweet collected at Wed Aug 15 20:02:51 +0000 2018
# Tweet collected at Wed Aug 15 20:02:52 +0000 2018
# Tweet collected at Wed Aug 15 20:02:53 +0000 2018
# Tweet collected at Wed Aug 15 20:02:56 +0000 2018
# Tweet collected at Wed Aug 15 20:02:57 +0000 2018
# Tweet collected at Wed Aug 15 20:02:57 +0000 2018
# Tweet collected at Wed Aug 15 20:02:59 +0000 2018
# Tweet collected at Wed Aug 15 20:03:00 +0000 2018
# Tweet collected at Wed Aug 15 20:03:02 +0000 2018
# Tweet collected at Wed Aug 15 20:03:02 +0000 2018
# Tweet collected at Wed Aug 15 20:03:02 +0000 2018
# Tweet collected at Wed Aug 15 20:03:02 +0000 2018
# Tweet collected at Wed Aug 15 20:03:04 +0000 2018
# Tweet collected at Wed Aug 15 20:03:04 +0000 2018
# Tweet collected at Wed Aug 15 20:03:04 +0000 2018
# Tweet collected at Wed Aug 15 20:03:05 +0000 2018
# Tweet collected at Wed Aug 15 20:03:05 +0000 2018
# Tweet collected at Wed Aug 15 20:03:05 +0000 2018
# Tweet collected at Wed Aug 15 20:03:08 +0000 2018
# Tweet collected at Wed Aug 15 20:03:08 +0000 2018
# Tweet collected at Wed Aug 15 20:03:09 +0000 2018
# Tweet collected at Wed Aug 15 20:03:10 +0000 2018
# Tweet collected at Wed Aug 15 20:03:10 +0000 2018
# Tweet collected at Wed Aug 15 20:03:11 +0000 2018
# Tweet collected at Wed Aug 15 20:03:11 +0000 2018
# Tweet collected at Wed Aug 15 20:03:12 +0000 2018
# Tweet collected at Wed Aug 15 20:03:13 +0000 2018
# Tweet collected at Wed Aug 15 20:03:13 +0000 2018
# Tweet collected at Wed Aug 15 20:03:13 +0000 2018
# Tweet collected at Wed Aug 15 20:03:14 +0000 2018
# Tweet collected at Wed Aug 15 20:03:15 +0000 2018
# Tweet collected at Wed Aug 15 20:03:15 +0000 2018
# Tweet collected at Wed Aug 15 20:03:19 +0000 2018
# Tweet collected at Wed Aug 15 20:03:20 +0000 2018
# Tweet collected at Wed Aug 15 20:03:23 +0000 2018
# Tweet collected at Wed Aug 15 20:03:23 +0000 2018
# Tweet collected at Wed Aug 15 20:03:24 +0000 2018
# Tweet collected at Wed Aug 15 20:03:25 +0000 2018
# Tweet collected at Wed Aug 15 20:03:34 +0000 2018
# Tweet collected at Wed Aug 15 20:03:34 +0000 2018
# Tweet collected at Wed Aug 15 20:03:34 +0000 2018
# Tweet collected at Wed Aug 15 20:03:35 +0000 2018
# Tweet collected at Wed Aug 15 20:03:36 +0000 2018
# Tweet collected at Wed Aug 15 20:03:36 +0000 2018
# Tweet collected at Wed Aug 15 20:03:37 +0000 2018
# Tweet collected at Wed Aug 15 20:03:38 +0000 2018
# Tweet collected at Wed Aug 15 20:03:39 +0000 2018
# Tweet collected at Wed Aug 15 20:03:40 +0000 2018
# Tweet collected at Wed Aug 15 20:03:41 +0000 2018
# Tweet collected at Wed Aug 15 20:03:44 +0000 2018
# Tweet collected at Wed Aug 15 20:03:45 +0000 2018
# Tweet collected at Wed Aug 15 20:03:47 +0000 2018
# Tweet collected at Wed Aug 15 20:03:49 +0000 2018
# Tweet collected at Wed Aug 15 20:03:49 +0000 2018
# Tweet collected at Wed Aug 15 20:03:49 +0000 2018
# Tweet collected at Wed Aug 15 20:03:50 +0000 2018
# Tweet collected at Wed Aug 15 20:03:50 +0000 2018
# Tweet collected at Wed Aug 15 20:03:51 +0000 2018
# Tweet collected at Wed Aug 15 20:03:54 +0000 2018
# Tweet collected at Wed Aug 15 20:03:55 +0000 2018
# Tweet collected at Wed Aug 15 20:03:59 +0000 2018
# Tweet collected at Wed Aug 15 20:04:00 +0000 2018
# Tweet collected at Wed Aug 15 20:04:01 +0000 2018
# Tweet collected at Wed Aug 15 20:04:02 +0000 2018
# Tweet collected at Wed Aug 15 20:04:02 +0000 2018
# Tweet collected at Wed Aug 15 20:04:02 +0000 2018
# Tweet collected at Wed Aug 15 20:04:02 +0000 2018
# Tweet collected at Wed Aug 15 20:04:04 +0000 2018
# Tweet collected at Wed Aug 15 20:04:05 +0000 2018
# Tweet collected at Wed Aug 15 20:04:06 +0000 2018
# Tweet collected at Wed Aug 15 20:04:07 +0000 2018
# Tweet collected at Wed Aug 15 20:04:09 +0000 2018
# Tweet collected at Wed Aug 15 20:04:09 +0000 2018
# Tweet collected at Wed Aug 15 20:04:12 +0000 2018
# Tweet collected at Wed Aug 15 20:04:12 +0000 2018
# Tweet collected at Wed Aug 15 20:04:13 +0000 2018
# Tweet collected at Wed Aug 15 20:04:12 +0000 2018
# Tweet collected at Wed Aug 15 20:04:14 +0000 2018
# Tweet collected at Wed Aug 15 20:04:14 +0000 2018
# Tweet collected at Wed Aug 15 20:04:15 +0000 2018
# Tweet collected at Wed Aug 15 20:04:16 +0000 2018
# Tweet collected at Wed Aug 15 20:04:17 +0000 2018
# Tweet collected at Wed Aug 15 20:04:18 +0000 2018
# Tweet collected at Wed Aug 15 20:04:19 +0000 2018
# Tweet collected at Wed Aug 15 20:04:21 +0000 2018
# Tweet collected at Wed Aug 15 20:04:21 +0000 2018
# Tweet collected at Wed Aug 15 20:04:23 +0000 2018
# Tweet collected at Wed Aug 15 20:04:23 +0000 2018
# Tweet collected at Wed Aug 15 20:04:23 +0000 2018
# Tweet collected at Wed Aug 15 20:04:27 +0000 2018
# Tweet collected at Wed Aug 15 20:04:29 +0000 2018
# Tweet collected at Wed Aug 15 20:04:30 +0000 2018
# Tweet collected at Wed Aug 15 20:04:31 +0000 2018
# Tweet collected at Wed Aug 15 20:04:38 +0000 2018
# Tweet collected at Wed Aug 15 20:04:41 +0000 2018
# Tweet collected at Wed Aug 15 20:04:41 +0000 2018
# Tweet collected at Wed Aug 15 20:04:43 +0000 2018
# Tweet collected at Wed Aug 15 20:04:44 +0000 2018
# Tweet collected at Wed Aug 15 20:04:44 +0000 2018
# Tweet collected at Wed Aug 15 20:04:46 +0000 2018
# Tweet collected at Wed Aug 15 20:04:46 +0000 2018
# Tweet collected at Wed Aug 15 20:04:46 +0000 2018
# Tweet collected at Wed Aug 15 20:04:48 +0000 2018
# Tweet collected at Wed Aug 15 20:04:50 +0000 2018
# Tweet collected at Wed Aug 15 20:04:51 +0000 2018
# Tweet collected at Wed Aug 15 20:04:52 +0000 2018
# Tweet collected at Wed Aug 15 20:04:52 +0000 2018
# Tweet collected at Wed Aug 15 20:04:53 +0000 2018
# Tweet collected at Wed Aug 15 20:04:53 +0000 2018
# Tweet collected at Wed Aug 15 20:04:55 +0000 2018
# Tweet collected at Wed Aug 15 20:05:00 +0000 2018
# Tweet collected at Wed Aug 15 20:05:01 +0000 2018
# Tweet collected at Wed Aug 15 20:05:01 +0000 2018
# Tweet collected at Wed Aug 15 20:05:01 +0000 2018
# Tweet collected at Wed Aug 15 20:05:04 +0000 2018
# Tweet collected at Wed Aug 15 20:05:05 +0000 2018
# Tweet collected at Wed Aug 15 20:05:06 +0000 2018
# Tweet collected at Wed Aug 15 20:05:07 +0000 2018
# Tweet collected at Wed Aug 15 20:05:07 +0000 2018
# Tweet collected at Wed Aug 15 20:05:07 +0000 2018
# Tweet collected at Wed Aug 15 20:05:07 +0000 2018
# Tweet collected at Wed Aug 15 20:05:08 +0000 2018
# Tweet collected at Wed Aug 15 20:05:08 +0000 2018
# Tweet collected at Wed Aug 15 20:05:08 +0000 2018
# Tweet collected at Wed Aug 15 20:05:08 +0000 2018
# Tweet collected at Wed Aug 15 20:05:09 +0000 2018
# Tweet collected at Wed Aug 15 20:05:10 +0000 2018
# Tweet collected at Wed Aug 15 20:05:11 +0000 2018
# Tweet collected at Wed Aug 15 20:05:11 +0000 2018
# Tweet collected at Wed Aug 15 20:05:11 +0000 2018
# Tweet collected at Wed Aug 15 20:05:11 +0000 2018
# Tweet collected at Wed Aug 15 20:05:12 +0000 2018
# Tweet collected at Wed Aug 15 20:05:12 +0000 2018
# Tweet collected at Wed Aug 15 20:05:13 +0000 2018
# Tweet collected at Wed Aug 15 20:05:15 +0000 2018
# Tweet collected at Wed Aug 15 20:05:15 +0000 2018
# Tweet collected at Wed Aug 15 20:05:16 +0000 2018
# Tweet collected at Wed Aug 15 20:05:22 +0000 2018
# Tweet collected at Wed Aug 15 20:05:23 +0000 2018
# Tweet collected at Wed Aug 15 20:05:24 +0000 2018
# Tweet collected at Wed Aug 15 20:05:24 +0000 2018
# Tweet collected at Wed Aug 15 20:05:24 +0000 2018
# Tweet collected at Wed Aug 15 20:05:25 +0000 2018
# Tweet collected at Wed Aug 15 20:05:25 +0000 2018
# Tweet collected at Wed Aug 15 20:05:27 +0000 2018
# Tweet collected at Wed Aug 15 20:05:28 +0000 2018
# Tweet collected at Wed Aug 15 20:05:30 +0000 2018
# Tweet collected at Wed Aug 15 20:05:31 +0000 2018
# Tweet collected at Wed Aug 15 20:05:35 +0000 2018
# Tweet collected at Wed Aug 15 20:05:35 +0000 2018
# Tweet collected at Wed Aug 15 20:05:37 +0000 2018
# Tweet collected at Wed Aug 15 20:05:38 +0000 2018
# Tweet collected at Wed Aug 15 20:05:38 +0000 2018
# Tweet collected at Wed Aug 15 20:05:38 +0000 2018
# Tweet collected at Wed Aug 15 20:05:41 +0000 2018
# Tweet collected at Wed Aug 15 20:05:42 +0000 2018
# Tweet collected at Wed Aug 15 20:05:45 +0000 2018
# Tweet collected at Wed Aug 15 20:05:46 +0000 2018
# Tweet collected at Wed Aug 15 20:05:48 +0000 2018
# Tweet collected at Wed Aug 15 20:05:48 +0000 2018
# Tweet collected at Wed Aug 15 20:05:50 +0000 2018
# Tweet collected at Wed Aug 15 20:05:51 +0000 2018
# Tweet collected at Wed Aug 15 20:05:53 +0000 2018
# Tweet collected at Wed Aug 15 20:05:55 +0000 2018
# Tweet collected at Wed Aug 15 20:06:01 +0000 2018
# Tweet collected at Wed Aug 15 20:06:02 +0000 2018
# Tweet collected at Wed Aug 15 20:06:03 +0000 2018
# Tweet collected at Wed Aug 15 20:06:04 +0000 2018
# Tweet collected at Wed Aug 15 20:06:04 +0000 2018
# Tweet collected at Wed Aug 15 20:06:02 +0000 2018
# Tweet collected at Wed Aug 15 20:06:09 +0000 2018
# Tweet collected at Wed Aug 15 20:06:09 +0000 2018
# Tweet collected at Wed Aug 15 20:06:10 +0000 2018
# Tweet collected at Wed Aug 15 20:06:12 +0000 2018
# Tweet collected at Wed Aug 15 20:06:16 +0000 2018
# Tweet collected at Wed Aug 15 20:06:17 +0000 2018
# Tweet collected at Wed Aug 15 20:06:17 +0000 2018
# Tweet collected at Wed Aug 15 20:06:17 +0000 2018
# Tweet collected at Wed Aug 15 20:06:20 +0000 2018
# Tweet collected at Wed Aug 15 20:06:22 +0000 2018
# Tweet collected at Wed Aug 15 20:06:23 +0000 2018
# Tweet collected at Wed Aug 15 20:06:30 +0000 2018
# Tweet collected at Wed Aug 15 20:06:32 +0000 2018
# Tweet collected at Wed Aug 15 20:06:33 +0000 2018
# Tweet collected at Wed Aug 15 20:06:34 +0000 2018
# Tweet collected at Wed Aug 15 20:06:35 +0000 2018
# Tweet collected at Wed Aug 15 20:06:39 +0000 2018
# Tweet collected at Wed Aug 15 20:06:40 +0000 2018
# Tweet collected at Wed Aug 15 20:06:41 +0000 2018
# Tweet collected at Wed Aug 15 20:06:42 +0000 2018
# Tweet collected at Wed Aug 15 20:06:42 +0000 2018
# Tweet collected at Wed Aug 15 20:06:44 +0000 2018
# Tweet collected at Wed Aug 15 20:06:48 +0000 2018
# Tweet collected at Wed Aug 15 20:06:49 +0000 2018
# Tweet collected at Wed Aug 15 20:06:50 +0000 2018
# Tweet collected at Wed Aug 15 20:06:52 +0000 2018
# Tweet collected at Wed Aug 15 20:06:52 +0000 2018
# Tweet collected at Wed Aug 15 20:06:52 +0000 2018
# Tweet collected at Wed Aug 15 20:06:53 +0000 2018
# Tweet collected at Wed Aug 15 20:06:54 +0000 2018
# Tweet collected at Wed Aug 15 20:06:54 +0000 2018
# Tweet collected at Wed Aug 15 20:06:56 +0000 2018
# Tweet collected at Wed Aug 15 20:06:58 +0000 2018
# Tweet collected at Wed Aug 15 20:07:02 +0000 2018
# Tweet collected at Wed Aug 15 20:07:02 +0000 2018
# Tweet collected at Wed Aug 15 20:07:03 +0000 2018
# Tweet collected at Wed Aug 15 20:07:03 +0000 2018
# Tweet collected at Wed Aug 15 20:07:05 +0000 2018
# Tweet collected at Wed Aug 15 20:07:06 +0000 2018
# Tweet collected at Wed Aug 15 20:07:06 +0000 2018
# Tweet collected at Wed Aug 15 20:07:07 +0000 2018
# Tweet collected at Wed Aug 15 20:07:07 +0000 2018
# Tweet collected at Wed Aug 15 20:07:08 +0000 2018
# Tweet collected at Wed Aug 15 20:07:09 +0000 2018
# Tweet collected at Wed Aug 15 20:07:10 +0000 2018
# Tweet collected at Wed Aug 15 20:07:10 +0000 2018
# Tweet collected at Wed Aug 15 20:07:11 +0000 2018
# Tweet collected at Wed Aug 15 20:07:12 +0000 2018
# Tweet collected at Wed Aug 15 20:07:14 +0000 2018
# Tweet collected at Wed Aug 15 20:07:18 +0000 2018
# Tweet collected at Wed Aug 15 20:07:18 +0000 2018
# Tweet collected at Wed Aug 15 20:07:20 +0000 2018
# Tweet collected at Wed Aug 15 20:07:23 +0000 2018
# Tweet collected at Wed Aug 15 20:07:23 +0000 2018
# Tweet collected at Wed Aug 15 20:07:23 +0000 2018
# Tweet collected at Wed Aug 15 20:07:25 +0000 2018
# Tweet collected at Wed Aug 15 20:07:26 +0000 2018
# Tweet collected at Wed Aug 15 20:07:28 +0000 2018
# Tweet collected at Wed Aug 15 20:07:30 +0000 2018
# Tweet collected at Wed Aug 15 20:07:32 +0000 2018
# Tweet collected at Wed Aug 15 20:07:33 +0000 2018
# Tweet collected at Wed Aug 15 20:07:33 +0000 2018
# Tweet collected at Wed Aug 15 20:07:33 +0000 2018
# Tweet collected at Wed Aug 15 20:07:35 +0000 2018
# Tweet collected at Wed Aug 15 20:07:35 +0000 2018
# Tweet collected at Wed Aug 15 20:07:39 +0000 2018
# Tweet collected at Wed Aug 15 20:07:40 +0000 2018
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-17600ade7044> in <module>()
#      56 streamer = tweepy.Stream(auth=auth, listener=listener)
#      57 print("Tracking: " + str(WORDS))
# ---> 58 streamer.filter(track=WORDS)
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding)
#     426         self.session.params = {'delimited': 'length'}
#     427         self.host = 'stream.twitter.com'
# --> 428         self._start(async)
#     429
#     430     def sitestream(self, follow, stall_warnings=False,
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     344             self._thread.start()
#     345         else:
# --> 346             self._run()
#     347
#     348     def on_closed(self, resp):
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in _run(self)
#     284             # call a handler first so that the exception can be logged.
#     285             self.listener.on_exception(exception)
# --> 286             raise
#     287
#     288     def _data(self, data):
#
# RuntimeError: No active exception to reraise
