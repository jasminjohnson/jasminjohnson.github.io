# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)

# %%
from __future__ import print_function
import tweepy
import json
from pymongo import MongoClient
 
MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'
 
WORDS = ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
 
CONSUMER_KEY = "8hXSibjBqguYXf4vVNDliDCOY"
CONSUMER_SECRET = "fUwZ4PJbK8wwaTpF5uEz6xniac9P5ACzXIMsk7pCSAiUHjViJA"
ACCESS_TOKEN = "2994396687-mpkDqjV6xQzfhtqvDncWy2JjAiORScTtbOOwRqD"
ACCESS_TOKEN_SECRET = "bfqOVgKhkW9r9fiRFNIGNp70Wottrc3E5zoBNCi7xthtQ"

# %% [markdown]
# ## MongoDB Example - reinsurance loss data analysis , JSON BLOB and read Twitter

# %% [markdown]
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# MongoDB is a document-oriented database. Instead of storing your data in tables made out of individual rows,
# like a relational database does, it stores your data in collections made out of individual documents.
# In MongoDB, a document is a big JSON blob with no particular format or schema.
#
# You can have all your data in one single collection.
#
# <!-- PELICAN_END_SUMMARY -->

# %%
**MongoDB Example**
- Create a document styple data in MongoDB
  - example: reinsurance treaty by reinsurer/year/treaty type        
- Create a document style data in MongoDB from Json API format
  - example: population by country, state, county and townships        
- Read Twitter data into MongoDB  
  - example : read twitter page about what type of insurance people are interesting buying
- Retrieve results from MongoDB into Excel for data analysis
- how to use BSON-NumPy to pull data out of Mongo and into pandas

# %% [markdown]
# **Making a Connection with MongoClient**
# -  Below link is an introduction tutorial to working with MongoDB and PyMongo
# -  ref: http://api.mongodb.com/python/current/tutorial.html

# %%
# Making a Connection with MongoClient
# Import pymongo
import pymongo

# The first step when working with PyMongo is to create a MongoClient to the running mongod instance
from pymongo import MongoClient

# Connect on the default host and port.
client = MongoClient()

# We can also specify the host and port explicitly
client = MongoClient('localhost', 27017)

# %% [markdown]
# **Getting a Database**
# - A single instance of MongoDB can support multiple independent databases.
# - When working with PyMongo you access databases using attribute style access on MongoClient instances.
# - Database name can not use attribute style access (ie. test-data), but "test_data" is okay

# %%
# Set up a collection name "test_database" in MongoDB
db = client.test_database

collection = db.test_collection

collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test_database'), 'test_collection')

# %% [markdown]
# #### **Document - example: reinsurance treaty by reinsurer/year/treaty type**
# - Data in MongoDB is represented (and stored) using JSON-style documents.
# - In PyMongo we use dictionaries to represent documents.
# - As an example, the following dictionary might be used to represent a reinsurance treaty type by reinsurer and year.
# - Documents can contain native Python types (like datetime.datetime instances) which will be automatically converted to and from the appropriate BSON types.

# %%
import datetime
treaty = {"reinsurer": "AIG",
        "treaty": "XOL layer",
        "tags": ["reinsurer", "treaty", "year"],
        "date": datetime.datetime.utcnow()}

# %% [markdown]
# #### *Inserting a Document*
# - When a document is inserted a special key, "_id", is automatically added if the document doesn’t already contain an "_id" key.
# - The value of "_id" must be unique across the collection. insert_one() returns an instance of InsertOneResult.

# %%
# To insert a document into a collection we can use the insert_one() method:
treaties = db.treaties
treaty_id = treaties.insert_one(treaty).inserted_id
treaty_id
# Out:
# ObjectId('5b7ed794760df705188fc61f')

# %% [markdown]
# **After inserting the first document, the posts collection has actually been created on the server.**
# - We can verify this by listing all of the collections in our database:

# %%
db.list_collection_names()
# Out:
# ['census', 'stock_data', 'treaties']

# %%
treaty2 = {"reinsurer": "Swiss Re",
        "treaty": "Clash Layer",
        "tags": ["reinsurer", "treaty", "year"],
        "date": datetime.datetime.utcnow()}

treaty_id = treaties.insert_one(treaty2).inserted_id
treaty_id
# Out:
# ObjectId('5b7ed797760df705188fc620')

# %%
treaty3 = {"reinsurer": "Parter Re",
        "treaty": "XOL 2nd Layer",
        "tags": ["reinsurer", "treaty", "year"],
        "date": datetime.datetime.utcnow()}

treaty_id = treaties.insert_one(treaty3).inserted_id
treaty_id
# Out:
# ObjectId('5b7ed79a760df705188fc621')

# %% [markdown]
# #### * Getting a Single Document With find_one()*
# - The most basic type of query that can be performed in MongoDB is find_one().
# - This method returns a single document matching a query (or None if there are no matches).
# - It is useful when you know there is only one matching document, or
# - are only interested in the first match. Here we use find_one() to get the first document from the posts collection:

# %%
import pprint
pprint.pprint(treaties.find_one())
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}

# %%
pprint.pprint(treaties.find_one({"reinsurer": "AIG"}))
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}

# %%
pprint.pprint(treaties.find_one({"reinsurer": "ACE"}))
# Out:
# None

# %% [markdown]
# #### * Querying By ObjectId*
# - We can also find a post by its _id, which in our example is an ObjectId:

# %%
treaty_id  ##output is an object
# Out:
# ObjectId('5b7ed79a760df705188fc621')

# %%
pprint.pprint(treaties.find_one({"_id": treaty_id}))
# Out:
# {'_id': ObjectId('5b7ed79a760df705188fc621'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 46, 797000),
#  'reinsurer': 'Parter Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL 2nd Layer'}

# %% [markdown]
# #### * Note that an ObjectId is not the same as its string representation:*

# %%
treaty_id_as_str = str(treaty_id)
treaty_id_as_str  ## output is a string
# Out:
# '5b7ed79a760df705188fc621'

# %%
treaties.find_one({"_id": treaty_id_as_str}) # No result

# %% [markdown]
# **Bulk Inserts**
# - we can also perform bulk insert operations, by passing a list as the first argument to insert_many().
# - This will insert each document in the list, sending only a single command to the server.
# - New_treaty has a different “shape” than the other posts - there is no "tags" field and we’ve added a new field, "title".
# - This is what we mean when we say that MongoDB is schema-free.

# %%
# new_treaty has a different “shape” than the other posts 
# there is no "tags" field and we’ve added a new field, "retenion". 

new_treaty = [{"reinsurer": "AIG",
              "treaty": "XOL Layer 2018",
              "tags": ["bulk", "insert"],
              "date": datetime.datetime(2018, 11, 12, 11, 14)},
              {"reinsurer": "Munich Re",
               "treaty": "QS 2018",
               "retenion": "QS 20% for US business",
               "date": datetime.datetime(2018, 11, 10, 10, 45)}]

result = treaties.insert_many(new_treaty)
result.inserted_ids
# Out:
# [ObjectId('5b7ed7ad760df705188fc622'), ObjectId('5b7ed7ad760df705188fc623')]

# %% [markdown]
# *The result from insert_many() now returns two ObjectId instances, one for each inserted document.*

# %% [markdown]
# **Query data**
# - use find()
# - use find_one()

# %%
for treaty in treaties.find():
     pprint.pprint(treaty)
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7ed797760df705188fc620'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 43, 818000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b7ed79a760df705188fc621'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 46, 797000),
#  'reinsurer': 'Parter Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL 2nd Layer'}
# {'_id': ObjectId('5b7ed7ad760df705188fc622'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b7ed7ad760df705188fc623'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}

# %%
# Use find() for query

# Find all treaty in the collection
# for treaty in treaties.find():
#      pprint.pprint(treaty)

# Find all reinsurer-AIG treaty:
for treaty in treaties.find({"reinsurer": "AIG"}):
    pprint.pprint(treaty)
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7ed7ad760df705188fc622'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}

# %%
# Find one reinsurer-AIG treaty:
pprint.pprint(treaties.find_one({"reinsurer": "AIG"}))
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}

# %% [markdown]
# #### * Counting*
# - If we just want to know how many documents match a query we can perform a count() operation instead of a full query.
# - We can get a count of all of the documents in a collection:

# %%
# How many AIG treaty?
treaties.count_documents(
  filter={"reinsurer": "AIG"} 
)


# How many treaties?
treaties.count_documents(
  filter={} 
)
# Out:
# 2
# 5

# %% [markdown]
# ** Range Queries**
# - MongoDB supports many different types of advanced queries.
# - As an example, lets perform a query where we limit results to treaties older than a certain date, but also sort the results by reinsurers

# %%
d = datetime.datetime(2018, 11, 12, 12)
for treaty in treaties.find({"date": {"$lt": d}}).sort("reinsurer"):
    pprint.pprint(treaty)
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7ed7ad760df705188fc622'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b7ed7ad760df705188fc623'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b7ed79a760df705188fc621'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 46, 797000),
#  'reinsurer': 'Parter Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL 2nd Layer'}
# {'_id': ObjectId('5b7ed797760df705188fc620'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 43, 818000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'Clash Layer'}

# %% [markdown]
# #### * Indexing*
# - Adding indexes can help accelerate certain queries and can also add additional functionality to querying and storing documents.
# - In this example, we’ll demonstrate how to create a unique index on a key that rejects documents whose value for that key already exists in the index.
# - First, we’ll need to create the index:

# %%
 result = db.profiles.create_index([('reinsurer_id', pymongo.ASCENDING)],
                                  unique=True)
 sorted(list(db.profiles.index_information()))
# Out:
# ['_id_', 'reinsurer_id_1']

# %% [markdown]
# **Notice that we have two indexes now**
# - one is the index on _id that MongoDB creates automatically,
# - and the other is the index on reinsurer_id we just created.

# %%
 # set up some user profiles
    
 user_profiles = [
     {'reinsurer_id': 228, 'reinsurer': 'Atlantic Re'},
     {'reinsurer_id': 235, 'reinsurer': 'XL Re'}]
 result = db.profiles.insert_many(user_profiles)

# %%
 # DuplicateKeyError: E11000 duplicate key error collection: test_database.profiles index: user_id_1 dup key: { : 235 }
 new_profile = {'user_id': 213, 'reinsurer': 'XL American'}
 duplicate_profile = {'user_id': 235, 'reinsurer': 'SCOR S.E'}
 result = db.profiles.insert_one(new_profile)  # This is fine.
 result = db.profiles.insert_one(duplicate_profile)

# %% [markdown]
# **Create a document style data in MongoDB from Json API format**
# - example: realtime intraday MSFT stock price
# - example: realtime sector stock return

# %%
realtime_stock_data={
"Meta Data": {
"1 Information": "Intraday (5min) open, high, low, close prices and volume",
"2 Symbol": "MSFT",
"3 Last Refreshed": "2018-08-22 15:55:00",
"4 Interval": "5min",
"5 Output Size": "Compact",
"6 Time Zone": "US/Eastern"
},
"Time Series (5min)": {
"2018-08-22 15:55:00": {
"1 open": "107.1500",
"2 high": "107.2100",
"3 low": "107.0500",
"4 close": "107.0500",
"5 volume": "970838"
}
}
}

# %%
stock_data = db.stock_data
stock_data_id = stock_data.insert_one(realtime_stock_data).inserted_id
stock_data_id
# Out:
# ObjectId('5b7efb1e760df705188fdd1a')

# %%
realtime_sector_data={
    "Meta Data": {
        "Information": "US Sector Performance (realtime & historical)",
        "Last Refreshed": "02:05 PM ET 08/23/2018"
    },
    "Rank A: Real-Time Performance": {
        "Information Technology": "0.51%",
        "Consumer Discretionary": "-0.04%",
        "Utilities": "-0.11%",
        "Telecommunication Services": "-0.13%",
        "Health Care": "-0.20%",
        "Real Estate": "-0.25%",
        "Consumer Staples": "-0.27%",
        "Industrials": "-0.48%",
        "Financials": "-0.54%",
        "Energy": "-0.57%",
        "Materials": "-0.86%"
    },
    "Rank B: 1 Day Performance": {
        "Energy": "1.20%",
        "Information Technology": "0.48%",
        "Consumer Discretionary": "0.12%",
        "Health Care": "0.11%",
        "Financials": "-0.26%",
        "Materials": "-0.45%",
        "Consumer Staples": "-0.63%",
        "Real Estate": "-0.65%",
        "Utilities": "-0.78%",
        "Industrials": "-0.93%",
        "Telecommunication Services": "-2.02%"
    },
    "Rank C: 5 Day Performance": {
        "Energy": "3.27%",
        "Industrials": "2.23%",
        "Consumer Discretionary": "2.21%",
        "Materials": "2.02%",
        "Financials": "1.93%",
        "Health Care": "1.71%",
        "Telecommunication Services": "1.09%",
        "Information Technology": "0.84%",
        "Consumer Staples": "0.76%",
        "Real Estate": "0.16%",
        "Utilities": "-0.35%"
    },
    "Rank D: 1 Month Performance": {
        "Telecommunication Services": "6.53%",
        "Health Care": "5.38%",
        "Industrials": "2.75%",
        "Real Estate": "2.62%",
        "Consumer Staples": "2.57%",
        "Financials": "2.45%",
        "Utilities": "1.92%",
        "Consumer Discretionary": "1.90%",
        "Materials": "0.90%",
        "Information Technology": "0.57%",
        "Energy": "-1.17%"
    },
    "Rank E: 3 Month Performance": {
        "Health Care": "9.80%",
        "Consumer Staples": "9.18%",
        "Utilities": "8.72%",
        "Consumer Discretionary": "8.41%",
        "Real Estate": "8.28%",
        "Telecommunication Services": "6.02%",
        "Information Technology": "5.55%",
        "Financials": "0.49%",
        "Industrials": "0.15%",
        "Materials": "-2.15%",
        "Energy": "-5.60%"
    },
    "Rank F: Year-to-Date (YTD) Performance": {
        "Information Technology": "16.10%",
        "Consumer Discretionary": "15.79%",
        "Health Care": "10.55%",
        "Energy": "2.53%",
        "Financials": "1.05%",
        "Utilities": "1.04%",
        "Real Estate": "0.96%",
        "Industrials": "0.75%",
        "Materials": "-2.75%",
        "Consumer Staples": "-5.33%",
        "Telecommunication Services": "-6.21%"
    },
    "Rank G: 1 Year Performance": {
        "Information Technology": "31.09%",
        "Consumer Discretionary": "29.36%",
        "Energy": "20.32%",
        "Health Care": "16.84%",
        "Financials": "15.29%",
        "Industrials": "12.18%",
        "Materials": "9.50%",
        "Real Estate": "3.09%",
        "Telecommunication Services": "-0.85%",
        "Utilities": "-2.24%",
        "Consumer Staples": "-2.32%"
    },
    "Rank H: 3 Year Performance": {
        "Information Technology": "95.67%",
        "Consumer Discretionary": "54.45%",
        "Financials": "46.80%",
        "Industrials": "45.21%",
        "Materials": "36.15%",
        "Health Care": "27.81%",
        "Utilities": "18.65%",
        "Energy": "18.31%",
        "Consumer Staples": "13.63%",
        "Telecommunication Services": "5.73%"
    },
    "Rank I: 5 Year Performance": {
        "Information Technology": "151.29%",
        "Consumer Discretionary": "98.24%",
        "Health Care": "85.23%",
        "Financials": "75.87%",
        "Industrials": "67.23%",
        "Materials": "45.10%",
        "Utilities": "43.92%",
        "Consumer Staples": "35.93%",
        "Telecommunication Services": "4.47%",
        "Energy": "-6.33%"
    },
    "Rank J: 10 Year Performance": {
        "Consumer Discretionary": "284.77%",
        "Information Technology": "252.24%",
        "Health Care": "176.38%",
        "Industrials": "107.68%",
        "Consumer Staples": "90.16%",
        "Financials": "74.45%",
        "Materials": "50.53%",
        "Utilities": "41.62%",
        "Telecommunication Services": "21.26%",
        "Energy": "-3.80%"
    }
}

# %%
sector_data = db.sector_data
sector_data_id = sector_data.insert_one(realtime_sector_data).inserted_id
sector_data_id
# Out:
# ObjectId('5b7efb26760df705188fdd1b')

# %% [markdown]
# **Below is the screenshot of MongoDB structures from GUI tool Robo 3T showing list of dataset**
# <img src="/images/MongoDB1.png" alt="[img: MongoDB view]" title="MongoDB View" />

# %% [markdown]
# **Collect data from Twitter into MongoDB**
# - ref:  http://pythondata.com/collecting-storing-tweets-with-python-and-mongodb/

# %%
from __future__ import print_function
import tweepy
import json
from pymongo import MongoClient
 
MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'
 
WORDS = ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
 
CONSUMER_KEY = "your key"
CONSUMER_SECRET = "your secret"
ACCESS_TOKEN = "your token"
ACCESS_TOKEN_SECRET = "your token secret"
 
 
class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 
 
    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
            client = MongoClient(MONGO_HOST)
            
            # Use twitterdb database. If it doesn't exist, it will be created.
            db = client.twitterdb
    
            # Decode the JSON from Twitter
            datajson = json.loads(data)
            
            #grab the 'created_at' data from the Tweet to use for display
            created_at = datajson['created_at']
 
            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(created_at))
            
            #insert the data into the mongoDB into a collection called twitter_search
            #if twitter_search doesn't exist, it will be created.
            db.twitter_search.insert(datajson)
        except Exception as e:
           print(e)
 
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)
# Out:
# Tracking: ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
# You are now connected to the streaming API.
# Tweet collected at Thu Aug 23 15:51:39 +0000 2018
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:48: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Tweet collected at Thu Aug 23 15:51:40 +0000 2018
# Tweet collected at Thu Aug 23 15:51:41 +0000 2018
# Tweet collected at Thu Aug 23 15:51:42 +0000 2018
# Tweet collected at Thu Aug 23 15:51:42 +0000 2018
# Tweet collected at Thu Aug 23 15:51:43 +0000 2018
# Tweet collected at Thu Aug 23 15:51:43 +0000 2018
# Tweet collected at Thu Aug 23 15:51:44 +0000 2018
# Tweet collected at Thu Aug 23 15:51:44 +0000 2018
# Tweet collected at Thu Aug 23 15:51:47 +0000 2018
# Tweet collected at Thu Aug 23 15:51:48 +0000 2018
# Tweet collected at Thu Aug 23 15:51:49 +0000 2018
# Tweet collected at Thu Aug 23 15:51:50 +0000 2018
# Tweet collected at Thu Aug 23 15:51:50 +0000 2018
# Tweet collected at Thu Aug 23 15:51:51 +0000 2018
# Tweet collected at Thu Aug 23 15:51:52 +0000 2018
# Tweet collected at Thu Aug 23 15:51:54 +0000 2018
# Tweet collected at Thu Aug 23 15:51:54 +0000 2018
# Tweet collected at Thu Aug 23 15:51:55 +0000 2018
# Tweet collected at Thu Aug 23 15:51:58 +0000 2018
# Tweet collected at Thu Aug 23 15:51:58 +0000 2018
# Tweet collected at Thu Aug 23 15:51:58 +0000 2018
# Tweet collected at Thu Aug 23 15:52:00 +0000 2018
# Tweet collected at Thu Aug 23 15:52:00 +0000 2018
# Tweet collected at Thu Aug 23 15:52:01 +0000 2018
# Tweet collected at Thu Aug 23 15:52:02 +0000 2018
# Tweet collected at Thu Aug 23 15:52:03 +0000 2018
# Tweet collected at Thu Aug 23 15:52:04 +0000 2018
# Tweet collected at Thu Aug 23 15:52:06 +0000 2018
# Tweet collected at Thu Aug 23 15:52:08 +0000 2018
# Tweet collected at Thu Aug 23 15:52:10 +0000 2018
# Tweet collected at Thu Aug 23 15:52:14 +0000 2018
# Tweet collected at Thu Aug 23 15:52:16 +0000 2018
# Tweet collected at Thu Aug 23 15:52:16 +0000 2018
# Tweet collected at Thu Aug 23 15:52:17 +0000 2018
# Tweet collected at Thu Aug 23 15:52:17 +0000 2018
# Tweet collected at Thu Aug 23 15:52:19 +0000 2018
# Tweet collected at Thu Aug 23 15:52:20 +0000 2018
# Tweet collected at Thu Aug 23 15:52:21 +0000 2018
# Tweet collected at Thu Aug 23 15:52:21 +0000 2018
# Tweet collected at Thu Aug 23 15:52:22 +0000 2018
# Tweet collected at Thu Aug 23 15:52:24 +0000 2018
# Tweet collected at Thu Aug 23 15:52:25 +0000 2018
# Tweet collected at Thu Aug 23 15:52:28 +0000 2018
# Tweet collected at Thu Aug 23 15:52:29 +0000 2018
# Tweet collected at Thu Aug 23 15:52:29 +0000 2018
# Tweet collected at Thu Aug 23 15:52:32 +0000 2018
# Tweet collected at Thu Aug 23 15:52:33 +0000 2018
# Tweet collected at Thu Aug 23 15:52:34 +0000 2018
# Tweet collected at Thu Aug 23 15:52:35 +0000 2018
# Tweet collected at Thu Aug 23 15:52:38 +0000 2018
# Tweet collected at Thu Aug 23 15:52:38 +0000 2018
# Tweet collected at Thu Aug 23 15:52:38 +0000 2018
# Tweet collected at Thu Aug 23 15:52:39 +0000 2018
# Tweet collected at Thu Aug 23 15:52:39 +0000 2018
# Tweet collected at Thu Aug 23 15:52:39 +0000 2018
# Tweet collected at Thu Aug 23 15:52:41 +0000 2018
# Tweet collected at Thu Aug 23 15:52:42 +0000 2018
# Tweet collected at Thu Aug 23 15:52:42 +0000 2018
# Tweet collected at Thu Aug 23 15:52:44 +0000 2018
# Tweet collected at Thu Aug 23 15:52:44 +0000 2018
# Tweet collected at Thu Aug 23 15:52:44 +0000 2018
# Tweet collected at Thu Aug 23 15:52:45 +0000 2018
# Tweet collected at Thu Aug 23 15:52:46 +0000 2018
# Tweet collected at Thu Aug 23 15:52:49 +0000 2018
# Tweet collected at Thu Aug 23 15:52:49 +0000 2018
# Tweet collected at Thu Aug 23 15:52:50 +0000 2018
# Tweet collected at Thu Aug 23 15:52:50 +0000 2018
# Tweet collected at Thu Aug 23 15:52:54 +0000 2018
# Tweet collected at Thu Aug 23 15:52:55 +0000 2018
# Tweet collected at Thu Aug 23 15:52:56 +0000 2018
# Tweet collected at Thu Aug 23 15:53:00 +0000 2018
# Tweet collected at Thu Aug 23 15:53:01 +0000 2018
# Tweet collected at Thu Aug 23 15:53:01 +0000 2018
# Tweet collected at Thu Aug 23 15:53:02 +0000 2018
# Tweet collected at Thu Aug 23 15:53:02 +0000 2018
# Tweet collected at Thu Aug 23 15:53:01 +0000 2018
# Tweet collected at Thu Aug 23 15:53:03 +0000 2018
# Tweet collected at Thu Aug 23 15:53:03 +0000 2018
# Tweet collected at Thu Aug 23 15:53:07 +0000 2018
# Tweet collected at Thu Aug 23 15:53:07 +0000 2018
# Tweet collected at Thu Aug 23 15:53:08 +0000 2018
# Tweet collected at Thu Aug 23 15:53:09 +0000 2018
# Tweet collected at Thu Aug 23 15:53:10 +0000 2018
# Tweet collected at Thu Aug 23 15:53:11 +0000 2018
# Tweet collected at Thu Aug 23 15:53:11 +0000 2018
# Tweet collected at Thu Aug 23 15:53:14 +0000 2018
# Tweet collected at Thu Aug 23 15:53:14 +0000 2018
# Tweet collected at Thu Aug 23 15:53:18 +0000 2018
# Tweet collected at Thu Aug 23 15:53:20 +0000 2018
# Tweet collected at Thu Aug 23 15:53:20 +0000 2018
# Tweet collected at Thu Aug 23 15:53:21 +0000 2018
# Tweet collected at Thu Aug 23 15:53:21 +0000 2018
# Tweet collected at Thu Aug 23 15:53:21 +0000 2018
# Tweet collected at Thu Aug 23 15:53:21 +0000 2018
# Tweet collected at Thu Aug 23 15:53:23 +0000 2018
# Tweet collected at Thu Aug 23 15:53:26 +0000 2018
# Tweet collected at Thu Aug 23 15:53:26 +0000 2018
# Tweet collected at Thu Aug 23 15:53:27 +0000 2018
# Tweet collected at Thu Aug 23 15:53:28 +0000 2018
# Tweet collected at Thu Aug 23 15:53:29 +0000 2018
# Tweet collected at Thu Aug 23 15:53:31 +0000 2018
# Tweet collected at Thu Aug 23 15:53:33 +0000 2018
# Tweet collected at Thu Aug 23 15:53:33 +0000 2018
# Tweet collected at Thu Aug 23 15:53:34 +0000 2018
# Tweet collected at Thu Aug 23 15:53:35 +0000 2018
# Tweet collected at Thu Aug 23 15:53:38 +0000 2018
# Tweet collected at Thu Aug 23 15:53:40 +0000 2018
# Tweet collected at Thu Aug 23 15:53:41 +0000 2018
# Tweet collected at Thu Aug 23 15:53:41 +0000 2018
# Tweet collected at Thu Aug 23 15:53:41 +0000 2018
# Tweet collected at Thu Aug 23 15:53:42 +0000 2018
# Tweet collected at Thu Aug 23 15:53:42 +0000 2018
# Tweet collected at Thu Aug 23 15:53:43 +0000 2018
# Tweet collected at Thu Aug 23 15:53:44 +0000 2018
# Tweet collected at Thu Aug 23 15:53:45 +0000 2018
# Tweet collected at Thu Aug 23 15:53:47 +0000 2018
# Tweet collected at Thu Aug 23 15:53:49 +0000 2018
# Tweet collected at Thu Aug 23 15:53:49 +0000 2018
# Tweet collected at Thu Aug 23 15:53:53 +0000 2018
# Tweet collected at Thu Aug 23 15:53:55 +0000 2018
# Tweet collected at Thu Aug 23 15:53:55 +0000 2018
# Tweet collected at Thu Aug 23 15:53:56 +0000 2018
# Tweet collected at Thu Aug 23 15:53:58 +0000 2018
# Tweet collected at Thu Aug 23 15:54:00 +0000 2018
# Tweet collected at Thu Aug 23 15:54:00 +0000 2018
# Tweet collected at Thu Aug 23 15:54:01 +0000 2018
# Tweet collected at Thu Aug 23 15:54:01 +0000 2018
# Tweet collected at Thu Aug 23 15:54:02 +0000 2018
# Tweet collected at Thu Aug 23 15:54:03 +0000 2018
# Tweet collected at Thu Aug 23 15:54:06 +0000 2018
# Tweet collected at Thu Aug 23 15:54:06 +0000 2018
# Tweet collected at Thu Aug 23 15:54:07 +0000 2018
# Tweet collected at Thu Aug 23 15:54:07 +0000 2018
# Tweet collected at Thu Aug 23 15:54:08 +0000 2018
# Tweet collected at Thu Aug 23 15:54:08 +0000 2018
# Tweet collected at Thu Aug 23 15:54:10 +0000 2018
# Tweet collected at Thu Aug 23 15:54:11 +0000 2018
# Tweet collected at Thu Aug 23 15:54:12 +0000 2018
# Tweet collected at Thu Aug 23 15:54:13 +0000 2018
# Tweet collected at Thu Aug 23 15:54:13 +0000 2018
# Tweet collected at Thu Aug 23 15:54:15 +0000 2018
# Tweet collected at Thu Aug 23 15:54:15 +0000 2018
# Tweet collected at Thu Aug 23 15:54:16 +0000 2018
# Tweet collected at Thu Aug 23 15:54:16 +0000 2018
# Tweet collected at Thu Aug 23 15:54:17 +0000 2018
# Tweet collected at Thu Aug 23 15:54:19 +0000 2018
# Tweet collected at Thu Aug 23 15:54:19 +0000 2018
# Tweet collected at Thu Aug 23 15:54:20 +0000 2018
# Tweet collected at Thu Aug 23 15:54:20 +0000 2018
# Tweet collected at Thu Aug 23 15:54:21 +0000 2018
# Tweet collected at Thu Aug 23 15:54:21 +0000 2018
# Tweet collected at Thu Aug 23 15:54:23 +0000 2018
# Tweet collected at Thu Aug 23 15:54:23 +0000 2018
# Tweet collected at Thu Aug 23 15:54:24 +0000 2018
# Tweet collected at Thu Aug 23 15:54:24 +0000 2018
# Tweet collected at Thu Aug 23 15:54:25 +0000 2018
# Tweet collected at Thu Aug 23 15:54:25 +0000 2018
# Tweet collected at Thu Aug 23 15:54:26 +0000 2018
# Tweet collected at Thu Aug 23 15:54:28 +0000 2018
# Tweet collected at Thu Aug 23 15:54:30 +0000 2018
# Tweet collected at Thu Aug 23 15:54:30 +0000 2018
# Tweet collected at Thu Aug 23 15:54:32 +0000 2018
# Tweet collected at Thu Aug 23 15:54:35 +0000 2018
# Tweet collected at Thu Aug 23 15:54:38 +0000 2018
# Tweet collected at Thu Aug 23 15:54:42 +0000 2018
# Tweet collected at Thu Aug 23 15:54:42 +0000 2018
# Tweet collected at Thu Aug 23 15:54:43 +0000 2018
# Tweet collected at Thu Aug 23 15:54:43 +0000 2018
# Tweet collected at Thu Aug 23 15:54:43 +0000 2018
# Tweet collected at Thu Aug 23 15:54:44 +0000 2018
# Tweet collected at Thu Aug 23 15:54:44 +0000 2018
# Tweet collected at Thu Aug 23 15:54:46 +0000 2018
# Tweet collected at Thu Aug 23 15:54:48 +0000 2018
# Tweet collected at Thu Aug 23 15:54:50 +0000 2018
# Tweet collected at Thu Aug 23 15:54:52 +0000 2018
# Tweet collected at Thu Aug 23 15:54:53 +0000 2018
# Tweet collected at Thu Aug 23 15:54:55 +0000 2018
# Tweet collected at Thu Aug 23 15:54:55 +0000 2018
# Tweet collected at Thu Aug 23 15:54:56 +0000 2018
# Tweet collected at Thu Aug 23 15:54:57 +0000 2018
# Tweet collected at Thu Aug 23 15:54:57 +0000 2018
# Tweet collected at Thu Aug 23 15:55:00 +0000 2018
# Tweet collected at Thu Aug 23 15:55:00 +0000 2018
# Tweet collected at Thu Aug 23 15:55:03 +0000 2018
# Tweet collected at Thu Aug 23 15:55:04 +0000 2018
# Tweet collected at Thu Aug 23 15:55:04 +0000 2018
# Tweet collected at Thu Aug 23 15:55:06 +0000 2018
# Tweet collected at Thu Aug 23 15:55:07 +0000 2018
# Tweet collected at Thu Aug 23 15:55:07 +0000 2018
# Tweet collected at Thu Aug 23 15:55:07 +0000 2018
# Tweet collected at Thu Aug 23 15:55:08 +0000 2018
# Tweet collected at Thu Aug 23 15:55:08 +0000 2018
# Tweet collected at Thu Aug 23 15:55:08 +0000 2018
# Tweet collected at Thu Aug 23 15:55:08 +0000 2018
# Tweet collected at Thu Aug 23 15:55:09 +0000 2018
# Tweet collected at Thu Aug 23 15:55:09 +0000 2018
# Tweet collected at Thu Aug 23 15:55:10 +0000 2018
# Tweet collected at Thu Aug 23 15:55:11 +0000 2018
# Tweet collected at Thu Aug 23 15:55:11 +0000 2018
# Tweet collected at Thu Aug 23 15:55:13 +0000 2018
# Tweet collected at Thu Aug 23 15:55:13 +0000 2018
# Tweet collected at Thu Aug 23 15:55:13 +0000 2018
# Tweet collected at Thu Aug 23 15:55:13 +0000 2018
# Tweet collected at Thu Aug 23 15:55:15 +0000 2018
# Tweet collected at Thu Aug 23 15:55:15 +0000 2018
# Tweet collected at Thu Aug 23 15:55:17 +0000 2018
# Tweet collected at Thu Aug 23 15:55:17 +0000 2018
# Tweet collected at Thu Aug 23 15:55:18 +0000 2018
# Tweet collected at Thu Aug 23 15:55:18 +0000 2018
# Tweet collected at Thu Aug 23 15:55:19 +0000 2018
# Tweet collected at Thu Aug 23 15:55:20 +0000 2018
# Tweet collected at Thu Aug 23 15:55:20 +0000 2018
# Tweet collected at Thu Aug 23 15:55:20 +0000 2018
# Tweet collected at Thu Aug 23 15:55:21 +0000 2018
# Tweet collected at Thu Aug 23 15:55:22 +0000 2018
# Tweet collected at Thu Aug 23 15:55:23 +0000 2018
# Tweet collected at Thu Aug 23 15:55:24 +0000 2018
# Tweet collected at Thu Aug 23 15:55:25 +0000 2018
# Tweet collected at Thu Aug 23 15:55:31 +0000 2018
# Tweet collected at Thu Aug 23 15:55:33 +0000 2018
# Tweet collected at Thu Aug 23 15:55:35 +0000 2018
# Tweet collected at Thu Aug 23 15:55:36 +0000 2018
# Tweet collected at Thu Aug 23 15:55:36 +0000 2018
# Tweet collected at Thu Aug 23 15:55:37 +0000 2018
# Tweet collected at Thu Aug 23 15:55:40 +0000 2018
# Tweet collected at Thu Aug 23 15:55:41 +0000 2018
# Tweet collected at Thu Aug 23 15:55:43 +0000 2018
# Tweet collected at Thu Aug 23 15:55:43 +0000 2018
# Tweet collected at Thu Aug 23 15:55:43 +0000 2018
# Tweet collected at Thu Aug 23 15:55:44 +0000 2018
# Tweet collected at Thu Aug 23 15:55:44 +0000 2018
# Tweet collected at Thu Aug 23 15:55:46 +0000 2018
# Tweet collected at Thu Aug 23 15:55:50 +0000 2018
# Tweet collected at Thu Aug 23 15:55:50 +0000 2018
# Tweet collected at Thu Aug 23 15:55:51 +0000 2018
# Tweet collected at Thu Aug 23 15:55:54 +0000 2018
# Tweet collected at Thu Aug 23 15:55:54 +0000 2018
# Tweet collected at Thu Aug 23 15:55:56 +0000 2018
# Tweet collected at Thu Aug 23 15:55:58 +0000 2018
# Tweet collected at Thu Aug 23 15:55:58 +0000 2018
# Tweet collected at Thu Aug 23 15:55:59 +0000 2018
# Tweet collected at Thu Aug 23 15:56:00 +0000 2018
# Tweet collected at Thu Aug 23 15:56:02 +0000 2018
# Tweet collected at Thu Aug 23 15:56:04 +0000 2018
# Tweet collected at Thu Aug 23 15:56:04 +0000 2018
# Tweet collected at Thu Aug 23 15:56:06 +0000 2018
# Tweet collected at Thu Aug 23 15:56:07 +0000 2018
# Tweet collected at Thu Aug 23 15:56:08 +0000 2018
# Tweet collected at Thu Aug 23 15:56:07 +0000 2018
# Tweet collected at Thu Aug 23 15:56:10 +0000 2018
# Tweet collected at Thu Aug 23 15:56:11 +0000 2018
# Tweet collected at Thu Aug 23 15:56:11 +0000 2018
# Tweet collected at Thu Aug 23 15:56:13 +0000 2018
# Tweet collected at Thu Aug 23 15:56:13 +0000 2018
# Tweet collected at Thu Aug 23 15:56:14 +0000 2018
# Tweet collected at Thu Aug 23 15:56:17 +0000 2018
# Tweet collected at Thu Aug 23 15:56:17 +0000 2018
# Tweet collected at Thu Aug 23 15:56:19 +0000 2018
# Tweet collected at Thu Aug 23 15:56:19 +0000 2018
# Tweet collected at Thu Aug 23 15:56:20 +0000 2018
# Tweet collected at Thu Aug 23 15:56:22 +0000 2018
# Tweet collected at Thu Aug 23 15:56:24 +0000 2018
# Tweet collected at Thu Aug 23 15:56:25 +0000 2018
# Tweet collected at Thu Aug 23 15:56:25 +0000 2018
# Tweet collected at Thu Aug 23 15:56:29 +0000 2018
# Tweet collected at Thu Aug 23 15:56:31 +0000 2018
# Tweet collected at Thu Aug 23 15:56:34 +0000 2018
# Tweet collected at Thu Aug 23 15:56:38 +0000 2018
# Tweet collected at Thu Aug 23 15:56:38 +0000 2018
# Tweet collected at Thu Aug 23 15:56:40 +0000 2018
# Tweet collected at Thu Aug 23 15:56:41 +0000 2018
# Tweet collected at Thu Aug 23 15:56:43 +0000 2018
# Tweet collected at Thu Aug 23 15:56:43 +0000 2018
# Tweet collected at Thu Aug 23 15:56:45 +0000 2018
# Tweet collected at Thu Aug 23 15:56:47 +0000 2018
# Tweet collected at Thu Aug 23 15:56:48 +0000 2018
# Tweet collected at Thu Aug 23 15:56:51 +0000 2018
# Tweet collected at Thu Aug 23 15:56:54 +0000 2018
# Tweet collected at Thu Aug 23 15:56:54 +0000 2018
# Tweet collected at Thu Aug 23 15:56:56 +0000 2018
# Tweet collected at Thu Aug 23 15:56:57 +0000 2018
# Tweet collected at Thu Aug 23 15:56:58 +0000 2018
# Tweet collected at Thu Aug 23 15:57:00 +0000 2018
# Tweet collected at Thu Aug 23 15:57:01 +0000 2018
# Tweet collected at Thu Aug 23 15:57:02 +0000 2018
# Tweet collected at Thu Aug 23 15:57:02 +0000 2018
# Tweet collected at Thu Aug 23 15:57:04 +0000 2018
# Tweet collected at Thu Aug 23 15:57:05 +0000 2018
# Tweet collected at Thu Aug 23 15:57:05 +0000 2018
# Tweet collected at Thu Aug 23 15:57:08 +0000 2018
# Tweet collected at Thu Aug 23 15:57:09 +0000 2018
# Tweet collected at Thu Aug 23 15:57:10 +0000 2018
# Tweet collected at Thu Aug 23 15:57:11 +0000 2018
# Tweet collected at Thu Aug 23 15:57:13 +0000 2018
# Tweet collected at Thu Aug 23 15:57:15 +0000 2018
# Tweet collected at Thu Aug 23 15:57:17 +0000 2018
# Tweet collected at Thu Aug 23 15:57:17 +0000 2018
# Tweet collected at Thu Aug 23 15:57:22 +0000 2018
# Tweet collected at Thu Aug 23 15:57:22 +0000 2018
# Tweet collected at Thu Aug 23 15:57:25 +0000 2018
# Tweet collected at Thu Aug 23 15:57:28 +0000 2018
# Tweet collected at Thu Aug 23 15:57:28 +0000 2018
# Tweet collected at Thu Aug 23 15:57:29 +0000 2018
# Tweet collected at Thu Aug 23 15:57:29 +0000 2018
# Tweet collected at Thu Aug 23 15:57:31 +0000 2018
# Tweet collected at Thu Aug 23 15:57:31 +0000 2018
# Tweet collected at Thu Aug 23 15:57:34 +0000 2018
# Tweet collected at Thu Aug 23 15:57:35 +0000 2018
# Tweet collected at Thu Aug 23 15:57:36 +0000 2018
# Tweet collected at Thu Aug 23 15:57:37 +0000 2018
# Tweet collected at Thu Aug 23 15:57:38 +0000 2018
# Tweet collected at Thu Aug 23 15:57:41 +0000 2018
# Tweet collected at Thu Aug 23 15:57:41 +0000 2018
# Tweet collected at Thu Aug 23 15:57:46 +0000 2018
# Tweet collected at Thu Aug 23 15:57:47 +0000 2018
# Tweet collected at Thu Aug 23 15:57:49 +0000 2018
# Tweet collected at Thu Aug 23 15:57:51 +0000 2018
# Tweet collected at Thu Aug 23 15:57:52 +0000 2018
# Tweet collected at Thu Aug 23 15:57:52 +0000 2018
# Tweet collected at Thu Aug 23 15:57:52 +0000 2018
# Tweet collected at Thu Aug 23 15:57:54 +0000 2018
# Tweet collected at Thu Aug 23 15:57:55 +0000 2018
# Tweet collected at Thu Aug 23 15:57:55 +0000 2018
# Tweet collected at Thu Aug 23 15:57:56 +0000 2018
# Tweet collected at Thu Aug 23 15:57:56 +0000 2018
# Tweet collected at Thu Aug 23 15:57:56 +0000 2018
# Tweet collected at Thu Aug 23 15:57:58 +0000 2018
# Tweet collected at Thu Aug 23 15:58:00 +0000 2018
# Tweet collected at Thu Aug 23 15:58:00 +0000 2018
# Tweet collected at Thu Aug 23 15:58:01 +0000 2018
# Tweet collected at Thu Aug 23 15:58:05 +0000 2018
# Tweet collected at Thu Aug 23 15:58:07 +0000 2018
# Tweet collected at Thu Aug 23 15:58:03 +0000 2018
# Tweet collected at Thu Aug 23 15:58:07 +0000 2018
# Tweet collected at Thu Aug 23 15:58:07 +0000 2018
# Tweet collected at Thu Aug 23 15:58:11 +0000 2018
# Tweet collected at Thu Aug 23 15:58:12 +0000 2018
# Tweet collected at Thu Aug 23 15:58:13 +0000 2018
# Tweet collected at Thu Aug 23 15:58:17 +0000 2018
# Tweet collected at Thu Aug 23 15:58:19 +0000 2018
# Tweet collected at Thu Aug 23 15:58:19 +0000 2018
# Tweet collected at Thu Aug 23 15:58:21 +0000 2018
# Tweet collected at Thu Aug 23 15:58:22 +0000 2018
# Tweet collected at Thu Aug 23 15:58:25 +0000 2018
# Tweet collected at Thu Aug 23 15:58:25 +0000 2018
# Tweet collected at Thu Aug 23 15:58:25 +0000 2018
# Tweet collected at Thu Aug 23 15:58:26 +0000 2018
# Tweet collected at Thu Aug 23 15:58:26 +0000 2018
# Tweet collected at Thu Aug 23 15:58:26 +0000 2018
# Tweet collected at Thu Aug 23 15:58:29 +0000 2018
# Tweet collected at Thu Aug 23 15:58:30 +0000 2018
# Tweet collected at Thu Aug 23 15:58:34 +0000 2018
# Tweet collected at Thu Aug 23 15:58:36 +0000 2018
# Tweet collected at Thu Aug 23 15:58:37 +0000 2018
# Tweet collected at Thu Aug 23 15:58:37 +0000 2018
# Tweet collected at Thu Aug 23 15:58:38 +0000 2018
# Tweet collected at Thu Aug 23 15:58:38 +0000 2018
# Tweet collected at Thu Aug 23 15:58:40 +0000 2018
# Tweet collected at Thu Aug 23 15:58:41 +0000 2018
# Tweet collected at Thu Aug 23 15:58:42 +0000 2018
# Tweet collected at Thu Aug 23 15:58:45 +0000 2018
# Tweet collected at Thu Aug 23 15:58:45 +0000 2018
# Tweet collected at Thu Aug 23 15:58:45 +0000 2018
# Tweet collected at Thu Aug 23 15:58:49 +0000 2018
# Tweet collected at Thu Aug 23 15:58:50 +0000 2018
# Tweet collected at Thu Aug 23 15:58:54 +0000 2018
# Tweet collected at Thu Aug 23 15:58:58 +0000 2018
# Tweet collected at Thu Aug 23 15:58:59 +0000 2018
# Tweet collected at Thu Aug 23 15:58:59 +0000 2018
# Tweet collected at Thu Aug 23 15:59:00 +0000 2018
# Tweet collected at Thu Aug 23 15:59:03 +0000 2018
# Tweet collected at Thu Aug 23 15:59:04 +0000 2018
# Tweet collected at Thu Aug 23 15:59:05 +0000 2018
# Tweet collected at Thu Aug 23 15:59:04 +0000 2018
# Tweet collected at Thu Aug 23 15:59:09 +0000 2018
# Tweet collected at Thu Aug 23 15:59:13 +0000 2018
# Tweet collected at Thu Aug 23 15:59:16 +0000 2018
# Tweet collected at Thu Aug 23 15:59:19 +0000 2018
# Tweet collected at Thu Aug 23 15:59:21 +0000 2018
# Tweet collected at Thu Aug 23 15:59:23 +0000 2018
# Tweet collected at Thu Aug 23 15:59:28 +0000 2018
# Tweet collected at Thu Aug 23 15:59:28 +0000 2018
# Tweet collected at Thu Aug 23 15:59:30 +0000 2018
# Tweet collected at Thu Aug 23 15:59:30 +0000 2018
# Tweet collected at Thu Aug 23 15:59:30 +0000 2018
# Tweet collected at Thu Aug 23 15:59:31 +0000 2018
# Tweet collected at Thu Aug 23 15:59:35 +0000 2018
# Tweet collected at Thu Aug 23 15:59:36 +0000 2018
# Tweet collected at Thu Aug 23 15:59:37 +0000 2018
# Tweet collected at Thu Aug 23 15:59:39 +0000 2018
# Tweet collected at Thu Aug 23 15:59:40 +0000 2018
# Tweet collected at Thu Aug 23 15:59:41 +0000 2018
# Tweet collected at Thu Aug 23 15:59:44 +0000 2018
# Tweet collected at Thu Aug 23 15:59:44 +0000 2018
# Tweet collected at Thu Aug 23 15:59:48 +0000 2018
# Tweet collected at Thu Aug 23 15:59:51 +0000 2018
# Tweet collected at Thu Aug 23 15:59:51 +0000 2018
# Tweet collected at Thu Aug 23 15:59:56 +0000 2018
# Tweet collected at Thu Aug 23 15:59:58 +0000 2018
# Tweet collected at Thu Aug 23 15:59:58 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:00 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:03 +0000 2018
# Tweet collected at Thu Aug 23 16:00:03 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:03 +0000 2018
# Tweet collected at Thu Aug 23 16:00:03 +0000 2018
# Tweet collected at Thu Aug 23 16:00:03 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:03 +0000 2018
# Tweet collected at Thu Aug 23 16:00:02 +0000 2018
# Tweet collected at Thu Aug 23 16:00:04 +0000 2018
# Tweet collected at Thu Aug 23 16:00:05 +0000 2018
# Tweet collected at Thu Aug 23 16:00:05 +0000 2018
# Tweet collected at Thu Aug 23 16:00:05 +0000 2018
# Tweet collected at Thu Aug 23 16:00:01 +0000 2018
# Tweet collected at Thu Aug 23 16:00:05 +0000 2018
# Tweet collected at Thu Aug 23 16:00:05 +0000 2018
# Tweet collected at Thu Aug 23 16:00:06 +0000 2018
# Tweet collected at Thu Aug 23 16:00:06 +0000 2018
# Tweet collected at Thu Aug 23 16:00:06 +0000 2018
# Tweet collected at Thu Aug 23 16:00:06 +0000 2018
# Tweet collected at Thu Aug 23 16:00:05 +0000 2018
# Tweet collected at Thu Aug 23 16:00:06 +0000 2018
# Tweet collected at Thu Aug 23 16:00:06 +0000 2018
# Tweet collected at Thu Aug 23 16:00:07 +0000 2018
# Tweet collected at Thu Aug 23 16:00:08 +0000 2018
# Tweet collected at Thu Aug 23 16:00:10 +0000 2018
# Tweet collected at Thu Aug 23 16:00:10 +0000 2018
# Tweet collected at Thu Aug 23 16:00:10 +0000 2018
# Tweet collected at Thu Aug 23 16:00:11 +0000 2018
# Tweet collected at Thu Aug 23 16:00:11 +0000 2018
# Tweet collected at Thu Aug 23 16:00:12 +0000 2018
# Tweet collected at Thu Aug 23 16:00:12 +0000 2018
# Tweet collected at Thu Aug 23 16:00:12 +0000 2018
# Tweet collected at Thu Aug 23 16:00:12 +0000 2018
# Tweet collected at Thu Aug 23 16:00:13 +0000 2018
# Tweet collected at Thu Aug 23 16:00:14 +0000 2018
# Tweet collected at Thu Aug 23 16:00:14 +0000 2018
# Tweet collected at Thu Aug 23 16:00:14 +0000 2018
# Tweet collected at Thu Aug 23 16:00:14 +0000 2018
# Tweet collected at Thu Aug 23 16:00:14 +0000 2018
# Tweet collected at Thu Aug 23 16:00:14 +0000 2018
# Tweet collected at Thu Aug 23 16:00:16 +0000 2018
# Tweet collected at Thu Aug 23 16:00:17 +0000 2018
# Tweet collected at Thu Aug 23 16:00:18 +0000 2018
# Tweet collected at Thu Aug 23 16:00:18 +0000 2018
# Tweet collected at Thu Aug 23 16:00:19 +0000 2018
# Tweet collected at Thu Aug 23 16:00:19 +0000 2018
# Tweet collected at Thu Aug 23 16:00:19 +0000 2018
# Tweet collected at Thu Aug 23 16:00:19 +0000 2018
# Tweet collected at Thu Aug 23 16:00:20 +0000 2018
# Tweet collected at Thu Aug 23 16:00:20 +0000 2018
# Tweet collected at Thu Aug 23 16:00:21 +0000 2018
# Tweet collected at Thu Aug 23 16:00:22 +0000 2018
# Tweet collected at Thu Aug 23 16:00:23 +0000 2018
# Tweet collected at Thu Aug 23 16:00:24 +0000 2018
# Tweet collected at Thu Aug 23 16:00:25 +0000 2018
# Tweet collected at Thu Aug 23 16:00:23 +0000 2018
# Tweet collected at Thu Aug 23 16:00:26 +0000 2018
# Tweet collected at Thu Aug 23 16:00:27 +0000 2018
# Tweet collected at Thu Aug 23 16:00:27 +0000 2018
# Tweet collected at Thu Aug 23 16:00:28 +0000 2018
# Tweet collected at Thu Aug 23 16:00:28 +0000 2018
# Tweet collected at Thu Aug 23 16:00:29 +0000 2018
# Tweet collected at Thu Aug 23 16:00:32 +0000 2018
# Tweet collected at Thu Aug 23 16:00:32 +0000 2018
# Tweet collected at Thu Aug 23 16:00:33 +0000 2018
# Tweet collected at Thu Aug 23 16:00:33 +0000 2018
# Tweet collected at Thu Aug 23 16:00:34 +0000 2018
# Tweet collected at Thu Aug 23 16:00:33 +0000 2018
# Tweet collected at Thu Aug 23 16:00:34 +0000 2018
# Tweet collected at Thu Aug 23 16:00:34 +0000 2018
# Tweet collected at Thu Aug 23 16:00:34 +0000 2018
# Tweet collected at Thu Aug 23 16:00:34 +0000 2018
# Tweet collected at Thu Aug 23 16:00:36 +0000 2018
# Tweet collected at Thu Aug 23 16:00:37 +0000 2018
# Tweet collected at Thu Aug 23 16:00:37 +0000 2018
# Tweet collected at Thu Aug 23 16:00:38 +0000 2018
# Tweet collected at Thu Aug 23 16:00:38 +0000 2018
# Tweet collected at Thu Aug 23 16:00:38 +0000 2018
# Tweet collected at Thu Aug 23 16:00:38 +0000 2018
# Tweet collected at Thu Aug 23 16:00:38 +0000 2018
# Tweet collected at Thu Aug 23 16:00:39 +0000 2018
# Tweet collected at Thu Aug 23 16:00:40 +0000 2018
# Tweet collected at Thu Aug 23 16:00:40 +0000 2018
# Tweet collected at Thu Aug 23 16:00:41 +0000 2018
# Tweet collected at Thu Aug 23 16:00:41 +0000 2018
# Tweet collected at Thu Aug 23 16:00:41 +0000 2018
# Tweet collected at Thu Aug 23 16:00:42 +0000 2018
# Tweet collected at Thu Aug 23 16:00:43 +0000 2018
# Tweet collected at Thu Aug 23 16:00:43 +0000 2018
# Tweet collected at Thu Aug 23 16:00:44 +0000 2018
# Tweet collected at Thu Aug 23 16:00:44 +0000 2018
# Tweet collected at Thu Aug 23 16:00:44 +0000 2018
# Tweet collected at Thu Aug 23 16:00:45 +0000 2018
# Tweet collected at Thu Aug 23 16:00:46 +0000 2018
# Tweet collected at Thu Aug 23 16:00:48 +0000 2018
# Tweet collected at Thu Aug 23 16:00:49 +0000 2018
# Tweet collected at Thu Aug 23 16:00:50 +0000 2018
# Tweet collected at Thu Aug 23 16:00:51 +0000 2018
# Tweet collected at Thu Aug 23 16:00:51 +0000 2018
# Tweet collected at Thu Aug 23 16:00:51 +0000 2018
# Tweet collected at Thu Aug 23 16:00:52 +0000 2018
# Tweet collected at Thu Aug 23 16:00:53 +0000 2018
# Tweet collected at Thu Aug 23 16:00:53 +0000 2018
# Tweet collected at Thu Aug 23 16:00:53 +0000 2018
# Tweet collected at Thu Aug 23 16:00:54 +0000 2018
# Tweet collected at Thu Aug 23 16:00:57 +0000 2018
# Tweet collected at Thu Aug 23 16:00:58 +0000 2018
# Tweet collected at Thu Aug 23 16:00:59 +0000 2018
# Tweet collected at Thu Aug 23 16:00:59 +0000 2018
# Tweet collected at Thu Aug 23 16:01:00 +0000 2018
# Tweet collected at Thu Aug 23 16:01:00 +0000 2018
# Tweet collected at Thu Aug 23 16:01:01 +0000 2018
# Tweet collected at Thu Aug 23 16:01:01 +0000 2018
# Tweet collected at Thu Aug 23 16:01:01 +0000 2018
# Tweet collected at Thu Aug 23 16:01:01 +0000 2018
# Tweet collected at Thu Aug 23 16:01:01 +0000 2018
# Tweet collected at Thu Aug 23 16:01:02 +0000 2018
# Tweet collected at Thu Aug 23 16:01:02 +0000 2018
# Tweet collected at Thu Aug 23 16:01:02 +0000 2018
# Tweet collected at Thu Aug 23 16:01:02 +0000 2018
# Tweet collected at Thu Aug 23 16:01:03 +0000 2018
# Tweet collected at Thu Aug 23 16:01:03 +0000 2018
# Tweet collected at Thu Aug 23 16:01:04 +0000 2018
# Tweet collected at Thu Aug 23 16:01:04 +0000 2018
# Tweet collected at Thu Aug 23 16:01:04 +0000 2018
# Tweet collected at Thu Aug 23 16:01:05 +0000 2018
# Tweet collected at Thu Aug 23 16:01:06 +0000 2018
# Tweet collected at Thu Aug 23 16:01:06 +0000 2018
# Tweet collected at Thu Aug 23 16:01:07 +0000 2018
# Tweet collected at Thu Aug 23 16:01:07 +0000 2018
# Tweet collected at Thu Aug 23 16:01:07 +0000 2018
# Tweet collected at Thu Aug 23 16:01:07 +0000 2018
# Tweet collected at Thu Aug 23 16:01:08 +0000 2018
# Tweet collected at Thu Aug 23 16:01:09 +0000 2018
# Tweet collected at Thu Aug 23 16:01:11 +0000 2018
# Tweet collected at Thu Aug 23 16:01:10 +0000 2018
# Tweet collected at Thu Aug 23 16:01:11 +0000 2018
# Tweet collected at Thu Aug 23 16:01:12 +0000 2018
# Tweet collected at Thu Aug 23 16:01:12 +0000 2018
# Tweet collected at Thu Aug 23 16:01:13 +0000 2018
# Tweet collected at Thu Aug 23 16:01:14 +0000 2018
# Tweet collected at Thu Aug 23 16:01:17 +0000 2018
# Tweet collected at Thu Aug 23 16:01:19 +0000 2018
# Tweet collected at Thu Aug 23 16:01:19 +0000 2018
# Tweet collected at Thu Aug 23 16:01:19 +0000 2018
# Tweet collected at Thu Aug 23 16:01:19 +0000 2018
# Tweet collected at Thu Aug 23 16:01:20 +0000 2018
# Tweet collected at Thu Aug 23 16:01:20 +0000 2018
# Tweet collected at Thu Aug 23 16:01:21 +0000 2018
# Tweet collected at Thu Aug 23 16:01:22 +0000 2018
# Tweet collected at Thu Aug 23 16:01:23 +0000 2018
# Tweet collected at Thu Aug 23 16:01:24 +0000 2018
# Tweet collected at Thu Aug 23 16:01:24 +0000 2018
# Tweet collected at Thu Aug 23 16:01:25 +0000 2018
# Tweet collected at Thu Aug 23 16:01:25 +0000 2018
# Tweet collected at Thu Aug 23 16:01:26 +0000 2018
# Tweet collected at Thu Aug 23 16:01:27 +0000 2018
# Tweet collected at Thu Aug 23 16:01:26 +0000 2018
# Tweet collected at Thu Aug 23 16:01:27 +0000 2018
# Tweet collected at Thu Aug 23 16:01:27 +0000 2018
# Tweet collected at Thu Aug 23 16:01:28 +0000 2018
# Tweet collected at Thu Aug 23 16:01:28 +0000 2018
# Tweet collected at Thu Aug 23 16:01:29 +0000 2018
# Tweet collected at Thu Aug 23 16:01:30 +0000 2018
# Tweet collected at Thu Aug 23 16:01:31 +0000 2018
# Tweet collected at Thu Aug 23 16:01:33 +0000 2018
# Tweet collected at Thu Aug 23 16:01:35 +0000 2018
# Tweet collected at Thu Aug 23 16:01:36 +0000 2018
# Tweet collected at Thu Aug 23 16:01:35 +0000 2018
# Tweet collected at Thu Aug 23 16:01:37 +0000 2018
# Tweet collected at Thu Aug 23 16:01:37 +0000 2018
# Tweet collected at Thu Aug 23 16:01:38 +0000 2018
# Tweet collected at Thu Aug 23 16:01:38 +0000 2018
# Tweet collected at Thu Aug 23 16:01:40 +0000 2018
# Tweet collected at Thu Aug 23 16:01:41 +0000 2018
# Tweet collected at Thu Aug 23 16:01:42 +0000 2018
# Tweet collected at Thu Aug 23 16:01:42 +0000 2018
# Tweet collected at Thu Aug 23 16:01:43 +0000 2018
# Tweet collected at Thu Aug 23 16:01:43 +0000 2018
# Tweet collected at Thu Aug 23 16:01:44 +0000 2018
# Tweet collected at Thu Aug 23 16:01:43 +0000 2018
# Tweet collected at Thu Aug 23 16:01:44 +0000 2018
# Tweet collected at Thu Aug 23 16:01:45 +0000 2018
# Tweet collected at Thu Aug 23 16:01:45 +0000 2018
# Tweet collected at Thu Aug 23 16:01:45 +0000 2018
# Tweet collected at Thu Aug 23 16:01:46 +0000 2018
# Tweet collected at Thu Aug 23 16:01:46 +0000 2018
# Tweet collected at Thu Aug 23 16:01:47 +0000 2018
# Tweet collected at Thu Aug 23 16:01:48 +0000 2018
# Tweet collected at Thu Aug 23 16:01:50 +0000 2018
# Tweet collected at Thu Aug 23 16:01:51 +0000 2018
# Tweet collected at Thu Aug 23 16:01:51 +0000 2018
# Tweet collected at Thu Aug 23 16:01:51 +0000 2018
# Tweet collected at Thu Aug 23 16:01:50 +0000 2018
# Tweet collected at Thu Aug 23 16:01:52 +0000 2018
# Tweet collected at Thu Aug 23 16:01:53 +0000 2018
# Tweet collected at Thu Aug 23 16:01:53 +0000 2018
# Tweet collected at Thu Aug 23 16:01:53 +0000 2018
# Tweet collected at Thu Aug 23 16:01:52 +0000 2018
# Tweet collected at Thu Aug 23 16:01:53 +0000 2018
# Tweet collected at Thu Aug 23 16:01:53 +0000 2018
# Tweet collected at Thu Aug 23 16:01:54 +0000 2018
# Tweet collected at Thu Aug 23 16:01:54 +0000 2018
# Tweet collected at Thu Aug 23 16:01:54 +0000 2018
# Tweet collected at Thu Aug 23 16:01:56 +0000 2018
# Tweet collected at Thu Aug 23 16:01:58 +0000 2018
# Tweet collected at Thu Aug 23 16:02:00 +0000 2018
# Tweet collected at Thu Aug 23 16:02:02 +0000 2018
# Tweet collected at Thu Aug 23 16:02:03 +0000 2018
# Tweet collected at Thu Aug 23 16:02:03 +0000 2018
# Tweet collected at Thu Aug 23 16:02:03 +0000 2018
# Tweet collected at Thu Aug 23 16:02:03 +0000 2018
# Tweet collected at Thu Aug 23 16:02:03 +0000 2018
# Tweet collected at Thu Aug 23 16:02:04 +0000 2018
# Tweet collected at Thu Aug 23 16:02:04 +0000 2018
# Tweet collected at Thu Aug 23 16:02:06 +0000 2018
# Tweet collected at Thu Aug 23 16:02:06 +0000 2018
# Tweet collected at Thu Aug 23 16:02:07 +0000 2018
# Tweet collected at Thu Aug 23 16:02:09 +0000 2018
# Tweet collected at Thu Aug 23 16:02:09 +0000 2018
# Tweet collected at Thu Aug 23 16:02:09 +0000 2018
# Tweet collected at Thu Aug 23 16:02:10 +0000 2018
# Tweet collected at Thu Aug 23 16:02:10 +0000 2018
# Tweet collected at Thu Aug 23 16:02:11 +0000 2018
# Tweet collected at Thu Aug 23 16:02:12 +0000 2018
# Tweet collected at Thu Aug 23 16:02:15 +0000 2018
# Tweet collected at Thu Aug 23 16:02:16 +0000 2018
# Tweet collected at Thu Aug 23 16:02:18 +0000 2018
# Tweet collected at Thu Aug 23 16:02:18 +0000 2018
# Tweet collected at Thu Aug 23 16:02:19 +0000 2018
# Tweet collected at Thu Aug 23 16:02:20 +0000 2018
# Tweet collected at Thu Aug 23 16:02:21 +0000 2018
# Tweet collected at Thu Aug 23 16:02:21 +0000 2018
# Tweet collected at Thu Aug 23 16:02:21 +0000 2018
# Tweet collected at Thu Aug 23 16:02:21 +0000 2018
# Tweet collected at Thu Aug 23 16:02:21 +0000 2018
# Tweet collected at Thu Aug 23 16:02:22 +0000 2018
# Tweet collected at Thu Aug 23 16:02:23 +0000 2018
# Tweet collected at Thu Aug 23 16:02:23 +0000 2018
# Tweet collected at Thu Aug 23 16:02:24 +0000 2018
# Tweet collected at Thu Aug 23 16:02:24 +0000 2018
# Tweet collected at Thu Aug 23 16:02:24 +0000 2018
# Tweet collected at Thu Aug 23 16:02:25 +0000 2018
# Tweet collected at Thu Aug 23 16:02:25 +0000 2018
# Tweet collected at Thu Aug 23 16:02:26 +0000 2018
# Tweet collected at Thu Aug 23 16:02:26 +0000 2018
# Tweet collected at Thu Aug 23 16:02:29 +0000 2018
# Tweet collected at Thu Aug 23 16:02:29 +0000 2018
# Tweet collected at Thu Aug 23 16:02:31 +0000 2018
# Tweet collected at Thu Aug 23 16:02:31 +0000 2018
# Tweet collected at Thu Aug 23 16:02:31 +0000 2018
# Tweet collected at Thu Aug 23 16:02:32 +0000 2018
# Tweet collected at Thu Aug 23 16:02:34 +0000 2018
# Tweet collected at Thu Aug 23 16:02:34 +0000 2018
# Tweet collected at Thu Aug 23 16:02:37 +0000 2018
# Tweet collected at Thu Aug 23 16:02:38 +0000 2018
# Tweet collected at Thu Aug 23 16:02:38 +0000 2018
# Tweet collected at Thu Aug 23 16:02:38 +0000 2018
# Tweet collected at Thu Aug 23 16:02:39 +0000 2018
# Tweet collected at Thu Aug 23 16:02:42 +0000 2018
# Tweet collected at Thu Aug 23 16:02:42 +0000 2018
# Tweet collected at Thu Aug 23 16:02:42 +0000 2018
# Tweet collected at Thu Aug 23 16:02:44 +0000 2018
# Tweet collected at Thu Aug 23 16:02:44 +0000 2018
# Tweet collected at Thu Aug 23 16:02:45 +0000 2018
# Tweet collected at Thu Aug 23 16:02:46 +0000 2018
# Tweet collected at Thu Aug 23 16:02:47 +0000 2018
# Tweet collected at Thu Aug 23 16:02:47 +0000 2018
# Tweet collected at Thu Aug 23 16:02:50 +0000 2018
# Tweet collected at Thu Aug 23 16:02:51 +0000 2018
# Tweet collected at Thu Aug 23 16:02:51 +0000 2018
# Tweet collected at Thu Aug 23 16:02:53 +0000 2018
# Tweet collected at Thu Aug 23 16:02:54 +0000 2018
# Tweet collected at Thu Aug 23 16:02:55 +0000 2018
# Tweet collected at Thu Aug 23 16:02:55 +0000 2018
# Tweet collected at Thu Aug 23 16:02:56 +0000 2018
# Tweet collected at Thu Aug 23 16:02:56 +0000 2018
# Tweet collected at Thu Aug 23 16:02:57 +0000 2018
# Tweet collected at Thu Aug 23 16:02:57 +0000 2018
# Tweet collected at Thu Aug 23 16:02:57 +0000 2018
# Tweet collected at Thu Aug 23 16:02:58 +0000 2018
# Tweet collected at Thu Aug 23 16:02:58 +0000 2018
# Tweet collected at Thu Aug 23 16:02:59 +0000 2018
# Tweet collected at Thu Aug 23 16:02:59 +0000 2018
# Tweet collected at Thu Aug 23 16:03:00 +0000 2018
# Tweet collected at Thu Aug 23 16:03:00 +0000 2018
# Tweet collected at Thu Aug 23 16:03:00 +0000 2018
# Tweet collected at Thu Aug 23 16:03:01 +0000 2018
# Tweet collected at Thu Aug 23 16:03:02 +0000 2018
# Tweet collected at Thu Aug 23 16:03:04 +0000 2018
# Tweet collected at Thu Aug 23 16:03:05 +0000 2018
# Tweet collected at Thu Aug 23 16:03:02 +0000 2018
# Tweet collected at Thu Aug 23 16:03:05 +0000 2018
# Tweet collected at Thu Aug 23 16:03:05 +0000 2018
# Tweet collected at Thu Aug 23 16:03:05 +0000 2018
# Tweet collected at Thu Aug 23 16:03:07 +0000 2018
# Tweet collected at Thu Aug 23 16:03:07 +0000 2018
# Tweet collected at Thu Aug 23 16:03:08 +0000 2018
# Tweet collected at Thu Aug 23 16:03:09 +0000 2018
# Tweet collected at Thu Aug 23 16:03:10 +0000 2018
# Tweet collected at Thu Aug 23 16:03:10 +0000 2018
# Tweet collected at Thu Aug 23 16:03:10 +0000 2018
# Tweet collected at Thu Aug 23 16:03:11 +0000 2018
# Tweet collected at Thu Aug 23 16:03:12 +0000 2018
# Tweet collected at Thu Aug 23 16:03:13 +0000 2018
# Tweet collected at Thu Aug 23 16:03:14 +0000 2018
# Tweet collected at Thu Aug 23 16:03:18 +0000 2018
# Tweet collected at Thu Aug 23 16:03:18 +0000 2018
# Tweet collected at Thu Aug 23 16:03:18 +0000 2018
# Tweet collected at Thu Aug 23 16:03:19 +0000 2018
# Tweet collected at Thu Aug 23 16:03:19 +0000 2018
# Tweet collected at Thu Aug 23 16:03:22 +0000 2018
# Tweet collected at Thu Aug 23 16:03:23 +0000 2018
# Tweet collected at Thu Aug 23 16:03:24 +0000 2018
# Tweet collected at Thu Aug 23 16:03:25 +0000 2018
# Tweet collected at Thu Aug 23 16:03:25 +0000 2018
# Tweet collected at Thu Aug 23 16:03:25 +0000 2018
# Tweet collected at Thu Aug 23 16:03:25 +0000 2018
# Tweet collected at Thu Aug 23 16:03:25 +0000 2018
# Tweet collected at Thu Aug 23 16:03:26 +0000 2018
# Tweet collected at Thu Aug 23 16:03:26 +0000 2018
# Tweet collected at Thu Aug 23 16:03:27 +0000 2018
# Tweet collected at Thu Aug 23 16:03:27 +0000 2018
# Tweet collected at Thu Aug 23 16:03:27 +0000 2018
# Tweet collected at Thu Aug 23 16:03:27 +0000 2018
# Tweet collected at Thu Aug 23 16:03:27 +0000 2018
# Tweet collected at Thu Aug 23 16:03:29 +0000 2018
# Tweet collected at Thu Aug 23 16:03:29 +0000 2018
# Tweet collected at Thu Aug 23 16:03:30 +0000 2018
# Tweet collected at Thu Aug 23 16:03:30 +0000 2018
# Tweet collected at Thu Aug 23 16:03:31 +0000 2018
# Tweet collected at Thu Aug 23 16:03:32 +0000 2018
# Tweet collected at Thu Aug 23 16:03:32 +0000 2018
# Tweet collected at Thu Aug 23 16:03:33 +0000 2018
# Tweet collected at Thu Aug 23 16:03:34 +0000 2018
# Tweet collected at Thu Aug 23 16:03:35 +0000 2018
# Tweet collected at Thu Aug 23 16:03:36 +0000 2018
# Tweet collected at Thu Aug 23 16:03:36 +0000 2018
# Tweet collected at Thu Aug 23 16:03:37 +0000 2018
# Tweet collected at Thu Aug 23 16:03:37 +0000 2018
# Tweet collected at Thu Aug 23 16:03:40 +0000 2018
# Tweet collected at Thu Aug 23 16:03:40 +0000 2018
# Tweet collected at Thu Aug 23 16:03:42 +0000 2018
# Tweet collected at Thu Aug 23 16:03:42 +0000 2018
# Tweet collected at Thu Aug 23 16:03:43 +0000 2018
# Tweet collected at Thu Aug 23 16:03:45 +0000 2018
# Tweet collected at Thu Aug 23 16:03:46 +0000 2018
# Tweet collected at Thu Aug 23 16:03:50 +0000 2018
# Tweet collected at Thu Aug 23 16:03:50 +0000 2018
# Tweet collected at Thu Aug 23 16:03:51 +0000 2018
# Tweet collected at Thu Aug 23 16:03:52 +0000 2018
# Tweet collected at Thu Aug 23 16:03:53 +0000 2018
# Tweet collected at Thu Aug 23 16:03:54 +0000 2018
# Tweet collected at Thu Aug 23 16:03:56 +0000 2018
# Tweet collected at Thu Aug 23 16:03:57 +0000 2018
# Tweet collected at Thu Aug 23 16:03:58 +0000 2018
# Tweet collected at Thu Aug 23 16:04:00 +0000 2018
# Tweet collected at Thu Aug 23 16:04:00 +0000 2018
# Tweet collected at Thu Aug 23 16:04:01 +0000 2018
# Tweet collected at Thu Aug 23 16:04:01 +0000 2018
# Tweet collected at Thu Aug 23 16:04:01 +0000 2018
# Tweet collected at Thu Aug 23 16:04:02 +0000 2018
# Tweet collected at Thu Aug 23 16:04:02 +0000 2018
# Tweet collected at Thu Aug 23 16:04:03 +0000 2018
# Tweet collected at Thu Aug 23 16:04:04 +0000 2018
# Tweet collected at Thu Aug 23 16:04:04 +0000 2018
# Tweet collected at Thu Aug 23 16:04:05 +0000 2018
# Tweet collected at Thu Aug 23 16:04:05 +0000 2018
# Tweet collected at Thu Aug 23 16:04:06 +0000 2018
# Tweet collected at Thu Aug 23 16:04:05 +0000 2018
# Tweet collected at Thu Aug 23 16:04:07 +0000 2018
# Tweet collected at Thu Aug 23 16:04:07 +0000 2018
# Tweet collected at Thu Aug 23 16:04:07 +0000 2018
# Tweet collected at Thu Aug 23 16:04:08 +0000 2018
# Tweet collected at Thu Aug 23 16:04:13 +0000 2018
# Tweet collected at Thu Aug 23 16:04:13 +0000 2018
# Tweet collected at Thu Aug 23 16:04:16 +0000 2018
# Tweet collected at Thu Aug 23 16:04:17 +0000 2018
# Tweet collected at Thu Aug 23 16:04:17 +0000 2018
# Tweet collected at Thu Aug 23 16:04:19 +0000 2018
# Tweet collected at Thu Aug 23 16:04:19 +0000 2018
# Tweet collected at Thu Aug 23 16:04:22 +0000 2018
# Tweet collected at Thu Aug 23 16:04:22 +0000 2018
# Tweet collected at Thu Aug 23 16:04:23 +0000 2018
# Tweet collected at Thu Aug 23 16:04:24 +0000 2018
# Tweet collected at Thu Aug 23 16:04:27 +0000 2018
# Tweet collected at Thu Aug 23 16:04:28 +0000 2018
# Tweet collected at Thu Aug 23 16:04:28 +0000 2018
# Tweet collected at Thu Aug 23 16:04:29 +0000 2018
# Tweet collected at Thu Aug 23 16:04:30 +0000 2018
# Tweet collected at Thu Aug 23 16:04:31 +0000 2018
# Tweet collected at Thu Aug 23 16:04:31 +0000 2018
# Tweet collected at Thu Aug 23 16:04:32 +0000 2018
# Tweet collected at Thu Aug 23 16:04:35 +0000 2018
# Tweet collected at Thu Aug 23 16:04:37 +0000 2018
# Tweet collected at Thu Aug 23 16:04:39 +0000 2018
# Tweet collected at Thu Aug 23 16:04:40 +0000 2018
# Tweet collected at Thu Aug 23 16:04:42 +0000 2018
# Tweet collected at Thu Aug 23 16:04:42 +0000 2018
# Tweet collected at Thu Aug 23 16:04:45 +0000 2018
# Tweet collected at Thu Aug 23 16:04:48 +0000 2018
# Tweet collected at Thu Aug 23 16:04:49 +0000 2018
# Tweet collected at Thu Aug 23 16:04:51 +0000 2018
# Tweet collected at Thu Aug 23 16:04:54 +0000 2018
# Tweet collected at Thu Aug 23 16:04:55 +0000 2018
# Tweet collected at Thu Aug 23 16:04:57 +0000 2018
# Tweet collected at Thu Aug 23 16:04:58 +0000 2018
# Tweet collected at Thu Aug 23 16:05:00 +0000 2018
# Tweet collected at Thu Aug 23 16:05:02 +0000 2018
# Tweet collected at Thu Aug 23 16:05:02 +0000 2018
# Tweet collected at Thu Aug 23 16:05:04 +0000 2018
# Tweet collected at Thu Aug 23 16:05:04 +0000 2018
# Tweet collected at Thu Aug 23 16:05:05 +0000 2018
# Tweet collected at Thu Aug 23 16:05:06 +0000 2018
# Tweet collected at Thu Aug 23 16:05:06 +0000 2018
# Tweet collected at Thu Aug 23 16:05:06 +0000 2018
# Tweet collected at Thu Aug 23 16:05:07 +0000 2018
# Tweet collected at Thu Aug 23 16:05:08 +0000 2018
# Tweet collected at Thu Aug 23 16:05:09 +0000 2018
# Tweet collected at Thu Aug 23 16:05:09 +0000 2018
# Tweet collected at Thu Aug 23 16:05:09 +0000 2018
# Tweet collected at Thu Aug 23 16:05:10 +0000 2018
# Tweet collected at Thu Aug 23 16:05:10 +0000 2018
# Tweet collected at Thu Aug 23 16:05:10 +0000 2018
# Tweet collected at Thu Aug 23 16:05:11 +0000 2018
# Tweet collected at Thu Aug 23 16:05:11 +0000 2018
# Tweet collected at Thu Aug 23 16:05:11 +0000 2018
# Tweet collected at Thu Aug 23 16:05:11 +0000 2018
# Tweet collected at Thu Aug 23 16:05:11 +0000 2018
# Tweet collected at Thu Aug 23 16:05:12 +0000 2018
# Tweet collected at Thu Aug 23 16:05:12 +0000 2018
# Tweet collected at Thu Aug 23 16:05:12 +0000 2018
# Tweet collected at Thu Aug 23 16:05:12 +0000 2018
# Tweet collected at Thu Aug 23 16:05:13 +0000 2018
# Tweet collected at Thu Aug 23 16:05:16 +0000 2018
# Tweet collected at Thu Aug 23 16:05:16 +0000 2018
# Tweet collected at Thu Aug 23 16:05:17 +0000 2018
# Tweet collected at Thu Aug 23 16:05:17 +0000 2018
# Tweet collected at Thu Aug 23 16:05:20 +0000 2018
# Tweet collected at Thu Aug 23 16:05:20 +0000 2018
# Tweet collected at Thu Aug 23 16:05:20 +0000 2018
# Tweet collected at Thu Aug 23 16:05:22 +0000 2018
# Tweet collected at Thu Aug 23 16:05:23 +0000 2018
# Tweet collected at Thu Aug 23 16:05:22 +0000 2018
# Tweet collected at Thu Aug 23 16:05:24 +0000 2018
# Tweet collected at Thu Aug 23 16:05:23 +0000 2018
# Tweet collected at Thu Aug 23 16:05:26 +0000 2018
# Tweet collected at Thu Aug 23 16:05:27 +0000 2018
# Tweet collected at Thu Aug 23 16:05:27 +0000 2018
# Tweet collected at Thu Aug 23 16:05:31 +0000 2018
# Tweet collected at Thu Aug 23 16:05:32 +0000 2018
# Tweet collected at Thu Aug 23 16:05:32 +0000 2018
# Tweet collected at Thu Aug 23 16:05:32 +0000 2018
# Tweet collected at Thu Aug 23 16:05:33 +0000 2018
# Tweet collected at Thu Aug 23 16:05:35 +0000 2018
# Tweet collected at Thu Aug 23 16:05:37 +0000 2018
# Tweet collected at Thu Aug 23 16:05:37 +0000 2018
# Tweet collected at Thu Aug 23 16:05:39 +0000 2018
# Tweet collected at Thu Aug 23 16:05:40 +0000 2018
# Tweet collected at Thu Aug 23 16:05:43 +0000 2018
# Tweet collected at Thu Aug 23 16:05:43 +0000 2018
# Tweet collected at Thu Aug 23 16:05:45 +0000 2018
# Tweet collected at Thu Aug 23 16:05:45 +0000 2018
# Tweet collected at Thu Aug 23 16:05:47 +0000 2018
# Tweet collected at Thu Aug 23 16:05:47 +0000 2018
# Tweet collected at Thu Aug 23 16:05:50 +0000 2018
# Tweet collected at Thu Aug 23 16:05:50 +0000 2018
# Tweet collected at Thu Aug 23 16:05:51 +0000 2018
# Tweet collected at Thu Aug 23 16:05:53 +0000 2018
# Tweet collected at Thu Aug 23 16:05:53 +0000 2018
# Tweet collected at Thu Aug 23 16:05:53 +0000 2018
# Tweet collected at Thu Aug 23 16:05:55 +0000 2018
# Tweet collected at Thu Aug 23 16:05:59 +0000 2018
# Tweet collected at Thu Aug 23 16:06:00 +0000 2018
# Tweet collected at Thu Aug 23 16:06:01 +0000 2018
# Tweet collected at Thu Aug 23 16:06:01 +0000 2018
# Tweet collected at Thu Aug 23 16:06:01 +0000 2018
# Tweet collected at Thu Aug 23 16:06:01 +0000 2018
# Tweet collected at Thu Aug 23 16:06:02 +0000 2018
# Tweet collected at Thu Aug 23 16:06:02 +0000 2018
# Tweet collected at Thu Aug 23 16:06:02 +0000 2018
# Tweet collected at Thu Aug 23 16:06:03 +0000 2018
# Tweet collected at Thu Aug 23 16:06:05 +0000 2018
# Tweet collected at Thu Aug 23 16:06:05 +0000 2018
# Tweet collected at Thu Aug 23 16:06:06 +0000 2018
# Tweet collected at Thu Aug 23 16:06:06 +0000 2018
# Tweet collected at Thu Aug 23 16:06:06 +0000 2018
# Tweet collected at Thu Aug 23 16:06:07 +0000 2018
# Tweet collected at Thu Aug 23 16:06:08 +0000 2018
# Tweet collected at Thu Aug 23 16:06:08 +0000 2018
# Tweet collected at Thu Aug 23 16:06:08 +0000 2018
# Tweet collected at Thu Aug 23 16:06:09 +0000 2018
# Tweet collected at Thu Aug 23 16:06:11 +0000 2018
# Tweet collected at Thu Aug 23 16:06:13 +0000 2018
# Tweet collected at Thu Aug 23 16:06:14 +0000 2018
# Tweet collected at Thu Aug 23 16:06:16 +0000 2018
# Tweet collected at Thu Aug 23 16:06:16 +0000 2018
# Tweet collected at Thu Aug 23 16:06:17 +0000 2018
# Tweet collected at Thu Aug 23 16:06:18 +0000 2018
# Tweet collected at Thu Aug 23 16:06:19 +0000 2018
# Tweet collected at Thu Aug 23 16:06:20 +0000 2018
# Tweet collected at Thu Aug 23 16:06:22 +0000 2018
# Tweet collected at Thu Aug 23 16:06:25 +0000 2018
# Tweet collected at Thu Aug 23 16:06:27 +0000 2018
# Tweet collected at Thu Aug 23 16:06:32 +0000 2018
# Tweet collected at Thu Aug 23 16:06:34 +0000 2018
# Tweet collected at Thu Aug 23 16:06:35 +0000 2018
# Tweet collected at Thu Aug 23 16:06:38 +0000 2018
# Tweet collected at Thu Aug 23 16:06:40 +0000 2018
# Tweet collected at Thu Aug 23 16:06:40 +0000 2018
# Tweet collected at Thu Aug 23 16:06:44 +0000 2018
# Tweet collected at Thu Aug 23 16:06:44 +0000 2018
# Tweet collected at Thu Aug 23 16:06:45 +0000 2018
# Tweet collected at Thu Aug 23 16:06:45 +0000 2018
# Tweet collected at Thu Aug 23 16:06:45 +0000 2018
# Tweet collected at Thu Aug 23 16:06:47 +0000 2018
# Tweet collected at Thu Aug 23 16:06:47 +0000 2018
# Tweet collected at Thu Aug 23 16:06:47 +0000 2018
# Tweet collected at Thu Aug 23 16:06:47 +0000 2018
# Tweet collected at Thu Aug 23 16:06:49 +0000 2018
# Tweet collected at Thu Aug 23 16:06:49 +0000 2018
# Tweet collected at Thu Aug 23 16:06:51 +0000 2018
# Tweet collected at Thu Aug 23 16:06:51 +0000 2018
# Tweet collected at Thu Aug 23 16:06:51 +0000 2018
# Tweet collected at Thu Aug 23 16:06:53 +0000 2018
# Tweet collected at Thu Aug 23 16:06:53 +0000 2018
# Tweet collected at Thu Aug 23 16:06:58 +0000 2018
# ...
# Tweet collected at Thu Aug 23 16:31:58 +0000 2018
# Tweet collected at Thu Aug 23 16:31:59 +0000 2018
# Tweet collected at Thu Aug 23 16:32:01 +0000 2018
# Tweet collected at Thu Aug 23 16:32:01 +0000 2018
# Tweet collected at Thu Aug 23 16:32:01 +0000 2018
# Tweet collected at Thu Aug 23 16:32:03 +0000 2018
# Tweet collected at Thu Aug 23 16:32:03 +0000 2018
# Tweet collected at Thu Aug 23 16:32:04 +0000 2018
# Tweet collected at Thu Aug 23 16:32:04 +0000 2018
# Tweet collected at Thu Aug 23 16:32:05 +0000 2018
# Tweet collected at Thu Aug 23 16:32:06 +0000 2018
# Tweet collected at Thu Aug 23 16:32:06 +0000 2018
# Tweet collected at Thu Aug 23 16:32:07 +0000 2018
# Tweet collected at Thu Aug 23 16:32:08 +0000 2018
# Tweet collected at Thu Aug 23 16:32:11 +0000 2018
# Tweet collected at Thu Aug 23 16:32:13 +0000 2018
# Tweet collected at Thu Aug 23 16:32:14 +0000 2018
# Tweet collected at Thu Aug 23 16:32:14 +0000 2018
# Tweet collected at Thu Aug 23 16:32:15 +0000 2018
# Tweet collected at Thu Aug 23 16:32:16 +0000 2018
# Tweet collected at Thu Aug 23 16:32:16 +0000 2018
# Tweet collected at Thu Aug 23 16:32:16 +0000 2018
# Tweet collected at Thu Aug 23 16:32:18 +0000 2018
# Tweet collected at Thu Aug 23 16:32:18 +0000 2018
# Tweet collected at Thu Aug 23 16:32:18 +0000 2018
# Tweet collected at Thu Aug 23 16:32:24 +0000 2018
# Tweet collected at Thu Aug 23 16:32:24 +0000 2018
# Tweet collected at Thu Aug 23 16:32:25 +0000 2018
# Tweet collected at Thu Aug 23 16:32:25 +0000 2018
# Tweet collected at Thu Aug 23 16:32:26 +0000 2018
# Tweet collected at Thu Aug 23 16:32:27 +0000 2018
# Tweet collected at Thu Aug 23 16:32:27 +0000 2018
# Tweet collected at Thu Aug 23 16:32:29 +0000 2018
# Tweet collected at Thu Aug 23 16:32:30 +0000 2018
# Tweet collected at Thu Aug 23 16:32:30 +0000 2018
# Tweet collected at Thu Aug 23 16:32:31 +0000 2018
# Tweet collected at Thu Aug 23 16:32:32 +0000 2018
# Tweet collected at Thu Aug 23 16:32:33 +0000 2018
# Tweet collected at Thu Aug 23 16:32:33 +0000 2018
# Tweet collected at Thu Aug 23 16:32:34 +0000 2018
# Tweet collected at Thu Aug 23 16:32:35 +0000 2018
# Tweet collected at Thu Aug 23 16:32:36 +0000 2018
# Tweet collected at Thu Aug 23 16:32:36 +0000 2018
# Tweet collected at Thu Aug 23 16:32:37 +0000 2018
# Tweet collected at Thu Aug 23 16:32:38 +0000 2018
# Tweet collected at Thu Aug 23 16:32:38 +0000 2018
# Tweet collected at Thu Aug 23 16:32:39 +0000 2018
# Tweet collected at Thu Aug 23 16:32:39 +0000 2018
# Tweet collected at Thu Aug 23 16:32:39 +0000 2018
# Tweet collected at Thu Aug 23 16:32:40 +0000 2018
# Tweet collected at Thu Aug 23 16:32:40 +0000 2018
# Tweet collected at Thu Aug 23 16:32:42 +0000 2018
# Tweet collected at Thu Aug 23 16:32:43 +0000 2018
# Tweet collected at Thu Aug 23 16:32:43 +0000 2018
# Tweet collected at Thu Aug 23 16:32:43 +0000 2018
# Tweet collected at Thu Aug 23 16:32:44 +0000 2018
# Tweet collected at Thu Aug 23 16:32:44 +0000 2018
# Tweet collected at Thu Aug 23 16:32:44 +0000 2018
# Tweet collected at Thu Aug 23 16:32:45 +0000 2018
# Tweet collected at Thu Aug 23 16:32:45 +0000 2018
# Tweet collected at Thu Aug 23 16:32:46 +0000 2018
# Tweet collected at Thu Aug 23 16:32:49 +0000 2018
# Tweet collected at Thu Aug 23 16:32:50 +0000 2018
# Tweet collected at Thu Aug 23 16:32:51 +0000 2018
# Tweet collected at Thu Aug 23 16:32:51 +0000 2018
# Tweet collected at Thu Aug 23 16:32:52 +0000 2018
# Tweet collected at Thu Aug 23 16:32:52 +0000 2018
# Tweet collected at Thu Aug 23 16:32:53 +0000 2018
# Tweet collected at Thu Aug 23 16:32:55 +0000 2018
# Tweet collected at Thu Aug 23 16:32:55 +0000 2018
# Tweet collected at Thu Aug 23 16:32:56 +0000 2018
# Tweet collected at Thu Aug 23 16:32:57 +0000 2018
# Tweet collected at Thu Aug 23 16:32:57 +0000 2018
# Tweet collected at Thu Aug 23 16:32:57 +0000 2018
# Tweet collected at Thu Aug 23 16:32:59 +0000 2018
# Tweet collected at Thu Aug 23 16:33:00 +0000 2018
# Tweet collected at Thu Aug 23 16:33:00 +0000 2018
# Tweet collected at Thu Aug 23 16:33:00 +0000 2018
# Tweet collected at Thu Aug 23 16:33:01 +0000 2018
# Tweet collected at Thu Aug 23 16:33:03 +0000 2018
# Tweet collected at Thu Aug 23 16:33:04 +0000 2018
# Tweet collected at Thu Aug 23 16:33:04 +0000 2018
# Tweet collected at Thu Aug 23 16:33:06 +0000 2018
# Tweet collected at Thu Aug 23 16:33:07 +0000 2018
# Tweet collected at Thu Aug 23 16:33:10 +0000 2018
# Tweet collected at Thu Aug 23 16:33:12 +0000 2018
# Tweet collected at Thu Aug 23 16:33:13 +0000 2018
# Tweet collected at Thu Aug 23 16:33:13 +0000 2018
# Tweet collected at Thu Aug 23 16:33:13 +0000 2018
# Tweet collected at Thu Aug 23 16:33:15 +0000 2018
# Tweet collected at Thu Aug 23 16:33:18 +0000 2018
# Tweet collected at Thu Aug 23 16:33:18 +0000 2018
# Tweet collected at Thu Aug 23 16:33:19 +0000 2018
# Tweet collected at Thu Aug 23 16:33:19 +0000 2018
# Tweet collected at Thu Aug 23 16:33:19 +0000 2018
# Tweet collected at Thu Aug 23 16:33:19 +0000 2018
# Tweet collected at Thu Aug 23 16:33:20 +0000 2018
# Tweet collected at Thu Aug 23 16:33:20 +0000 2018
# Tweet collected at Thu Aug 23 16:33:22 +0000 2018
# Tweet collected at Thu Aug 23 16:33:22 +0000 2018
# Tweet collected at Thu Aug 23 16:33:23 +0000 2018
# Tweet collected at Thu Aug 23 16:33:23 +0000 2018
# Tweet collected at Thu Aug 23 16:33:23 +0000 2018
# Tweet collected at Thu Aug 23 16:33:23 +0000 2018
# Tweet collected at Thu Aug 23 16:33:23 +0000 2018
# Tweet collected at Thu Aug 23 16:33:23 +0000 2018
# Tweet collected at Thu Aug 23 16:33:24 +0000 2018
# Tweet collected at Thu Aug 23 16:33:25 +0000 2018
# Tweet collected at Thu Aug 23 16:33:27 +0000 2018
# Tweet collected at Thu Aug 23 16:33:29 +0000 2018
# Tweet collected at Thu Aug 23 16:33:29 +0000 2018
# Tweet collected at Thu Aug 23 16:33:31 +0000 2018
# Tweet collected at Thu Aug 23 16:33:31 +0000 2018
# Tweet collected at Thu Aug 23 16:33:32 +0000 2018
# Tweet collected at Thu Aug 23 16:33:33 +0000 2018
# Tweet collected at Thu Aug 23 16:33:36 +0000 2018
# Tweet collected at Thu Aug 23 16:33:39 +0000 2018
# Tweet collected at Thu Aug 23 16:33:39 +0000 2018
# Tweet collected at Thu Aug 23 16:33:40 +0000 2018
# Tweet collected at Thu Aug 23 16:33:41 +0000 2018
# Tweet collected at Thu Aug 23 16:33:41 +0000 2018
# Tweet collected at Thu Aug 23 16:33:45 +0000 2018
# Tweet collected at Thu Aug 23 16:33:45 +0000 2018
# Tweet collected at Thu Aug 23 16:33:48 +0000 2018
# Tweet collected at Thu Aug 23 16:33:52 +0000 2018
# Tweet collected at Thu Aug 23 16:33:54 +0000 2018
# Tweet collected at Thu Aug 23 16:33:54 +0000 2018
# Tweet collected at Thu Aug 23 16:33:56 +0000 2018
# Tweet collected at Thu Aug 23 16:33:56 +0000 2018
# Tweet collected at Thu Aug 23 16:33:57 +0000 2018
# Tweet collected at Thu Aug 23 16:33:57 +0000 2018
# Tweet collected at Thu Aug 23 16:33:58 +0000 2018
# Tweet collected at Thu Aug 23 16:33:59 +0000 2018
# Tweet collected at Thu Aug 23 16:33:59 +0000 2018
# Tweet collected at Thu Aug 23 16:34:00 +0000 2018
# Tweet collected at Thu Aug 23 16:34:01 +0000 2018
# Tweet collected at Thu Aug 23 16:34:01 +0000 2018
# Tweet collected at Thu Aug 23 16:34:03 +0000 2018
# Tweet collected at Thu Aug 23 16:34:02 +0000 2018
# Tweet collected at Thu Aug 23 16:34:04 +0000 2018
# Tweet collected at Thu Aug 23 16:34:04 +0000 2018
# Tweet collected at Thu Aug 23 16:34:05 +0000 2018
# Tweet collected at Thu Aug 23 16:34:05 +0000 2018
# Tweet collected at Thu Aug 23 16:34:06 +0000 2018
# Tweet collected at Thu Aug 23 16:34:08 +0000 2018
# Tweet collected at Thu Aug 23 16:34:08 +0000 2018
# Tweet collected at Thu Aug 23 16:34:09 +0000 2018
# Tweet collected at Thu Aug 23 16:34:11 +0000 2018
# Tweet collected at Thu Aug 23 16:34:11 +0000 2018
# Tweet collected at Thu Aug 23 16:34:12 +0000 2018
# Tweet collected at Thu Aug 23 16:34:13 +0000 2018
# Tweet collected at Thu Aug 23 16:34:13 +0000 2018
# Tweet collected at Thu Aug 23 16:34:14 +0000 2018
# Tweet collected at Thu Aug 23 16:34:15 +0000 2018
# Tweet collected at Thu Aug 23 16:34:16 +0000 2018
# Tweet collected at Thu Aug 23 16:34:19 +0000 2018
# Tweet collected at Thu Aug 23 16:34:20 +0000 2018
# Tweet collected at Thu Aug 23 16:34:24 +0000 2018
# Tweet collected at Thu Aug 23 16:34:25 +0000 2018
# Tweet collected at Thu Aug 23 16:34:28 +0000 2018
# Tweet collected at Thu Aug 23 16:34:29 +0000 2018
# Tweet collected at Thu Aug 23 16:34:29 +0000 2018
# Tweet collected at Thu Aug 23 16:34:29 +0000 2018
# Tweet collected at Thu Aug 23 16:34:30 +0000 2018
# Tweet collected at Thu Aug 23 16:34:30 +0000 2018
# Tweet collected at Thu Aug 23 16:34:35 +0000 2018
# Tweet collected at Thu Aug 23 16:34:36 +0000 2018
# Tweet collected at Thu Aug 23 16:34:38 +0000 2018
# Tweet collected at Thu Aug 23 16:34:38 +0000 2018
# Tweet collected at Thu Aug 23 16:34:40 +0000 2018
# Tweet collected at Thu Aug 23 16:34:40 +0000 2018
# Tweet collected at Thu Aug 23 16:34:40 +0000 2018
# Tweet collected at Thu Aug 23 16:34:41 +0000 2018
# Tweet collected at Thu Aug 23 16:34:41 +0000 2018
# Tweet collected at Thu Aug 23 16:34:42 +0000 2018
# Tweet collected at Thu Aug 23 16:34:43 +0000 2018
# Tweet collected at Thu Aug 23 16:34:43 +0000 2018
# Tweet collected at Thu Aug 23 16:34:44 +0000 2018
# Tweet collected at Thu Aug 23 16:34:45 +0000 2018
# Tweet collected at Thu Aug 23 16:34:49 +0000 2018
# Tweet collected at Thu Aug 23 16:34:52 +0000 2018
# Tweet collected at Thu Aug 23 16:34:55 +0000 2018
# Tweet collected at Thu Aug 23 16:34:55 +0000 2018
# Tweet collected at Thu Aug 23 16:34:55 +0000 2018
# Tweet collected at Thu Aug 23 16:34:55 +0000 2018
# Tweet collected at Thu Aug 23 16:34:55 +0000 2018
# Tweet collected at Thu Aug 23 16:34:58 +0000 2018
# Tweet collected at Thu Aug 23 16:34:59 +0000 2018
# Tweet collected at Thu Aug 23 16:35:00 +0000 2018
# Tweet collected at Thu Aug 23 16:35:00 +0000 2018
# Tweet collected at Thu Aug 23 16:35:00 +0000 2018
# Tweet collected at Thu Aug 23 16:35:00 +0000 2018
# Tweet collected at Thu Aug 23 16:35:02 +0000 2018
# Tweet collected at Thu Aug 23 16:35:02 +0000 2018
# Tweet collected at Thu Aug 23 16:35:03 +0000 2018
# Tweet collected at Thu Aug 23 16:35:06 +0000 2018
# Tweet collected at Thu Aug 23 16:35:06 +0000 2018
# Tweet collected at Thu Aug 23 16:35:06 +0000 2018
# Tweet collected at Thu Aug 23 16:35:07 +0000 2018
# Tweet collected at Thu Aug 23 16:35:07 +0000 2018
# Tweet collected at Thu Aug 23 16:35:07 +0000 2018
# Tweet collected at Thu Aug 23 16:35:08 +0000 2018
# Tweet collected at Thu Aug 23 16:35:08 +0000 2018
# Tweet collected at Thu Aug 23 16:35:10 +0000 2018
# Tweet collected at Thu Aug 23 16:35:11 +0000 2018
# Tweet collected at Thu Aug 23 16:35:10 +0000 2018
# Tweet collected at Thu Aug 23 16:35:11 +0000 2018
# Tweet collected at Thu Aug 23 16:35:11 +0000 2018
# Tweet collected at Thu Aug 23 16:35:12 +0000 2018
# Tweet collected at Thu Aug 23 16:35:12 +0000 2018
# Tweet collected at Thu Aug 23 16:35:13 +0000 2018
# Tweet collected at Thu Aug 23 16:35:15 +0000 2018
# Tweet collected at Thu Aug 23 16:35:15 +0000 2018
# Tweet collected at Thu Aug 23 16:35:17 +0000 2018
# Tweet collected at Thu Aug 23 16:35:17 +0000 2018
# Tweet collected at Thu Aug 23 16:35:18 +0000 2018
# Tweet collected at Thu Aug 23 16:35:18 +0000 2018
# Tweet collected at Thu Aug 23 16:35:18 +0000 2018
# Tweet collected at Thu Aug 23 16:35:19 +0000 2018
# Tweet collected at Thu Aug 23 16:35:19 +0000 2018
# Tweet collected at Thu Aug 23 16:35:19 +0000 2018
# Tweet collected at Thu Aug 23 16:35:19 +0000 2018
# Tweet collected at Thu Aug 23 16:35:20 +0000 2018
# Tweet collected at Thu Aug 23 16:35:21 +0000 2018
# Tweet collected at Thu Aug 23 16:35:21 +0000 2018
# Tweet collected at Thu Aug 23 16:35:22 +0000 2018
# Tweet collected at Thu Aug 23 16:35:25 +0000 2018
# Tweet collected at Thu Aug 23 16:35:25 +0000 2018
# Tweet collected at Thu Aug 23 16:35:26 +0000 2018
# Tweet collected at Thu Aug 23 16:35:26 +0000 2018
# Tweet collected at Thu Aug 23 16:35:26 +0000 2018
# Tweet collected at Thu Aug 23 16:35:28 +0000 2018
# Tweet collected at Thu Aug 23 16:35:28 +0000 2018
# Tweet collected at Thu Aug 23 16:35:30 +0000 2018
# Tweet collected at Thu Aug 23 16:35:31 +0000 2018
# Tweet collected at Thu Aug 23 16:35:31 +0000 2018
# Tweet collected at Thu Aug 23 16:35:32 +0000 2018
# Tweet collected at Thu Aug 23 16:35:32 +0000 2018
# Tweet collected at Thu Aug 23 16:35:33 +0000 2018
# Tweet collected at Thu Aug 23 16:35:35 +0000 2018
# Tweet collected at Thu Aug 23 16:35:36 +0000 2018
# Tweet collected at Thu Aug 23 16:35:37 +0000 2018
# Tweet collected at Thu Aug 23 16:35:38 +0000 2018
# Tweet collected at Thu Aug 23 16:35:38 +0000 2018
# Tweet collected at Thu Aug 23 16:35:39 +0000 2018
# Tweet collected at Thu Aug 23 16:35:42 +0000 2018
# Tweet collected at Thu Aug 23 16:35:43 +0000 2018
# Tweet collected at Thu Aug 23 16:35:44 +0000 2018
# Tweet collected at Thu Aug 23 16:35:44 +0000 2018
# Tweet collected at Thu Aug 23 16:35:46 +0000 2018
# Tweet collected at Thu Aug 23 16:35:48 +0000 2018
# Tweet collected at Thu Aug 23 16:35:48 +0000 2018
# Tweet collected at Thu Aug 23 16:35:49 +0000 2018
# Tweet collected at Thu Aug 23 16:35:50 +0000 2018
# Tweet collected at Thu Aug 23 16:35:51 +0000 2018
# Tweet collected at Thu Aug 23 16:35:52 +0000 2018
# Tweet collected at Thu Aug 23 16:35:52 +0000 2018
# Tweet collected at Thu Aug 23 16:35:54 +0000 2018
# Tweet collected at Thu Aug 23 16:35:54 +0000 2018
# Tweet collected at Thu Aug 23 16:35:55 +0000 2018
# Tweet collected at Thu Aug 23 16:35:57 +0000 2018
# Tweet collected at Thu Aug 23 16:35:58 +0000 2018
# Tweet collected at Thu Aug 23 16:35:59 +0000 2018
# Tweet collected at Thu Aug 23 16:36:02 +0000 2018
# Tweet collected at Thu Aug 23 16:36:02 +0000 2018
# Tweet collected at Thu Aug 23 16:36:02 +0000 2018
# Tweet collected at Thu Aug 23 16:36:02 +0000 2018
# Tweet collected at Thu Aug 23 16:36:03 +0000 2018
# Tweet collected at Thu Aug 23 16:36:08 +0000 2018
# Tweet collected at Thu Aug 23 16:36:11 +0000 2018
# Tweet collected at Thu Aug 23 16:36:11 +0000 2018
# Tweet collected at Thu Aug 23 16:36:15 +0000 2018
# Tweet collected at Thu Aug 23 16:36:16 +0000 2018
# Tweet collected at Thu Aug 23 16:36:19 +0000 2018
# Tweet collected at Thu Aug 23 16:36:26 +0000 2018
# Tweet collected at Thu Aug 23 16:36:26 +0000 2018
# Tweet collected at Thu Aug 23 16:36:24 +0000 2018
# Tweet collected at Thu Aug 23 16:36:26 +0000 2018
# Tweet collected at Thu Aug 23 16:36:27 +0000 2018
# Tweet collected at Thu Aug 23 16:36:28 +0000 2018
# Tweet collected at Thu Aug 23 16:36:28 +0000 2018
# Tweet collected at Thu Aug 23 16:36:30 +0000 2018
# Tweet collected at Thu Aug 23 16:36:32 +0000 2018
# Tweet collected at Thu Aug 23 16:36:32 +0000 2018
# Tweet collected at Thu Aug 23 16:36:34 +0000 2018
# Tweet collected at Thu Aug 23 16:36:34 +0000 2018
# Tweet collected at Thu Aug 23 16:36:34 +0000 2018
# Tweet collected at Thu Aug 23 16:36:37 +0000 2018
# Tweet collected at Thu Aug 23 16:36:41 +0000 2018
# Tweet collected at Thu Aug 23 16:36:44 +0000 2018
# Tweet collected at Thu Aug 23 16:36:48 +0000 2018
# Tweet collected at Thu Aug 23 16:36:48 +0000 2018
# Tweet collected at Thu Aug 23 16:36:48 +0000 2018
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-17600ade7044> in <module>()
#      56 streamer = tweepy.Stream(auth=auth, listener=listener)
#      57 print("Tracking: " + str(WORDS))
# ---> 58 streamer.filter(track=WORDS)
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding)
#     426         self.session.params = {'delimited': 'length'}
#     427         self.host = 'stream.twitter.com'
# --> 428         self._start(async)
#     429
#     430     def sitestream(self, follow, stall_warnings=False,
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     344             self._thread.start()
#     345         else:
# --> 346             self._run()
#     347
#     348     def on_closed(self, resp):
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in _run(self)
#     284             # call a handler first so that the exception can be logged.
#     285             self.listener.on_exception(exception)
# --> 286             raise
#     287
#     288     def _data(self, data):
#
# RuntimeError: No active exception to reraise
