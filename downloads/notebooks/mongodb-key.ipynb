# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)

# %%
from __future__ import print_function
import tweepy
import json
from pymongo import MongoClient
 
MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'
 
WORDS = ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
 
CONSUMER_KEY = "8hXSibjBqguYXf4vVNDliDCOY"
CONSUMER_SECRET = "fUwZ4PJbK8wwaTpF5uEz6xniac9P5ACzXIMsk7pCSAiUHjViJA"
ACCESS_TOKEN = "2994396687-mpkDqjV6xQzfhtqvDncWy2JjAiORScTtbOOwRqD"
ACCESS_TOKEN_SECRET = "bfqOVgKhkW9r9fiRFNIGNp70Wottrc3E5zoBNCi7xthtQ"

# %% [markdown]
# ## MongoDB Example - reinsurance loss data analysis , JSON BLOB and read Twitter

# %% [markdown]
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# MongoDB is a document-oriented database. Instead of storing your data in tables made out of individual rows,
# like a relational database does, it stores your data in collections made out of individual documents.
# In MongoDB, a document is a big JSON blob with no particular format or schema.
#
# You can have all your data in one single collection.
#
# <!-- PELICAN_END_SUMMARY -->

# %% [markdown]
# **MongoDB Example**
# - Create a document styple data in MongoDB
#   - example: reinsurance treaty by reinsurer/year/treaty type
# - Create a document style data in MongoDB from Json API format
#   - example: realtime stock price and realtime sector data
# - Read Twitter data into MongoDB
#   - example : read twitter page about what type of insurance people are interesting buying

# %% [markdown]
# **Making a Connection with MongoClient**
# -  Below link is an introduction tutorial to working with MongoDB and PyMongo
# -  ref: http://api.mongodb.com/python/current/tutorial.html

# %%
# Making a Connection with MongoClient
# Import pymongo
import pymongo

# The first step when working with PyMongo is to create a MongoClient to the running mongod instance
from pymongo import MongoClient

# Connect on the default host and port.
client = MongoClient()

# We can also specify the host and port explicitly
client = MongoClient('localhost', 27017)

# %% [markdown]
# **Getting a Database**
# - A single instance of MongoDB can support multiple independent databases.
# - When working with PyMongo you access databases using attribute style access on MongoClient instances.
# - Database name can not use attribute style access (ie. test-data), but "test_data" is okay

# %%
# Set up a collection name "test_database" in MongoDB
db = client.test_database

collection = db.test_collection

collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test_database'), 'test_collection')

# %% [markdown]
# #### **Document - example: reinsurance treaty by reinsurer/year/treaty type**
# - Data in MongoDB is represented (and stored) using JSON-style documents.
# - In PyMongo we use dictionaries to represent documents.
# - As an example, the following dictionary might be used to represent a reinsurance treaty type by reinsurer and year.
# - Documents can contain native Python types (like datetime.datetime instances) which will be automatically converted to and from the appropriate BSON types.

# %%
import datetime
treaty = {"reinsurer": "AIG",
        "treaty": "XOL layer",
        "tags": ["reinsurer", "treaty", "year"],
        "date": datetime.datetime.utcnow()}

# %% [markdown]
# #### *Inserting a Document*
# - When a document is inserted a special key, "_id", is automatically added if the document doesn’t already contain an "_id" key.
# - The value of "_id" must be unique across the collection. insert_one() returns an instance of InsertOneResult.

# %%
# To insert a document into a collection we can use the insert_one() method:
treaties = db.treaties
treaty_id = treaties.insert_one(treaty).inserted_id
treaty_id
# Out:
# ObjectId('5b7ed794760df705188fc61f')

# %% [markdown]
# **After inserting the first document, the posts collection has actually been created on the server.**
# - We can verify this by listing all of the collections in our database:

# %%
db.list_collection_names()
# Out:
# ['census', 'stock_data', 'treaties']

# %%
treaty2 = {"reinsurer": "Swiss Re",
        "treaty": "Clash Layer",
        "tags": ["reinsurer", "treaty", "year"],
        "date": datetime.datetime.utcnow()}

treaty_id = treaties.insert_one(treaty2).inserted_id
treaty_id
# Out:
# ObjectId('5b7ed797760df705188fc620')

# %%
treaty3 = {"reinsurer": "Parter Re",
        "treaty": "XOL 2nd Layer",
        "tags": ["reinsurer", "treaty", "year"],
        "date": datetime.datetime.utcnow()}

treaty_id = treaties.insert_one(treaty3).inserted_id
treaty_id
# Out:
# ObjectId('5b7ed79a760df705188fc621')

# %% [markdown]
# #### * Getting a Single Document With find_one()*
# - The most basic type of query that can be performed in MongoDB is find_one().
# - This method returns a single document matching a query (or None if there are no matches).
# - It is useful when you know there is only one matching document, or
# - are only interested in the first match. Here we use find_one() to get the first document from the posts collection:

# %%
import pprint
pprint.pprint(treaties.find_one())
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}

# %%
pprint.pprint(treaties.find_one({"reinsurer": "AIG"}))
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}

# %%
pprint.pprint(treaties.find_one({"reinsurer": "ACE"}))
# Out:
# None

# %% [markdown]
# #### * Querying By ObjectId*
# - We can also find a post by its _id, which in our example is an ObjectId:

# %%
treaty_id  ##output is an object
# Out:
# ObjectId('5b7ed79a760df705188fc621')

# %%
pprint.pprint(treaties.find_one({"_id": treaty_id}))
# Out:
# {'_id': ObjectId('5b7ed79a760df705188fc621'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 46, 797000),
#  'reinsurer': 'Parter Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL 2nd Layer'}

# %% [markdown]
# #### * Note that an ObjectId is not the same as its string representation:*

# %%
treaty_id_as_str = str(treaty_id)
treaty_id_as_str  ## output is a string
# Out:
# '5b7ed79a760df705188fc621'

# %%
treaties.find_one({"_id": treaty_id_as_str}) # No result

# %% [markdown]
# **Bulk Inserts**
# - we can also perform bulk insert operations, by passing a list as the first argument to insert_many().
# - This will insert each document in the list, sending only a single command to the server.
# - New_treaty has a different “shape” than the other posts - there is no "tags" field and we’ve added a new field, "title".
# - This is what we mean when we say that MongoDB is schema-free.

# %%
# new_treaty has a different “shape” than the other posts 
# there is no "tags" field and we’ve added a new field, "retenion". 

new_treaty = [{"reinsurer": "AIG",
              "treaty": "XOL Layer 2018",
              "tags": ["bulk", "insert"],
              "date": datetime.datetime(2018, 11, 12, 11, 14)},
              {"reinsurer": "Munich Re",
               "treaty": "QS 2018",
               "retenion": "QS 20% for US business",
               "date": datetime.datetime(2018, 11, 10, 10, 45)}]

result = treaties.insert_many(new_treaty)
result.inserted_ids
# Out:
# [ObjectId('5b7ed7ad760df705188fc622'), ObjectId('5b7ed7ad760df705188fc623')]

# %% [markdown]
# *The result from insert_many() now returns two ObjectId instances, one for each inserted document.*

# %% [markdown]
# **Query data**
# - use find()
# - use find_one()

# %%
for treaty in treaties.find():
     pprint.pprint(treaty)
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7ed797760df705188fc620'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 43, 818000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'Clash Layer'}
# {'_id': ObjectId('5b7ed79a760df705188fc621'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 46, 797000),
#  'reinsurer': 'Parter Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL 2nd Layer'}
# {'_id': ObjectId('5b7ed7ad760df705188fc622'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b7ed7ad760df705188fc623'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}

# %%
# Use find() for query

# Find all treaty in the collection
# for treaty in treaties.find():
#      pprint.pprint(treaty)

# Find all reinsurer-AIG treaty:
for treaty in treaties.find({"reinsurer": "AIG"}):
    pprint.pprint(treaty)
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7ed7ad760df705188fc622'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}

# %%
# Find one reinsurer-AIG treaty:
pprint.pprint(treaties.find_one({"reinsurer": "AIG"}))
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}

# %% [markdown]
# #### * Counting*
# - If we just want to know how many documents match a query we can perform a count() operation instead of a full query.
# - We can get a count of all of the documents in a collection:

# %%
# How many AIG treaty?
treaties.count_documents(
  filter={"reinsurer": "AIG"} 
)


# How many treaties?
treaties.count_documents(
  filter={} 
)
# Out:
# 2
# 5

# %% [markdown]
# ** Range Queries**
# - MongoDB supports many different types of advanced queries.
# - As an example, lets perform a query where we limit results to treaties older than a certain date, but also sort the results by reinsurers

# %%
d = datetime.datetime(2018, 11, 12, 12)
for treaty in treaties.find({"date": {"$lt": d}}).sort("reinsurer"):
    pprint.pprint(treaty)
# Out:
# {'_id': ObjectId('5b7ed794760df705188fc61f'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 36, 898000),
#  'reinsurer': 'AIG',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL layer'}
# {'_id': ObjectId('5b7ed7ad760df705188fc622'),
#  'date': datetime.datetime(2018, 11, 12, 11, 14),
#  'reinsurer': 'AIG',
#  'tags': ['bulk', 'insert'],
#  'treaty': 'XOL Layer 2018'}
# {'_id': ObjectId('5b7ed7ad760df705188fc623'),
#  'date': datetime.datetime(2018, 11, 10, 10, 45),
#  'reinsurer': 'Munich Re',
#  'retenion': 'QS 20% for US business',
#  'treaty': 'QS 2018'}
# {'_id': ObjectId('5b7ed79a760df705188fc621'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 46, 797000),
#  'reinsurer': 'Parter Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'XOL 2nd Layer'}
# {'_id': ObjectId('5b7ed797760df705188fc620'),
#  'date': datetime.datetime(2018, 8, 23, 15, 49, 43, 818000),
#  'reinsurer': 'Swiss Re',
#  'tags': ['reinsurer', 'treaty', 'year'],
#  'treaty': 'Clash Layer'}

# %% [markdown]
# #### * Indexing*
# - Adding indexes can help accelerate certain queries and can also add additional functionality to querying and storing documents.
# - In this example, we’ll demonstrate how to create a unique index on a key that rejects documents whose value for that key already exists in the index.
# - First, we’ll need to create the index:

# %%
 result = db.profiles.create_index([('reinsurer_id', pymongo.ASCENDING)],
                                  unique=True)
 sorted(list(db.profiles.index_information()))
# Out:
# ['_id_', 'reinsurer_id_1']

# %% [markdown]
# **Notice that we have two indexes now**
# - one is the index on _id that MongoDB creates automatically,
# - and the other is the index on reinsurer_id we just created.

# %%
 # set up some user profiles
    
 user_profiles = [
     {'reinsurer_id': 228, 'reinsurer': 'Atlantic Re'},
     {'reinsurer_id': 235, 'reinsurer': 'XL Re'}]
 result = db.profiles.insert_many(user_profiles)

# %%
 # DuplicateKeyError: E11000 duplicate key error collection: test_database.profiles index: user_id_1 dup key: { : 235 }
 new_profile = {'user_id': 213, 'reinsurer': 'XL American'}
 duplicate_profile = {'user_id': 235, 'reinsurer': 'SCOR S.E'}
 result = db.profiles.insert_one(new_profile)  # This is fine.
 result = db.profiles.insert_one(duplicate_profile)

# %% [markdown]
# **Create a document style data in MongoDB from Json API format**
# - example: realtime intraday MSFT stock price
# - example: realtime sector stock return

# %%
realtime_stock_data={
"Meta Data": {
"1 Information": "Intraday (5min) open, high, low, close prices and volume",
"2 Symbol": "MSFT",
"3 Last Refreshed": "2018-08-22 15:55:00",
"4 Interval": "5min",
"5 Output Size": "Compact",
"6 Time Zone": "US/Eastern"
},
"Time Series (5min)": {
"2018-08-22 15:55:00": {
"1 open": "107.1500",
"2 high": "107.2100",
"3 low": "107.0500",
"4 close": "107.0500",
"5 volume": "970838"
}
}
}

# %%
stock_data = db.stock_data
stock_data_id = stock_data.insert_one(realtime_stock_data).inserted_id
stock_data_id
# Out:
# ObjectId('5b7efb1e760df705188fdd1a')

# %%
realtime_sector_data={
    "Meta Data": {
        "Information": "US Sector Performance (realtime & historical)",
        "Last Refreshed": "02:05 PM ET 08/23/2018"
    },
    "Rank A: Real-Time Performance": {
        "Information Technology": "0.51%",
        "Consumer Discretionary": "-0.04%",
        "Utilities": "-0.11%",
        "Telecommunication Services": "-0.13%",
        "Health Care": "-0.20%",
        "Real Estate": "-0.25%",
        "Consumer Staples": "-0.27%",
        "Industrials": "-0.48%",
        "Financials": "-0.54%",
        "Energy": "-0.57%",
        "Materials": "-0.86%"
    },
    "Rank B: 1 Day Performance": {
        "Energy": "1.20%",
        "Information Technology": "0.48%",
        "Consumer Discretionary": "0.12%",
        "Health Care": "0.11%",
        "Financials": "-0.26%",
        "Materials": "-0.45%",
        "Consumer Staples": "-0.63%",
        "Real Estate": "-0.65%",
        "Utilities": "-0.78%",
        "Industrials": "-0.93%",
        "Telecommunication Services": "-2.02%"
    },
    "Rank C: 5 Day Performance": {
        "Energy": "3.27%",
        "Industrials": "2.23%",
        "Consumer Discretionary": "2.21%",
        "Materials": "2.02%",
        "Financials": "1.93%",
        "Health Care": "1.71%",
        "Telecommunication Services": "1.09%",
        "Information Technology": "0.84%",
        "Consumer Staples": "0.76%",
        "Real Estate": "0.16%",
        "Utilities": "-0.35%"
    },
    "Rank D: 1 Month Performance": {
        "Telecommunication Services": "6.53%",
        "Health Care": "5.38%",
        "Industrials": "2.75%",
        "Real Estate": "2.62%",
        "Consumer Staples": "2.57%",
        "Financials": "2.45%",
        "Utilities": "1.92%",
        "Consumer Discretionary": "1.90%",
        "Materials": "0.90%",
        "Information Technology": "0.57%",
        "Energy": "-1.17%"
    },
    "Rank E: 3 Month Performance": {
        "Health Care": "9.80%",
        "Consumer Staples": "9.18%",
        "Utilities": "8.72%",
        "Consumer Discretionary": "8.41%",
        "Real Estate": "8.28%",
        "Telecommunication Services": "6.02%",
        "Information Technology": "5.55%",
        "Financials": "0.49%",
        "Industrials": "0.15%",
        "Materials": "-2.15%",
        "Energy": "-5.60%"
    },
    "Rank F: Year-to-Date (YTD) Performance": {
        "Information Technology": "16.10%",
        "Consumer Discretionary": "15.79%",
        "Health Care": "10.55%",
        "Energy": "2.53%",
        "Financials": "1.05%",
        "Utilities": "1.04%",
        "Real Estate": "0.96%",
        "Industrials": "0.75%",
        "Materials": "-2.75%",
        "Consumer Staples": "-5.33%",
        "Telecommunication Services": "-6.21%"
    },
    "Rank G: 1 Year Performance": {
        "Information Technology": "31.09%",
        "Consumer Discretionary": "29.36%",
        "Energy": "20.32%",
        "Health Care": "16.84%",
        "Financials": "15.29%",
        "Industrials": "12.18%",
        "Materials": "9.50%",
        "Real Estate": "3.09%",
        "Telecommunication Services": "-0.85%",
        "Utilities": "-2.24%",
        "Consumer Staples": "-2.32%"
    },
    "Rank H: 3 Year Performance": {
        "Information Technology": "95.67%",
        "Consumer Discretionary": "54.45%",
        "Financials": "46.80%",
        "Industrials": "45.21%",
        "Materials": "36.15%",
        "Health Care": "27.81%",
        "Utilities": "18.65%",
        "Energy": "18.31%",
        "Consumer Staples": "13.63%",
        "Telecommunication Services": "5.73%"
    },
    "Rank I: 5 Year Performance": {
        "Information Technology": "151.29%",
        "Consumer Discretionary": "98.24%",
        "Health Care": "85.23%",
        "Financials": "75.87%",
        "Industrials": "67.23%",
        "Materials": "45.10%",
        "Utilities": "43.92%",
        "Consumer Staples": "35.93%",
        "Telecommunication Services": "4.47%",
        "Energy": "-6.33%"
    },
    "Rank J: 10 Year Performance": {
        "Consumer Discretionary": "284.77%",
        "Information Technology": "252.24%",
        "Health Care": "176.38%",
        "Industrials": "107.68%",
        "Consumer Staples": "90.16%",
        "Financials": "74.45%",
        "Materials": "50.53%",
        "Utilities": "41.62%",
        "Telecommunication Services": "21.26%",
        "Energy": "-3.80%"
    }
}

# %%
sector_data = db.sector_data
sector_data_id = sector_data.insert_one(realtime_sector_data).inserted_id
sector_data_id
# Out:
# ObjectId('5b7efb26760df705188fdd1b')

# %% [markdown]
# **Below is the screenshot of MongoDB structures from GUI tool Robo 3T showing list of dataset**
# <img src="/images/MongoDB1.png" alt="[img: MongoDB view]" title="MongoDB View" />

# %%
# !pwd
# Out:
# /c/data/jasmin/jasminblog/content/downloads/notebooks

# %% [markdown]
# **Collect data from Twitter into MongoDB**
# - ref:  http://pythondata.com/collecting-storing-tweets-with-python-and-mongodb/

# %%
from __future__ import print_function
import tweepy
import json
from pymongo import MongoClient
 
MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'
 
WORDS = ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
 
# CONSUMER_KEY = "your key"
# CONSUMER_SECRET = "your secret"
# ACCESS_TOKEN = "your token"
# ACCESS_TOKEN_SECRET = "your token secret"
 
 
class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 
 
    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
 
    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False
 
    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
            client = MongoClient(MONGO_HOST)
            
            # Use twitterdb database. If it doesn't exist, it will be created.
            db = client.twitterdb
    
            # Decode the JSON from Twitter
            datajson = json.loads(data)
            
            #grab the 'created_at' data from the Tweet to use for display
            created_at = datajson['created_at']
 
            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(created_at))
            
            #insert the data into the mongoDB into a collection called twitter_search
            #if twitter_search doesn't exist, it will be created.
            db.twitter_search.insert(datajson)
        except Exception as e:
           print(e)
 
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)
# Out:
# Tracking: ['#insurance', '#AI', '#datascience', '#machinelearning', '#auto', '#reinsurance']
# You are now connected to the streaming API.
# Tweet collected at Thu Aug 23 18:54:40 +0000 2018
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:48: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Tweet collected at Thu Aug 23 18:54:46 +0000 2018
# Tweet collected at Thu Aug 23 18:54:47 +0000 2018
# Tweet collected at Thu Aug 23 18:54:49 +0000 2018
# Tweet collected at Thu Aug 23 18:54:52 +0000 2018
# Tweet collected at Thu Aug 23 18:54:55 +0000 2018
# Tweet collected at Thu Aug 23 18:54:55 +0000 2018
# Tweet collected at Thu Aug 23 18:54:57 +0000 2018
# Tweet collected at Thu Aug 23 18:54:58 +0000 2018
# Tweet collected at Thu Aug 23 18:55:00 +0000 2018
# Tweet collected at Thu Aug 23 18:55:00 +0000 2018
# Tweet collected at Thu Aug 23 18:55:00 +0000 2018
# Tweet collected at Thu Aug 23 18:55:01 +0000 2018
# Tweet collected at Thu Aug 23 18:55:02 +0000 2018
# Tweet collected at Thu Aug 23 18:55:05 +0000 2018
# Tweet collected at Thu Aug 23 18:55:06 +0000 2018
# Tweet collected at Thu Aug 23 18:55:06 +0000 2018
# Tweet collected at Thu Aug 23 18:55:07 +0000 2018
# Tweet collected at Thu Aug 23 18:55:07 +0000 2018
# Tweet collected at Thu Aug 23 18:55:06 +0000 2018
# Tweet collected at Thu Aug 23 18:55:07 +0000 2018
# Tweet collected at Thu Aug 23 18:55:08 +0000 2018
# Tweet collected at Thu Aug 23 18:55:09 +0000 2018
# Tweet collected at Thu Aug 23 18:55:13 +0000 2018
# Tweet collected at Thu Aug 23 18:55:14 +0000 2018
# Tweet collected at Thu Aug 23 18:55:14 +0000 2018
# Tweet collected at Thu Aug 23 18:55:15 +0000 2018
# Tweet collected at Thu Aug 23 18:55:19 +0000 2018
# Tweet collected at Thu Aug 23 18:55:22 +0000 2018
# Tweet collected at Thu Aug 23 18:55:24 +0000 2018
# Tweet collected at Thu Aug 23 18:55:25 +0000 2018
# Tweet collected at Thu Aug 23 18:55:26 +0000 2018
# Tweet collected at Thu Aug 23 18:55:27 +0000 2018
# Tweet collected at Thu Aug 23 18:55:33 +0000 2018
# Tweet collected at Thu Aug 23 18:55:39 +0000 2018
# Tweet collected at Thu Aug 23 18:55:43 +0000 2018
# Tweet collected at Thu Aug 23 18:55:45 +0000 2018
# Tweet collected at Thu Aug 23 18:55:50 +0000 2018
# Tweet collected at Thu Aug 23 18:55:51 +0000 2018
# Tweet collected at Thu Aug 23 18:55:53 +0000 2018
# Tweet collected at Thu Aug 23 18:55:53 +0000 2018
# Tweet collected at Thu Aug 23 18:55:56 +0000 2018
# Tweet collected at Thu Aug 23 18:55:57 +0000 2018
# Tweet collected at Thu Aug 23 18:55:58 +0000 2018
# Tweet collected at Thu Aug 23 18:56:01 +0000 2018
# Tweet collected at Thu Aug 23 18:56:01 +0000 2018
# Tweet collected at Thu Aug 23 18:56:02 +0000 2018
# Tweet collected at Thu Aug 23 18:56:03 +0000 2018
# Tweet collected at Thu Aug 23 18:56:04 +0000 2018
# Tweet collected at Thu Aug 23 18:56:04 +0000 2018
# Tweet collected at Thu Aug 23 18:56:07 +0000 2018
# Tweet collected at Thu Aug 23 18:56:10 +0000 2018
# Tweet collected at Thu Aug 23 18:56:12 +0000 2018
# Tweet collected at Thu Aug 23 18:56:14 +0000 2018
# Tweet collected at Thu Aug 23 18:56:14 +0000 2018
# Tweet collected at Thu Aug 23 18:56:14 +0000 2018
# Tweet collected at Thu Aug 23 18:56:16 +0000 2018
# Tweet collected at Thu Aug 23 18:56:19 +0000 2018
# Tweet collected at Thu Aug 23 18:56:21 +0000 2018
# Tweet collected at Thu Aug 23 18:56:22 +0000 2018
# Tweet collected at Thu Aug 23 18:56:24 +0000 2018
# Tweet collected at Thu Aug 23 18:56:29 +0000 2018
# Tweet collected at Thu Aug 23 18:56:31 +0000 2018
# Tweet collected at Thu Aug 23 18:56:32 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:35 +0000 2018
# Tweet collected at Thu Aug 23 18:56:34 +0000 2018
# Tweet collected at Thu Aug 23 18:56:35 +0000 2018
# Tweet collected at Thu Aug 23 18:56:35 +0000 2018
# Tweet collected at Thu Aug 23 18:56:35 +0000 2018
# Tweet collected at Thu Aug 23 18:56:36 +0000 2018
# Tweet collected at Thu Aug 23 18:56:37 +0000 2018
# Tweet collected at Thu Aug 23 18:56:37 +0000 2018
# Tweet collected at Thu Aug 23 18:56:37 +0000 2018
# Tweet collected at Thu Aug 23 18:56:38 +0000 2018
# Tweet collected at Thu Aug 23 18:56:40 +0000 2018
# Tweet collected at Thu Aug 23 18:56:40 +0000 2018
# Tweet collected at Thu Aug 23 18:56:43 +0000 2018
# Tweet collected at Thu Aug 23 18:56:45 +0000 2018
# Tweet collected at Thu Aug 23 18:56:46 +0000 2018
# Tweet collected at Thu Aug 23 18:56:48 +0000 2018
# Tweet collected at Thu Aug 23 18:56:48 +0000 2018
# Tweet collected at Thu Aug 23 18:56:53 +0000 2018
# Tweet collected at Thu Aug 23 18:56:54 +0000 2018
# Tweet collected at Thu Aug 23 18:56:56 +0000 2018
# Tweet collected at Thu Aug 23 18:56:58 +0000 2018
# Tweet collected at Thu Aug 23 18:56:59 +0000 2018
# Tweet collected at Thu Aug 23 18:57:01 +0000 2018
# Tweet collected at Thu Aug 23 18:57:04 +0000 2018
# Tweet collected at Thu Aug 23 18:57:03 +0000 2018
# Tweet collected at Thu Aug 23 18:57:09 +0000 2018
# Tweet collected at Thu Aug 23 18:57:12 +0000 2018
# Tweet collected at Thu Aug 23 18:57:15 +0000 2018
# Tweet collected at Thu Aug 23 18:57:16 +0000 2018
# Tweet collected at Thu Aug 23 18:57:16 +0000 2018
# Tweet collected at Thu Aug 23 18:57:16 +0000 2018
# Tweet collected at Thu Aug 23 18:57:17 +0000 2018
# Tweet collected at Thu Aug 23 18:57:18 +0000 2018
# Tweet collected at Thu Aug 23 18:57:20 +0000 2018
# Tweet collected at Thu Aug 23 18:57:21 +0000 2018
# Tweet collected at Thu Aug 23 18:57:22 +0000 2018
# Tweet collected at Thu Aug 23 18:57:25 +0000 2018
# Tweet collected at Thu Aug 23 18:57:31 +0000 2018
# Tweet collected at Thu Aug 23 18:57:32 +0000 2018
# Tweet collected at Thu Aug 23 18:57:33 +0000 2018
# Tweet collected at Thu Aug 23 18:57:33 +0000 2018
# Tweet collected at Thu Aug 23 18:57:33 +0000 2018
# Tweet collected at Thu Aug 23 18:57:34 +0000 2018
# Tweet collected at Thu Aug 23 18:57:35 +0000 2018
# Tweet collected at Thu Aug 23 18:57:38 +0000 2018
# Tweet collected at Thu Aug 23 18:57:38 +0000 2018
# Tweet collected at Thu Aug 23 18:57:38 +0000 2018
# Tweet collected at Thu Aug 23 18:57:38 +0000 2018
# Tweet collected at Thu Aug 23 18:57:39 +0000 2018
# Tweet collected at Thu Aug 23 18:57:40 +0000 2018
# Tweet collected at Thu Aug 23 18:57:41 +0000 2018
# Tweet collected at Thu Aug 23 18:57:42 +0000 2018
# Tweet collected at Thu Aug 23 18:57:43 +0000 2018
# Tweet collected at Thu Aug 23 18:57:43 +0000 2018
# Tweet collected at Thu Aug 23 18:57:43 +0000 2018
# Tweet collected at Thu Aug 23 18:57:43 +0000 2018
# Tweet collected at Thu Aug 23 18:57:43 +0000 2018
# Tweet collected at Thu Aug 23 18:57:46 +0000 2018
# Tweet collected at Thu Aug 23 18:57:47 +0000 2018
# Tweet collected at Thu Aug 23 18:57:48 +0000 2018
# Tweet collected at Thu Aug 23 18:57:49 +0000 2018
# Tweet collected at Thu Aug 23 18:57:50 +0000 2018
# Tweet collected at Thu Aug 23 18:57:52 +0000 2018
# Tweet collected at Thu Aug 23 18:57:55 +0000 2018
# Tweet collected at Thu Aug 23 18:57:56 +0000 2018
# Tweet collected at Thu Aug 23 18:57:56 +0000 2018
# Tweet collected at Thu Aug 23 18:57:56 +0000 2018
# Tweet collected at Thu Aug 23 18:57:58 +0000 2018
# Tweet collected at Thu Aug 23 18:57:59 +0000 2018
# Tweet collected at Thu Aug 23 18:57:58 +0000 2018
# Tweet collected at Thu Aug 23 18:58:00 +0000 2018
# Tweet collected at Thu Aug 23 18:57:59 +0000 2018
# Tweet collected at Thu Aug 23 18:58:00 +0000 2018
# Tweet collected at Thu Aug 23 18:58:01 +0000 2018
# Tweet collected at Thu Aug 23 18:58:02 +0000 2018
# Tweet collected at Thu Aug 23 18:58:02 +0000 2018
# Tweet collected at Thu Aug 23 18:58:02 +0000 2018
# Tweet collected at Thu Aug 23 18:58:03 +0000 2018
# Tweet collected at Thu Aug 23 18:58:03 +0000 2018
# Tweet collected at Thu Aug 23 18:58:04 +0000 2018
# Tweet collected at Thu Aug 23 18:58:04 +0000 2018
# Tweet collected at Thu Aug 23 18:58:05 +0000 2018
# Tweet collected at Thu Aug 23 18:58:07 +0000 2018
# Tweet collected at Thu Aug 23 18:58:09 +0000 2018
# Tweet collected at Thu Aug 23 18:58:10 +0000 2018
# Tweet collected at Thu Aug 23 18:58:10 +0000 2018
# Tweet collected at Thu Aug 23 18:58:11 +0000 2018
# Tweet collected at Thu Aug 23 18:58:11 +0000 2018
# Tweet collected at Thu Aug 23 18:58:12 +0000 2018
# Tweet collected at Thu Aug 23 18:58:15 +0000 2018
# Tweet collected at Thu Aug 23 18:58:15 +0000 2018
# Tweet collected at Thu Aug 23 18:58:16 +0000 2018
# Tweet collected at Thu Aug 23 18:58:21 +0000 2018
# Tweet collected at Thu Aug 23 18:58:21 +0000 2018
# Tweet collected at Thu Aug 23 18:58:21 +0000 2018
# Tweet collected at Thu Aug 23 18:58:22 +0000 2018
# Tweet collected at Thu Aug 23 18:58:25 +0000 2018
# Tweet collected at Thu Aug 23 18:58:26 +0000 2018
# Tweet collected at Thu Aug 23 18:58:28 +0000 2018
# Tweet collected at Thu Aug 23 18:58:30 +0000 2018
# Tweet collected at Thu Aug 23 18:58:31 +0000 2018
# Tweet collected at Thu Aug 23 18:58:31 +0000 2018
# Tweet collected at Thu Aug 23 18:58:31 +0000 2018
# Tweet collected at Thu Aug 23 18:58:32 +0000 2018
# Tweet collected at Thu Aug 23 18:58:33 +0000 2018
# Tweet collected at Thu Aug 23 18:58:36 +0000 2018
# Tweet collected at Thu Aug 23 18:58:37 +0000 2018
# Tweet collected at Thu Aug 23 18:58:38 +0000 2018
# Tweet collected at Thu Aug 23 18:58:38 +0000 2018
# Tweet collected at Thu Aug 23 18:58:38 +0000 2018
# Tweet collected at Thu Aug 23 18:58:41 +0000 2018
# Tweet collected at Thu Aug 23 18:58:41 +0000 2018
# Tweet collected at Thu Aug 23 18:58:42 +0000 2018
# Tweet collected at Thu Aug 23 18:58:43 +0000 2018
# Tweet collected at Thu Aug 23 18:58:44 +0000 2018
# Tweet collected at Thu Aug 23 18:58:45 +0000 2018
# Tweet collected at Thu Aug 23 18:58:45 +0000 2018
# Tweet collected at Thu Aug 23 18:58:51 +0000 2018
# Tweet collected at Thu Aug 23 18:58:55 +0000 2018
# Tweet collected at Thu Aug 23 18:59:00 +0000 2018
# Tweet collected at Thu Aug 23 18:59:01 +0000 2018
# Tweet collected at Thu Aug 23 18:59:02 +0000 2018
# Tweet collected at Thu Aug 23 18:59:05 +0000 2018
# Tweet collected at Thu Aug 23 18:59:05 +0000 2018
# Tweet collected at Thu Aug 23 18:59:08 +0000 2018
# Tweet collected at Thu Aug 23 18:59:11 +0000 2018
# Tweet collected at Thu Aug 23 18:59:11 +0000 2018
# Tweet collected at Thu Aug 23 18:59:12 +0000 2018
# Tweet collected at Thu Aug 23 18:59:15 +0000 2018
# Tweet collected at Thu Aug 23 18:59:15 +0000 2018
# Tweet collected at Thu Aug 23 18:59:16 +0000 2018
# Tweet collected at Thu Aug 23 18:59:21 +0000 2018
# Tweet collected at Thu Aug 23 18:59:21 +0000 2018
# Tweet collected at Thu Aug 23 18:59:24 +0000 2018
# Tweet collected at Thu Aug 23 18:59:26 +0000 2018
# Tweet collected at Thu Aug 23 18:59:26 +0000 2018
# Tweet collected at Thu Aug 23 18:59:27 +0000 2018
# Tweet collected at Thu Aug 23 18:59:29 +0000 2018
# Tweet collected at Thu Aug 23 18:59:30 +0000 2018
# Tweet collected at Thu Aug 23 18:59:30 +0000 2018
# Tweet collected at Thu Aug 23 18:59:31 +0000 2018
# Tweet collected at Thu Aug 23 18:59:31 +0000 2018
# Tweet collected at Thu Aug 23 18:59:32 +0000 2018
# Tweet collected at Thu Aug 23 18:59:34 +0000 2018
# Tweet collected at Thu Aug 23 18:59:34 +0000 2018
# Tweet collected at Thu Aug 23 18:59:35 +0000 2018
# Tweet collected at Thu Aug 23 18:59:37 +0000 2018
# Tweet collected at Thu Aug 23 18:59:38 +0000 2018
# Tweet collected at Thu Aug 23 18:59:39 +0000 2018
# Tweet collected at Thu Aug 23 18:59:41 +0000 2018
# Tweet collected at Thu Aug 23 18:59:42 +0000 2018
# Tweet collected at Thu Aug 23 18:59:44 +0000 2018
# Tweet collected at Thu Aug 23 18:59:50 +0000 2018
# Tweet collected at Thu Aug 23 18:59:52 +0000 2018
# Tweet collected at Thu Aug 23 18:59:54 +0000 2018
# Tweet collected at Thu Aug 23 18:59:55 +0000 2018
# Tweet collected at Thu Aug 23 18:59:58 +0000 2018
# Tweet collected at Thu Aug 23 18:59:59 +0000 2018
# Tweet collected at Thu Aug 23 19:00:00 +0000 2018
# Tweet collected at Thu Aug 23 19:00:00 +0000 2018
# Tweet collected at Thu Aug 23 19:00:00 +0000 2018
# Tweet collected at Thu Aug 23 19:00:00 +0000 2018
# Tweet collected at Thu Aug 23 19:00:00 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:00 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:02 +0000 2018
# Tweet collected at Thu Aug 23 19:00:02 +0000 2018
# Tweet collected at Thu Aug 23 19:00:02 +0000 2018
# Tweet collected at Thu Aug 23 19:00:01 +0000 2018
# Tweet collected at Thu Aug 23 19:00:02 +0000 2018
# Tweet collected at Thu Aug 23 19:00:03 +0000 2018
# Tweet collected at Thu Aug 23 19:00:04 +0000 2018
# Tweet collected at Thu Aug 23 19:00:03 +0000 2018
# Tweet collected at Thu Aug 23 19:00:04 +0000 2018
# Tweet collected at Thu Aug 23 19:00:05 +0000 2018
# Tweet collected at Thu Aug 23 19:00:05 +0000 2018
# Tweet collected at Thu Aug 23 19:00:05 +0000 2018
# Tweet collected at Thu Aug 23 19:00:05 +0000 2018
# Tweet collected at Thu Aug 23 19:00:06 +0000 2018
# Tweet collected at Thu Aug 23 19:00:07 +0000 2018
# Tweet collected at Thu Aug 23 19:00:07 +0000 2018
# Tweet collected at Thu Aug 23 19:00:07 +0000 2018
# Tweet collected at Thu Aug 23 19:00:07 +0000 2018
# Tweet collected at Thu Aug 23 19:00:08 +0000 2018
# Tweet collected at Thu Aug 23 19:00:08 +0000 2018
# Tweet collected at Thu Aug 23 19:00:09 +0000 2018
# Tweet collected at Thu Aug 23 19:00:10 +0000 2018
# Tweet collected at Thu Aug 23 19:00:10 +0000 2018
# Tweet collected at Thu Aug 23 19:00:12 +0000 2018
# Tweet collected at Thu Aug 23 19:00:12 +0000 2018
# Tweet collected at Thu Aug 23 19:00:13 +0000 2018
# Tweet collected at Thu Aug 23 19:00:13 +0000 2018
# Tweet collected at Thu Aug 23 19:00:13 +0000 2018
# Tweet collected at Thu Aug 23 19:00:14 +0000 2018
# Tweet collected at Thu Aug 23 19:00:14 +0000 2018
# Tweet collected at Thu Aug 23 19:00:14 +0000 2018
# Tweet collected at Thu Aug 23 19:00:14 +0000 2018
# Tweet collected at Thu Aug 23 19:00:14 +0000 2018
# Tweet collected at Thu Aug 23 19:00:14 +0000 2018
# Tweet collected at Thu Aug 23 19:00:15 +0000 2018
# Tweet collected at Thu Aug 23 19:00:15 +0000 2018
# Tweet collected at Thu Aug 23 19:00:15 +0000 2018
# Tweet collected at Thu Aug 23 19:00:16 +0000 2018
# Tweet collected at Thu Aug 23 19:00:18 +0000 2018
# Tweet collected at Thu Aug 23 19:00:21 +0000 2018
# Tweet collected at Thu Aug 23 19:00:21 +0000 2018
# Tweet collected at Thu Aug 23 19:00:22 +0000 2018
# Tweet collected at Thu Aug 23 19:00:22 +0000 2018
# Tweet collected at Thu Aug 23 19:00:23 +0000 2018
# Tweet collected at Thu Aug 23 19:00:24 +0000 2018
# Tweet collected at Thu Aug 23 19:00:25 +0000 2018
# Tweet collected at Thu Aug 23 19:00:26 +0000 2018
# Tweet collected at Thu Aug 23 19:00:27 +0000 2018
# Tweet collected at Thu Aug 23 19:00:29 +0000 2018
# Tweet collected at Thu Aug 23 19:00:29 +0000 2018
# Tweet collected at Thu Aug 23 19:00:32 +0000 2018
# Tweet collected at Thu Aug 23 19:00:33 +0000 2018
# Tweet collected at Thu Aug 23 19:00:33 +0000 2018
# Tweet collected at Thu Aug 23 19:00:34 +0000 2018
# Tweet collected at Thu Aug 23 19:00:35 +0000 2018
# Tweet collected at Thu Aug 23 19:00:34 +0000 2018
# Tweet collected at Thu Aug 23 19:00:36 +0000 2018
# Tweet collected at Thu Aug 23 19:00:36 +0000 2018
# Tweet collected at Thu Aug 23 19:00:37 +0000 2018
# Tweet collected at Thu Aug 23 19:00:37 +0000 2018
# Tweet collected at Thu Aug 23 19:00:38 +0000 2018
# Tweet collected at Thu Aug 23 19:00:38 +0000 2018
# Tweet collected at Thu Aug 23 19:00:39 +0000 2018
# Tweet collected at Thu Aug 23 19:00:40 +0000 2018
# Tweet collected at Thu Aug 23 19:00:40 +0000 2018
# Tweet collected at Thu Aug 23 19:00:41 +0000 2018
# Tweet collected at Thu Aug 23 19:00:41 +0000 2018
# Tweet collected at Thu Aug 23 19:00:41 +0000 2018
# Tweet collected at Thu Aug 23 19:00:41 +0000 2018
# Tweet collected at Thu Aug 23 19:00:42 +0000 2018
# Tweet collected at Thu Aug 23 19:00:44 +0000 2018
# Tweet collected at Thu Aug 23 19:00:45 +0000 2018
# Tweet collected at Thu Aug 23 19:00:46 +0000 2018
# Tweet collected at Thu Aug 23 19:00:46 +0000 2018
# Tweet collected at Thu Aug 23 19:00:47 +0000 2018
# Tweet collected at Thu Aug 23 19:00:51 +0000 2018
# Tweet collected at Thu Aug 23 19:00:52 +0000 2018
# Tweet collected at Thu Aug 23 19:00:53 +0000 2018
# Tweet collected at Thu Aug 23 19:00:54 +0000 2018
# Tweet collected at Thu Aug 23 19:00:55 +0000 2018
# Tweet collected at Thu Aug 23 19:00:56 +0000 2018
# Tweet collected at Thu Aug 23 19:00:57 +0000 2018
# Tweet collected at Thu Aug 23 19:00:59 +0000 2018
# Tweet collected at Thu Aug 23 19:00:59 +0000 2018
# Tweet collected at Thu Aug 23 19:00:59 +0000 2018
# Tweet collected at Thu Aug 23 19:01:00 +0000 2018
# Tweet collected at Thu Aug 23 19:01:00 +0000 2018
# Tweet collected at Thu Aug 23 19:01:00 +0000 2018
# Tweet collected at Thu Aug 23 19:01:00 +0000 2018
# Tweet collected at Thu Aug 23 19:01:02 +0000 2018
# Tweet collected at Thu Aug 23 19:01:02 +0000 2018
# Tweet collected at Thu Aug 23 19:01:03 +0000 2018
# Tweet collected at Thu Aug 23 19:01:03 +0000 2018
# Tweet collected at Thu Aug 23 19:01:03 +0000 2018
# Tweet collected at Thu Aug 23 19:01:03 +0000 2018
# Tweet collected at Thu Aug 23 19:01:04 +0000 2018
# Tweet collected at Thu Aug 23 19:01:04 +0000 2018
# Tweet collected at Thu Aug 23 19:01:04 +0000 2018
# Tweet collected at Thu Aug 23 19:01:06 +0000 2018
# Tweet collected at Thu Aug 23 19:01:06 +0000 2018
# Tweet collected at Thu Aug 23 19:01:08 +0000 2018
# Tweet collected at Thu Aug 23 19:01:08 +0000 2018
# Tweet collected at Thu Aug 23 19:01:08 +0000 2018
# Tweet collected at Thu Aug 23 19:01:08 +0000 2018
# Tweet collected at Thu Aug 23 19:01:09 +0000 2018
# Tweet collected at Thu Aug 23 19:01:09 +0000 2018
# Tweet collected at Thu Aug 23 19:01:09 +0000 2018
# Tweet collected at Thu Aug 23 19:01:13 +0000 2018
# Tweet collected at Thu Aug 23 19:01:13 +0000 2018
# Tweet collected at Thu Aug 23 19:01:14 +0000 2018
# Tweet collected at Thu Aug 23 19:01:14 +0000 2018
# Tweet collected at Thu Aug 23 19:01:15 +0000 2018
# Tweet collected at Thu Aug 23 19:01:17 +0000 2018
# Tweet collected at Thu Aug 23 19:01:17 +0000 2018
# Tweet collected at Thu Aug 23 19:01:17 +0000 2018
# Tweet collected at Thu Aug 23 19:01:17 +0000 2018
# Tweet collected at Thu Aug 23 19:01:17 +0000 2018
# Tweet collected at Thu Aug 23 19:01:19 +0000 2018
# Tweet collected at Thu Aug 23 19:01:20 +0000 2018
# Tweet collected at Thu Aug 23 19:01:20 +0000 2018
# Tweet collected at Thu Aug 23 19:01:20 +0000 2018
# Tweet collected at Thu Aug 23 19:01:21 +0000 2018
# Tweet collected at Thu Aug 23 19:01:24 +0000 2018
# Tweet collected at Thu Aug 23 19:01:25 +0000 2018
# Tweet collected at Thu Aug 23 19:01:26 +0000 2018
# Tweet collected at Thu Aug 23 19:01:27 +0000 2018
# Tweet collected at Thu Aug 23 19:01:28 +0000 2018
# Tweet collected at Thu Aug 23 19:01:30 +0000 2018
# Tweet collected at Thu Aug 23 19:01:31 +0000 2018
# Tweet collected at Thu Aug 23 19:01:32 +0000 2018
# Tweet collected at Thu Aug 23 19:01:34 +0000 2018
# Tweet collected at Thu Aug 23 19:01:34 +0000 2018
# Tweet collected at Thu Aug 23 19:01:35 +0000 2018
# Tweet collected at Thu Aug 23 19:01:35 +0000 2018
# Tweet collected at Thu Aug 23 19:01:37 +0000 2018
# Tweet collected at Thu Aug 23 19:01:37 +0000 2018
# Tweet collected at Thu Aug 23 19:01:38 +0000 2018
# Tweet collected at Thu Aug 23 19:01:39 +0000 2018
# Tweet collected at Thu Aug 23 19:01:39 +0000 2018
# Tweet collected at Thu Aug 23 19:01:40 +0000 2018
# Tweet collected at Thu Aug 23 19:01:41 +0000 2018
# Tweet collected at Thu Aug 23 19:01:41 +0000 2018
# Tweet collected at Thu Aug 23 19:01:43 +0000 2018
# Tweet collected at Thu Aug 23 19:01:45 +0000 2018
# Tweet collected at Thu Aug 23 19:01:45 +0000 2018
# Tweet collected at Thu Aug 23 19:01:46 +0000 2018
# Tweet collected at Thu Aug 23 19:01:46 +0000 2018
# Tweet collected at Thu Aug 23 19:01:46 +0000 2018
# Tweet collected at Thu Aug 23 19:01:47 +0000 2018
# Tweet collected at Thu Aug 23 19:01:49 +0000 2018
# Tweet collected at Thu Aug 23 19:01:51 +0000 2018
# Tweet collected at Thu Aug 23 19:01:52 +0000 2018
# Tweet collected at Thu Aug 23 19:01:54 +0000 2018
# Tweet collected at Thu Aug 23 19:01:55 +0000 2018
# Tweet collected at Thu Aug 23 19:01:55 +0000 2018
# Tweet collected at Thu Aug 23 19:01:57 +0000 2018
# Tweet collected at Thu Aug 23 19:01:57 +0000 2018
# Tweet collected at Thu Aug 23 19:01:58 +0000 2018
# Tweet collected at Thu Aug 23 19:01:58 +0000 2018
# Tweet collected at Thu Aug 23 19:01:58 +0000 2018
# Tweet collected at Thu Aug 23 19:01:58 +0000 2018
# Tweet collected at Thu Aug 23 19:02:00 +0000 2018
# Tweet collected at Thu Aug 23 19:02:00 +0000 2018
# Tweet collected at Thu Aug 23 19:02:00 +0000 2018
# Tweet collected at Thu Aug 23 19:02:00 +0000 2018
# Tweet collected at Thu Aug 23 19:02:00 +0000 2018
# Tweet collected at Thu Aug 23 19:02:00 +0000 2018
# Tweet collected at Thu Aug 23 19:02:01 +0000 2018
# Tweet collected at Thu Aug 23 19:02:02 +0000 2018
# Tweet collected at Thu Aug 23 19:02:01 +0000 2018
# Tweet collected at Thu Aug 23 19:02:02 +0000 2018
# Tweet collected at Thu Aug 23 19:02:02 +0000 2018
# Tweet collected at Thu Aug 23 19:02:04 +0000 2018
# Tweet collected at Thu Aug 23 19:02:04 +0000 2018
# Tweet collected at Thu Aug 23 19:02:06 +0000 2018
# Tweet collected at Thu Aug 23 19:02:07 +0000 2018
# Tweet collected at Thu Aug 23 19:02:07 +0000 2018
# Tweet collected at Thu Aug 23 19:02:09 +0000 2018
# Tweet collected at Thu Aug 23 19:02:09 +0000 2018
# Tweet collected at Thu Aug 23 19:02:12 +0000 2018
# Tweet collected at Thu Aug 23 19:02:13 +0000 2018
# Tweet collected at Thu Aug 23 19:02:13 +0000 2018
# Tweet collected at Thu Aug 23 19:02:14 +0000 2018
# Tweet collected at Thu Aug 23 19:02:16 +0000 2018
# Tweet collected at Thu Aug 23 19:02:17 +0000 2018
# Tweet collected at Thu Aug 23 19:02:18 +0000 2018
# Tweet collected at Thu Aug 23 19:02:18 +0000 2018
# Tweet collected at Thu Aug 23 19:02:22 +0000 2018
# Tweet collected at Thu Aug 23 19:02:23 +0000 2018
# Tweet collected at Thu Aug 23 19:02:25 +0000 2018
# Tweet collected at Thu Aug 23 19:02:26 +0000 2018
# Tweet collected at Thu Aug 23 19:02:27 +0000 2018
# Tweet collected at Thu Aug 23 19:02:27 +0000 2018
# Tweet collected at Thu Aug 23 19:02:28 +0000 2018
# Tweet collected at Thu Aug 23 19:02:31 +0000 2018
# Tweet collected at Thu Aug 23 19:02:31 +0000 2018
# Tweet collected at Thu Aug 23 19:02:35 +0000 2018
# Tweet collected at Thu Aug 23 19:02:35 +0000 2018
# Tweet collected at Thu Aug 23 19:02:36 +0000 2018
# Tweet collected at Thu Aug 23 19:02:38 +0000 2018
# Tweet collected at Thu Aug 23 19:02:38 +0000 2018
# Tweet collected at Thu Aug 23 19:02:38 +0000 2018
# Tweet collected at Thu Aug 23 19:02:39 +0000 2018
# Tweet collected at Thu Aug 23 19:02:40 +0000 2018
# Tweet collected at Thu Aug 23 19:02:40 +0000 2018
# Tweet collected at Thu Aug 23 19:02:41 +0000 2018
# Tweet collected at Thu Aug 23 19:02:41 +0000 2018
# Tweet collected at Thu Aug 23 19:02:44 +0000 2018
# Tweet collected at Thu Aug 23 19:02:46 +0000 2018
# Tweet collected at Thu Aug 23 19:02:49 +0000 2018
# Tweet collected at Thu Aug 23 19:02:50 +0000 2018
# Tweet collected at Thu Aug 23 19:02:50 +0000 2018
# Tweet collected at Thu Aug 23 19:02:51 +0000 2018
# Tweet collected at Thu Aug 23 19:02:52 +0000 2018
# Tweet collected at Thu Aug 23 19:02:52 +0000 2018
# Tweet collected at Thu Aug 23 19:02:53 +0000 2018
# Tweet collected at Thu Aug 23 19:02:55 +0000 2018
# Tweet collected at Thu Aug 23 19:02:55 +0000 2018
# Tweet collected at Thu Aug 23 19:02:56 +0000 2018
# Tweet collected at Thu Aug 23 19:02:58 +0000 2018
# Tweet collected at Thu Aug 23 19:03:00 +0000 2018
# Tweet collected at Thu Aug 23 19:03:02 +0000 2018
# Tweet collected at Thu Aug 23 19:03:02 +0000 2018
# Tweet collected at Thu Aug 23 19:03:03 +0000 2018
# Tweet collected at Thu Aug 23 19:03:04 +0000 2018
# Tweet collected at Thu Aug 23 19:03:04 +0000 2018
# Tweet collected at Thu Aug 23 19:03:05 +0000 2018
# Tweet collected at Thu Aug 23 19:03:06 +0000 2018
# Tweet collected at Thu Aug 23 19:03:06 +0000 2018
# Tweet collected at Thu Aug 23 19:03:07 +0000 2018
# Tweet collected at Thu Aug 23 19:03:08 +0000 2018
# Tweet collected at Thu Aug 23 19:03:08 +0000 2018
# Tweet collected at Thu Aug 23 19:03:08 +0000 2018
# Tweet collected at Thu Aug 23 19:03:11 +0000 2018
# Tweet collected at Thu Aug 23 19:03:11 +0000 2018
# Tweet collected at Thu Aug 23 19:03:11 +0000 2018
# Tweet collected at Thu Aug 23 19:03:11 +0000 2018
# Tweet collected at Thu Aug 23 19:03:13 +0000 2018
# Tweet collected at Thu Aug 23 19:03:15 +0000 2018
# Tweet collected at Thu Aug 23 19:03:16 +0000 2018
# Tweet collected at Thu Aug 23 19:03:18 +0000 2018
# Tweet collected at Thu Aug 23 19:03:19 +0000 2018
# Tweet collected at Thu Aug 23 19:03:21 +0000 2018
# Tweet collected at Thu Aug 23 19:03:21 +0000 2018
# Tweet collected at Thu Aug 23 19:03:21 +0000 2018
# Tweet collected at Thu Aug 23 19:03:23 +0000 2018
# Tweet collected at Thu Aug 23 19:03:23 +0000 2018
# Tweet collected at Thu Aug 23 19:03:24 +0000 2018
# Tweet collected at Thu Aug 23 19:03:25 +0000 2018
# Tweet collected at Thu Aug 23 19:03:25 +0000 2018
# Tweet collected at Thu Aug 23 19:03:25 +0000 2018
# Tweet collected at Thu Aug 23 19:03:28 +0000 2018
# Tweet collected at Thu Aug 23 19:03:30 +0000 2018
# Tweet collected at Thu Aug 23 19:03:30 +0000 2018
# Tweet collected at Thu Aug 23 19:03:32 +0000 2018
# Tweet collected at Thu Aug 23 19:03:33 +0000 2018
# Tweet collected at Thu Aug 23 19:03:34 +0000 2018
# Tweet collected at Thu Aug 23 19:03:35 +0000 2018
# Tweet collected at Thu Aug 23 19:03:37 +0000 2018
# Tweet collected at Thu Aug 23 19:03:39 +0000 2018
# Tweet collected at Thu Aug 23 19:03:42 +0000 2018
# Tweet collected at Thu Aug 23 19:03:43 +0000 2018
# Tweet collected at Thu Aug 23 19:03:43 +0000 2018
# Tweet collected at Thu Aug 23 19:03:44 +0000 2018
# Tweet collected at Thu Aug 23 19:03:46 +0000 2018
# Tweet collected at Thu Aug 23 19:03:46 +0000 2018
# Tweet collected at Thu Aug 23 19:03:48 +0000 2018
# Tweet collected at Thu Aug 23 19:03:50 +0000 2018
# Tweet collected at Thu Aug 23 19:03:54 +0000 2018
# Tweet collected at Thu Aug 23 19:03:54 +0000 2018
# Tweet collected at Thu Aug 23 19:03:54 +0000 2018
# Tweet collected at Thu Aug 23 19:03:54 +0000 2018
# Tweet collected at Thu Aug 23 19:03:55 +0000 2018
# Tweet collected at Thu Aug 23 19:03:58 +0000 2018
# Tweet collected at Thu Aug 23 19:03:59 +0000 2018
# Tweet collected at Thu Aug 23 19:04:00 +0000 2018
# Tweet collected at Thu Aug 23 19:04:01 +0000 2018
# Tweet collected at Thu Aug 23 19:04:01 +0000 2018
# Tweet collected at Thu Aug 23 19:04:01 +0000 2018
# Tweet collected at Thu Aug 23 19:04:02 +0000 2018
# Tweet collected at Thu Aug 23 19:04:04 +0000 2018
# Tweet collected at Thu Aug 23 19:04:04 +0000 2018
# Tweet collected at Thu Aug 23 19:04:06 +0000 2018
# Tweet collected at Thu Aug 23 19:04:10 +0000 2018
# Tweet collected at Thu Aug 23 19:04:10 +0000 2018
# Tweet collected at Thu Aug 23 19:04:12 +0000 2018
# Tweet collected at Thu Aug 23 19:04:13 +0000 2018
# Tweet collected at Thu Aug 23 19:04:15 +0000 2018
# Tweet collected at Thu Aug 23 19:04:16 +0000 2018
# Tweet collected at Thu Aug 23 19:04:16 +0000 2018
# Tweet collected at Thu Aug 23 19:04:17 +0000 2018
# Tweet collected at Thu Aug 23 19:04:20 +0000 2018
# Tweet collected at Thu Aug 23 19:04:20 +0000 2018
# Tweet collected at Thu Aug 23 19:04:20 +0000 2018
# Tweet collected at Thu Aug 23 19:04:20 +0000 2018
# Tweet collected at Thu Aug 23 19:04:24 +0000 2018
# Tweet collected at Thu Aug 23 19:04:25 +0000 2018
# Tweet collected at Thu Aug 23 19:04:30 +0000 2018
# Tweet collected at Thu Aug 23 19:04:30 +0000 2018
# Tweet collected at Thu Aug 23 19:04:38 +0000 2018
# Tweet collected at Thu Aug 23 19:04:38 +0000 2018
# Tweet collected at Thu Aug 23 19:04:39 +0000 2018
# Tweet collected at Thu Aug 23 19:04:41 +0000 2018
# Tweet collected at Thu Aug 23 19:04:42 +0000 2018
# Tweet collected at Thu Aug 23 19:04:43 +0000 2018
# Tweet collected at Thu Aug 23 19:04:43 +0000 2018
# Tweet collected at Thu Aug 23 19:04:44 +0000 2018
# Tweet collected at Thu Aug 23 19:04:49 +0000 2018
# Tweet collected at Thu Aug 23 19:04:49 +0000 2018
# Tweet collected at Thu Aug 23 19:04:52 +0000 2018
# Tweet collected at Thu Aug 23 19:04:52 +0000 2018
# Tweet collected at Thu Aug 23 19:04:53 +0000 2018
# Tweet collected at Thu Aug 23 19:04:54 +0000 2018
# Tweet collected at Thu Aug 23 19:04:58 +0000 2018
# Tweet collected at Thu Aug 23 19:05:00 +0000 2018
# Tweet collected at Thu Aug 23 19:05:00 +0000 2018
# Tweet collected at Thu Aug 23 19:05:00 +0000 2018
# Tweet collected at Thu Aug 23 19:05:00 +0000 2018
# Tweet collected at Thu Aug 23 19:05:01 +0000 2018
# Tweet collected at Thu Aug 23 19:05:01 +0000 2018
# Tweet collected at Thu Aug 23 19:05:02 +0000 2018
# Tweet collected at Thu Aug 23 19:05:02 +0000 2018
# Tweet collected at Thu Aug 23 19:05:03 +0000 2018
# Tweet collected at Thu Aug 23 19:05:04 +0000 2018
# Tweet collected at Thu Aug 23 19:05:04 +0000 2018
# Tweet collected at Thu Aug 23 19:05:05 +0000 2018
# Tweet collected at Thu Aug 23 19:05:05 +0000 2018
# Tweet collected at Thu Aug 23 19:05:07 +0000 2018
# Tweet collected at Thu Aug 23 19:05:08 +0000 2018
# Tweet collected at Thu Aug 23 19:05:08 +0000 2018
# Tweet collected at Thu Aug 23 19:05:08 +0000 2018
# Tweet collected at Thu Aug 23 19:05:08 +0000 2018
# Tweet collected at Thu Aug 23 19:05:09 +0000 2018
# Tweet collected at Thu Aug 23 19:05:09 +0000 2018
# Tweet collected at Thu Aug 23 19:05:09 +0000 2018
# Tweet collected at Thu Aug 23 19:05:11 +0000 2018
# Tweet collected at Thu Aug 23 19:05:10 +0000 2018
# Tweet collected at Thu Aug 23 19:05:11 +0000 2018
# Tweet collected at Thu Aug 23 19:05:13 +0000 2018
# Tweet collected at Thu Aug 23 19:05:13 +0000 2018
# Tweet collected at Thu Aug 23 19:05:14 +0000 2018
# Tweet collected at Thu Aug 23 19:05:14 +0000 2018
# Tweet collected at Thu Aug 23 19:05:14 +0000 2018
# Tweet collected at Thu Aug 23 19:05:14 +0000 2018
# Tweet collected at Thu Aug 23 19:05:18 +0000 2018
# Tweet collected at Thu Aug 23 19:05:19 +0000 2018
# Tweet collected at Thu Aug 23 19:05:21 +0000 2018
# Tweet collected at Thu Aug 23 19:05:25 +0000 2018
# Tweet collected at Thu Aug 23 19:05:25 +0000 2018
# Tweet collected at Thu Aug 23 19:05:26 +0000 2018
# Tweet collected at Thu Aug 23 19:05:27 +0000 2018
# Tweet collected at Thu Aug 23 19:05:28 +0000 2018
# Tweet collected at Thu Aug 23 19:05:29 +0000 2018
# Tweet collected at Thu Aug 23 19:05:30 +0000 2018
# Tweet collected at Thu Aug 23 19:05:30 +0000 2018
# Tweet collected at Thu Aug 23 19:05:32 +0000 2018
# Tweet collected at Thu Aug 23 19:05:32 +0000 2018
# Tweet collected at Thu Aug 23 19:05:33 +0000 2018
# Tweet collected at Thu Aug 23 19:05:34 +0000 2018
# Tweet collected at Thu Aug 23 19:05:36 +0000 2018
# Tweet collected at Thu Aug 23 19:05:39 +0000 2018
# Tweet collected at Thu Aug 23 19:05:39 +0000 2018
# Tweet collected at Thu Aug 23 19:05:42 +0000 2018
# Tweet collected at Thu Aug 23 19:05:42 +0000 2018
# Tweet collected at Thu Aug 23 19:05:46 +0000 2018
# Tweet collected at Thu Aug 23 19:05:49 +0000 2018
# Tweet collected at Thu Aug 23 19:05:49 +0000 2018
# Tweet collected at Thu Aug 23 19:05:52 +0000 2018
# Tweet collected at Thu Aug 23 19:05:53 +0000 2018
# Tweet collected at Thu Aug 23 19:05:55 +0000 2018
# Tweet collected at Thu Aug 23 19:05:56 +0000 2018
# Tweet collected at Thu Aug 23 19:05:59 +0000 2018
# Tweet collected at Thu Aug 23 19:06:00 +0000 2018
# Tweet collected at Thu Aug 23 19:06:01 +0000 2018
# Tweet collected at Thu Aug 23 19:06:01 +0000 2018
# Tweet collected at Thu Aug 23 19:06:03 +0000 2018
# Tweet collected at Thu Aug 23 19:06:04 +0000 2018
# Tweet collected at Thu Aug 23 19:06:04 +0000 2018
# Tweet collected at Thu Aug 23 19:06:06 +0000 2018
# Tweet collected at Thu Aug 23 19:06:07 +0000 2018
# Tweet collected at Thu Aug 23 19:06:11 +0000 2018
# Tweet collected at Thu Aug 23 19:06:18 +0000 2018
# Tweet collected at Thu Aug 23 19:06:20 +0000 2018
# Tweet collected at Thu Aug 23 19:06:21 +0000 2018
# Tweet collected at Thu Aug 23 19:06:20 +0000 2018
# Tweet collected at Thu Aug 23 19:06:21 +0000 2018
# Tweet collected at Thu Aug 23 19:06:21 +0000 2018
# Tweet collected at Thu Aug 23 19:06:22 +0000 2018
# Tweet collected at Thu Aug 23 19:06:23 +0000 2018
# Tweet collected at Thu Aug 23 19:06:23 +0000 2018
# Tweet collected at Thu Aug 23 19:06:23 +0000 2018
# Tweet collected at Thu Aug 23 19:06:24 +0000 2018
# Tweet collected at Thu Aug 23 19:06:24 +0000 2018
# Tweet collected at Thu Aug 23 19:06:24 +0000 2018
# Tweet collected at Thu Aug 23 19:06:25 +0000 2018
# Tweet collected at Thu Aug 23 19:06:26 +0000 2018
# Tweet collected at Thu Aug 23 19:06:26 +0000 2018
# Tweet collected at Thu Aug 23 19:06:27 +0000 2018
# Tweet collected at Thu Aug 23 19:06:28 +0000 2018
# Tweet collected at Thu Aug 23 19:06:30 +0000 2018
# Tweet collected at Thu Aug 23 19:06:31 +0000 2018
# Tweet collected at Thu Aug 23 19:06:34 +0000 2018
# Tweet collected at Thu Aug 23 19:06:36 +0000 2018
# Tweet collected at Thu Aug 23 19:06:38 +0000 2018
# Tweet collected at Thu Aug 23 19:06:40 +0000 2018
# Tweet collected at Thu Aug 23 19:06:43 +0000 2018
# Tweet collected at Thu Aug 23 19:06:45 +0000 2018
# Tweet collected at Thu Aug 23 19:06:47 +0000 2018
# Tweet collected at Thu Aug 23 19:06:48 +0000 2018
# Tweet collected at Thu Aug 23 19:06:56 +0000 2018
# Tweet collected at Thu Aug 23 19:06:56 +0000 2018
# Tweet collected at Thu Aug 23 19:07:00 +0000 2018
# Tweet collected at Thu Aug 23 19:07:00 +0000 2018
# Tweet collected at Thu Aug 23 19:07:00 +0000 2018
# Tweet collected at Thu Aug 23 19:07:01 +0000 2018
# Tweet collected at Thu Aug 23 19:07:01 +0000 2018
# Tweet collected at Thu Aug 23 19:07:01 +0000 2018
# Tweet collected at Thu Aug 23 19:07:02 +0000 2018
# Tweet collected at Thu Aug 23 19:07:03 +0000 2018
# Tweet collected at Thu Aug 23 19:07:04 +0000 2018
# Tweet collected at Thu Aug 23 19:07:04 +0000 2018
# Tweet collected at Thu Aug 23 19:07:08 +0000 2018
# Tweet collected at Thu Aug 23 19:07:07 +0000 2018
# Tweet collected at Thu Aug 23 19:07:09 +0000 2018
# Tweet collected at Thu Aug 23 19:07:11 +0000 2018
# Tweet collected at Thu Aug 23 19:07:11 +0000 2018
# Tweet collected at Thu Aug 23 19:07:13 +0000 2018
# Tweet collected at Thu Aug 23 19:07:14 +0000 2018
# Tweet collected at Thu Aug 23 19:07:17 +0000 2018
# Tweet collected at Thu Aug 23 19:07:18 +0000 2018
# Tweet collected at Thu Aug 23 19:07:18 +0000 2018
# Tweet collected at Thu Aug 23 19:07:27 +0000 2018
# Tweet collected at Thu Aug 23 19:07:28 +0000 2018
# Tweet collected at Thu Aug 23 19:07:28 +0000 2018
# Tweet collected at Thu Aug 23 19:07:30 +0000 2018
# Tweet collected at Thu Aug 23 19:07:32 +0000 2018
# Tweet collected at Thu Aug 23 19:07:33 +0000 2018
# Tweet collected at Thu Aug 23 19:07:36 +0000 2018
# Tweet collected at Thu Aug 23 19:07:37 +0000 2018
# Tweet collected at Thu Aug 23 19:07:38 +0000 2018
# Tweet collected at Thu Aug 23 19:07:39 +0000 2018
# Tweet collected at Thu Aug 23 19:07:39 +0000 2018
# Tweet collected at Thu Aug 23 19:07:40 +0000 2018
# Tweet collected at Thu Aug 23 19:07:40 +0000 2018
# Tweet collected at Thu Aug 23 19:07:40 +0000 2018
# Tweet collected at Thu Aug 23 19:07:41 +0000 2018
# Tweet collected at Thu Aug 23 19:07:43 +0000 2018
# Tweet collected at Thu Aug 23 19:07:44 +0000 2018
# Tweet collected at Thu Aug 23 19:07:46 +0000 2018
# Tweet collected at Thu Aug 23 19:07:48 +0000 2018
# Tweet collected at Thu Aug 23 19:07:49 +0000 2018
# Tweet collected at Thu Aug 23 19:07:49 +0000 2018
# Tweet collected at Thu Aug 23 19:07:53 +0000 2018
# Tweet collected at Thu Aug 23 19:07:53 +0000 2018
# Tweet collected at Thu Aug 23 19:07:54 +0000 2018
# Tweet collected at Thu Aug 23 19:07:53 +0000 2018
# Tweet collected at Thu Aug 23 19:07:55 +0000 2018
# Tweet collected at Thu Aug 23 19:07:55 +0000 2018
# Tweet collected at Thu Aug 23 19:07:59 +0000 2018
# Tweet collected at Thu Aug 23 19:08:00 +0000 2018
# Tweet collected at Thu Aug 23 19:08:00 +0000 2018
# Tweet collected at Thu Aug 23 19:08:00 +0000 2018
# Tweet collected at Thu Aug 23 19:08:01 +0000 2018
# Tweet collected at Thu Aug 23 19:08:00 +0000 2018
# Tweet collected at Thu Aug 23 19:08:02 +0000 2018
# Tweet collected at Thu Aug 23 19:08:01 +0000 2018
# Tweet collected at Thu Aug 23 19:08:02 +0000 2018
# Tweet collected at Thu Aug 23 19:08:04 +0000 2018
# Tweet collected at Thu Aug 23 19:08:04 +0000 2018
# Tweet collected at Thu Aug 23 19:08:05 +0000 2018
# Tweet collected at Thu Aug 23 19:08:05 +0000 2018
# Tweet collected at Thu Aug 23 19:08:06 +0000 2018
# Tweet collected at Thu Aug 23 19:08:08 +0000 2018
# Tweet collected at Thu Aug 23 19:08:14 +0000 2018
# Tweet collected at Thu Aug 23 19:08:15 +0000 2018
# Tweet collected at Thu Aug 23 19:08:16 +0000 2018
# Tweet collected at Thu Aug 23 19:08:16 +0000 2018
# Tweet collected at Thu Aug 23 19:08:16 +0000 2018
# Tweet collected at Thu Aug 23 19:08:19 +0000 2018
# Tweet collected at Thu Aug 23 19:08:20 +0000 2018
# Tweet collected at Thu Aug 23 19:08:21 +0000 2018
# Tweet collected at Thu Aug 23 19:08:22 +0000 2018
# Tweet collected at Thu Aug 23 19:08:22 +0000 2018
# Tweet collected at Thu Aug 23 19:08:23 +0000 2018
# Tweet collected at Thu Aug 23 19:08:24 +0000 2018
# Tweet collected at Thu Aug 23 19:08:26 +0000 2018
# Tweet collected at Thu Aug 23 19:08:29 +0000 2018
# Tweet collected at Thu Aug 23 19:08:31 +0000 2018
# Tweet collected at Thu Aug 23 19:08:32 +0000 2018
# Tweet collected at Thu Aug 23 19:08:37 +0000 2018
# Tweet collected at Thu Aug 23 19:08:38 +0000 2018
# Tweet collected at Thu Aug 23 19:08:39 +0000 2018
# Tweet collected at Thu Aug 23 19:08:45 +0000 2018
# Tweet collected at Thu Aug 23 19:08:45 +0000 2018
# Tweet collected at Thu Aug 23 19:08:45 +0000 2018
# Tweet collected at Thu Aug 23 19:08:45 +0000 2018
# Tweet collected at Thu Aug 23 19:08:47 +0000 2018
# Tweet collected at Thu Aug 23 19:08:48 +0000 2018
# Tweet collected at Thu Aug 23 19:08:49 +0000 2018
# Tweet collected at Thu Aug 23 19:08:51 +0000 2018
# Tweet collected at Thu Aug 23 19:08:57 +0000 2018
# Tweet collected at Thu Aug 23 19:08:57 +0000 2018
# Tweet collected at Thu Aug 23 19:08:58 +0000 2018
# Tweet collected at Thu Aug 23 19:08:59 +0000 2018
# Tweet collected at Thu Aug 23 19:09:02 +0000 2018
# Tweet collected at Thu Aug 23 19:09:03 +0000 2018
# Tweet collected at Thu Aug 23 19:09:04 +0000 2018
# Tweet collected at Thu Aug 23 19:09:06 +0000 2018
# Tweet collected at Thu Aug 23 19:09:07 +0000 2018
# Tweet collected at Thu Aug 23 19:09:09 +0000 2018
# Tweet collected at Thu Aug 23 19:09:12 +0000 2018
# Tweet collected at Thu Aug 23 19:09:14 +0000 2018
# Tweet collected at Thu Aug 23 19:09:14 +0000 2018
# Tweet collected at Thu Aug 23 19:09:16 +0000 2018
# Tweet collected at Thu Aug 23 19:09:18 +0000 2018
# Tweet collected at Thu Aug 23 19:09:18 +0000 2018
# Tweet collected at Thu Aug 23 19:09:20 +0000 2018
# Tweet collected at Thu Aug 23 19:09:21 +0000 2018
# Tweet collected at Thu Aug 23 19:09:22 +0000 2018
# Tweet collected at Thu Aug 23 19:09:22 +0000 2018
# Tweet collected at Thu Aug 23 19:09:22 +0000 2018
# Tweet collected at Thu Aug 23 19:09:23 +0000 2018
# Tweet collected at Thu Aug 23 19:09:23 +0000 2018
# Tweet collected at Thu Aug 23 19:09:24 +0000 2018
# Tweet collected at Thu Aug 23 19:09:35 +0000 2018
# Tweet collected at Thu Aug 23 19:09:36 +0000 2018
# Tweet collected at Thu Aug 23 19:09:37 +0000 2018
# Tweet collected at Thu Aug 23 19:09:38 +0000 2018
# Tweet collected at Thu Aug 23 19:09:39 +0000 2018
# Tweet collected at Thu Aug 23 19:09:42 +0000 2018
# Tweet collected at Thu Aug 23 19:09:42 +0000 2018
# Tweet collected at Thu Aug 23 19:09:42 +0000 2018
# Tweet collected at Thu Aug 23 19:09:44 +0000 2018
# Tweet collected at Thu Aug 23 19:09:46 +0000 2018
# Tweet collected at Thu Aug 23 19:09:47 +0000 2018
# Tweet collected at Thu Aug 23 19:09:47 +0000 2018
# Tweet collected at Thu Aug 23 19:09:47 +0000 2018
# Tweet collected at Thu Aug 23 19:09:47 +0000 2018
# Tweet collected at Thu Aug 23 19:09:47 +0000 2018
# Tweet collected at Thu Aug 23 19:09:48 +0000 2018
# Tweet collected at Thu Aug 23 19:09:49 +0000 2018
# Tweet collected at Thu Aug 23 19:09:49 +0000 2018
# Tweet collected at Thu Aug 23 19:09:49 +0000 2018
# Tweet collected at Thu Aug 23 19:09:50 +0000 2018
# Tweet collected at Thu Aug 23 19:09:51 +0000 2018
# Tweet collected at Thu Aug 23 19:09:51 +0000 2018
# Tweet collected at Thu Aug 23 19:09:52 +0000 2018
# Tweet collected at Thu Aug 23 19:09:58 +0000 2018
# Tweet collected at Thu Aug 23 19:09:58 +0000 2018
# Tweet collected at Thu Aug 23 19:09:58 +0000 2018
# Tweet collected at Thu Aug 23 19:09:58 +0000 2018
# Tweet collected at Thu Aug 23 19:09:59 +0000 2018
# Tweet collected at Thu Aug 23 19:10:00 +0000 2018
# Tweet collected at Thu Aug 23 19:10:02 +0000 2018
# Tweet collected at Thu Aug 23 19:10:03 +0000 2018
# Tweet collected at Thu Aug 23 19:10:06 +0000 2018
# Tweet collected at Thu Aug 23 19:10:06 +0000 2018
# Tweet collected at Thu Aug 23 19:10:06 +0000 2018
# Tweet collected at Thu Aug 23 19:10:06 +0000 2018
# Tweet collected at Thu Aug 23 19:10:07 +0000 2018
# Tweet collected at Thu Aug 23 19:10:07 +0000 2018
# Tweet collected at Thu Aug 23 19:10:07 +0000 2018
# Tweet collected at Thu Aug 23 19:10:08 +0000 2018
# Tweet collected at Thu Aug 23 19:10:08 +0000 2018
# Tweet collected at Thu Aug 23 19:10:09 +0000 2018
# Tweet collected at Thu Aug 23 19:10:09 +0000 2018
# Tweet collected at Thu Aug 23 19:10:08 +0000 2018
# Tweet collected at Thu Aug 23 19:10:08 +0000 2018
# Tweet collected at Thu Aug 23 19:10:10 +0000 2018
# Tweet collected at Thu Aug 23 19:10:10 +0000 2018
# Tweet collected at Thu Aug 23 19:10:10 +0000 2018
# Tweet collected at Thu Aug 23 19:10:10 +0000 2018
# Tweet collected at Thu Aug 23 19:10:12 +0000 2018
# Tweet collected at Thu Aug 23 19:10:12 +0000 2018
# Tweet collected at Thu Aug 23 19:10:14 +0000 2018
# Tweet collected at Thu Aug 23 19:10:17 +0000 2018
# Tweet collected at Thu Aug 23 19:10:17 +0000 2018
# Tweet collected at Thu Aug 23 19:10:18 +0000 2018
# Tweet collected at Thu Aug 23 19:10:18 +0000 2018
# Tweet collected at Thu Aug 23 19:10:19 +0000 2018
# Tweet collected at Thu Aug 23 19:10:20 +0000 2018
# Tweet collected at Thu Aug 23 19:10:20 +0000 2018
# Tweet collected at Thu Aug 23 19:10:20 +0000 2018
# Tweet collected at Thu Aug 23 19:10:21 +0000 2018
# Tweet collected at Thu Aug 23 19:10:23 +0000 2018
# Tweet collected at Thu Aug 23 19:10:23 +0000 2018
# Tweet collected at Thu Aug 23 19:10:24 +0000 2018
# Tweet collected at Thu Aug 23 19:10:25 +0000 2018
# Tweet collected at Thu Aug 23 19:10:27 +0000 2018
# Tweet collected at Thu Aug 23 19:10:29 +0000 2018
# Tweet collected at Thu Aug 23 19:10:30 +0000 2018
# Tweet collected at Thu Aug 23 19:10:31 +0000 2018
# Tweet collected at Thu Aug 23 19:10:33 +0000 2018
# Tweet collected at Thu Aug 23 19:10:35 +0000 2018
# Tweet collected at Thu Aug 23 19:10:36 +0000 2018
# Tweet collected at Thu Aug 23 19:10:37 +0000 2018
# Tweet collected at Thu Aug 23 19:10:39 +0000 2018
# Tweet collected at Thu Aug 23 19:10:40 +0000 2018
# Tweet collected at Thu Aug 23 19:10:41 +0000 2018
# Tweet collected at Thu Aug 23 19:10:42 +0000 2018
# Tweet collected at Thu Aug 23 19:10:44 +0000 2018
# Tweet collected at Thu Aug 23 19:10:47 +0000 2018
# Tweet collected at Thu Aug 23 19:10:49 +0000 2018
# Tweet collected at Thu Aug 23 19:10:49 +0000 2018
# Tweet collected at Thu Aug 23 19:10:53 +0000 2018
# Tweet collected at Thu Aug 23 19:11:02 +0000 2018
# Tweet collected at Thu Aug 23 19:11:03 +0000 2018
# Tweet collected at Thu Aug 23 19:11:04 +0000 2018
# Tweet collected at Thu Aug 23 19:11:06 +0000 2018
# Tweet collected at Thu Aug 23 19:11:07 +0000 2018
# Tweet collected at Thu Aug 23 19:11:08 +0000 2018
# Tweet collected at Thu Aug 23 19:11:11 +0000 2018
# Tweet collected at Thu Aug 23 19:11:14 +0000 2018
# Tweet collected at Thu Aug 23 19:11:15 +0000 2018
# Tweet collected at Thu Aug 23 19:11:15 +0000 2018
# Tweet collected at Thu Aug 23 19:11:19 +0000 2018
# Tweet collected at Thu Aug 23 19:11:19 +0000 2018
# Tweet collected at Thu Aug 23 19:11:19 +0000 2018
# Tweet collected at Thu Aug 23 19:11:20 +0000 2018
# Tweet collected at Thu Aug 23 19:11:22 +0000 2018
# Tweet collected at Thu Aug 23 19:11:23 +0000 2018
# Tweet collected at Thu Aug 23 19:11:23 +0000 2018
# Tweet collected at Thu Aug 23 19:11:26 +0000 2018
# Tweet collected at Thu Aug 23 19:11:27 +0000 2018
# Tweet collected at Thu Aug 23 19:11:28 +0000 2018
# Tweet collected at Thu Aug 23 19:11:29 +0000 2018
# Tweet collected at Thu Aug 23 19:11:30 +0000 2018
# Tweet collected at Thu Aug 23 19:11:34 +0000 2018
# Tweet collected at Thu Aug 23 19:11:34 +0000 2018
# Tweet collected at Thu Aug 23 19:11:36 +0000 2018
# Tweet collected at Thu Aug 23 19:11:36 +0000 2018
# Tweet collected at Thu Aug 23 19:11:38 +0000 2018
# Tweet collected at Thu Aug 23 19:11:38 +0000 2018
# Tweet collected at Thu Aug 23 19:11:39 +0000 2018
# Tweet collected at Thu Aug 23 19:11:44 +0000 2018
# Tweet collected at Thu Aug 23 19:11:46 +0000 2018
# Tweet collected at Thu Aug 23 19:11:46 +0000 2018
# Tweet collected at Thu Aug 23 19:11:46 +0000 2018
# Tweet collected at Thu Aug 23 19:11:49 +0000 2018
# Tweet collected at Thu Aug 23 19:11:50 +0000 2018
# Tweet collected at Thu Aug 23 19:11:51 +0000 2018
# Tweet collected at Thu Aug 23 19:11:53 +0000 2018
# Tweet collected at Thu Aug 23 19:11:55 +0000 2018
# Tweet collected at Thu Aug 23 19:11:56 +0000 2018
# Tweet collected at Thu Aug 23 19:11:57 +0000 2018
# Tweet collected at Thu Aug 23 19:11:59 +0000 2018
# Tweet collected at Thu Aug 23 19:12:01 +0000 2018
# Tweet collected at Thu Aug 23 19:12:02 +0000 2018
# Tweet collected at Thu Aug 23 19:12:04 +0000 2018
# Tweet collected at Thu Aug 23 19:12:07 +0000 2018
# Tweet collected at Thu Aug 23 19:12:08 +0000 2018
# Tweet collected at Thu Aug 23 19:12:09 +0000 2018
# Tweet collected at Thu Aug 23 19:12:10 +0000 2018
# Tweet collected at Thu Aug 23 19:12:12 +0000 2018
# Tweet collected at Thu Aug 23 19:12:17 +0000 2018
# Tweet collected at Thu Aug 23 19:12:18 +0000 2018
# Tweet collected at Thu Aug 23 19:12:19 +0000 2018
# Tweet collected at Thu Aug 23 19:12:19 +0000 2018
# Tweet collected at Thu Aug 23 19:12:19 +0000 2018
# Tweet collected at Thu Aug 23 19:12:22 +0000 2018
# Tweet collected at Thu Aug 23 19:12:24 +0000 2018
# Tweet collected at Thu Aug 23 19:12:25 +0000 2018
# Tweet collected at Thu Aug 23 19:12:27 +0000 2018
# Tweet collected at Thu Aug 23 19:12:27 +0000 2018
# Tweet collected at Thu Aug 23 19:12:28 +0000 2018
# Tweet collected at Thu Aug 23 19:12:30 +0000 2018
# Tweet collected at Thu Aug 23 19:12:31 +0000 2018
# Tweet collected at Thu Aug 23 19:12:32 +0000 2018
# Tweet collected at Thu Aug 23 19:12:35 +0000 2018
# Tweet collected at Thu Aug 23 19:12:36 +0000 2018
# Tweet collected at Thu Aug 23 19:12:37 +0000 2018
# Tweet collected at Thu Aug 23 19:12:38 +0000 2018
# Tweet collected at Thu Aug 23 19:12:41 +0000 2018
# Tweet collected at Thu Aug 23 19:12:42 +0000 2018
# Tweet collected at Thu Aug 23 19:12:43 +0000 2018
# Tweet collected at Thu Aug 23 19:12:45 +0000 2018
# Tweet collected at Thu Aug 23 19:12:51 +0000 2018
# Tweet collected at Thu Aug 23 19:12:52 +0000 2018
# Tweet collected at Thu Aug 23 19:12:52 +0000 2018
# Tweet collected at Thu Aug 23 19:12:55 +0000 2018
# Tweet collected at Thu Aug 23 19:13:00 +0000 2018
# Tweet collected at Thu Aug 23 19:13:01 +0000 2018
# Tweet collected at Thu Aug 23 19:13:01 +0000 2018
# Tweet collected at Thu Aug 23 19:13:02 +0000 2018
# Tweet collected at Thu Aug 23 19:13:02 +0000 2018
# Tweet collected at Thu Aug 23 19:13:03 +0000 2018
# Tweet collected at Thu Aug 23 19:13:03 +0000 2018
# Tweet collected at Thu Aug 23 19:13:04 +0000 2018
# Tweet collected at Thu Aug 23 19:13:04 +0000 2018
# Tweet collected at Thu Aug 23 19:13:04 +0000 2018
# Tweet collected at Thu Aug 23 19:13:05 +0000 2018
# Tweet collected at Thu Aug 23 19:13:06 +0000 2018
# Tweet collected at Thu Aug 23 19:13:07 +0000 2018
# Tweet collected at Thu Aug 23 19:13:08 +0000 2018
# Tweet collected at Thu Aug 23 19:13:09 +0000 2018
# Tweet collected at Thu Aug 23 19:13:09 +0000 2018
# Tweet collected at Thu Aug 23 19:13:09 +0000 2018
# Tweet collected at Thu Aug 23 19:13:10 +0000 2018
# Tweet collected at Thu Aug 23 19:13:11 +0000 2018
# Tweet collected at Thu Aug 23 19:13:13 +0000 2018
# Tweet collected at Thu Aug 23 19:13:19 +0000 2018
# Tweet collected at Thu Aug 23 19:13:24 +0000 2018
# Tweet collected at Thu Aug 23 19:13:24 +0000 2018
# Tweet collected at Thu Aug 23 19:13:26 +0000 2018
# Tweet collected at Thu Aug 23 19:13:26 +0000 2018
# Tweet collected at Thu Aug 23 19:13:26 +0000 2018
# Tweet collected at Thu Aug 23 19:13:28 +0000 2018
# Tweet collected at Thu Aug 23 19:13:29 +0000 2018
# Tweet collected at Thu Aug 23 19:13:29 +0000 2018
# Tweet collected at Thu Aug 23 19:13:30 +0000 2018
# Tweet collected at Thu Aug 23 19:13:32 +0000 2018
# ...
# Tweet collected at Thu Aug 23 19:24:07 +0000 2018
# Tweet collected at Thu Aug 23 19:24:09 +0000 2018
# Tweet collected at Thu Aug 23 19:24:09 +0000 2018
# Tweet collected at Thu Aug 23 19:24:15 +0000 2018
# Tweet collected at Thu Aug 23 19:24:18 +0000 2018
# Tweet collected at Thu Aug 23 19:24:19 +0000 2018
# Tweet collected at Thu Aug 23 19:24:19 +0000 2018
# Tweet collected at Thu Aug 23 19:24:19 +0000 2018
# Tweet collected at Thu Aug 23 19:24:19 +0000 2018
# Tweet collected at Thu Aug 23 19:24:22 +0000 2018
# Tweet collected at Thu Aug 23 19:24:24 +0000 2018
# Tweet collected at Thu Aug 23 19:24:26 +0000 2018
# Tweet collected at Thu Aug 23 19:24:26 +0000 2018
# Tweet collected at Thu Aug 23 19:24:28 +0000 2018
# Tweet collected at Thu Aug 23 19:24:29 +0000 2018
# Tweet collected at Thu Aug 23 19:24:30 +0000 2018
# Tweet collected at Thu Aug 23 19:24:30 +0000 2018
# Tweet collected at Thu Aug 23 19:24:31 +0000 2018
# Tweet collected at Thu Aug 23 19:24:33 +0000 2018
# Tweet collected at Thu Aug 23 19:24:35 +0000 2018
# Tweet collected at Thu Aug 23 19:24:36 +0000 2018
# Tweet collected at Thu Aug 23 19:24:39 +0000 2018
# Tweet collected at Thu Aug 23 19:24:40 +0000 2018
# Tweet collected at Thu Aug 23 19:24:39 +0000 2018
# Tweet collected at Thu Aug 23 19:24:41 +0000 2018
# Tweet collected at Thu Aug 23 19:24:42 +0000 2018
# Tweet collected at Thu Aug 23 19:24:45 +0000 2018
# Tweet collected at Thu Aug 23 19:24:46 +0000 2018
# Tweet collected at Thu Aug 23 19:24:49 +0000 2018
# Tweet collected at Thu Aug 23 19:24:50 +0000 2018
# Tweet collected at Thu Aug 23 19:24:53 +0000 2018
# Tweet collected at Thu Aug 23 19:24:54 +0000 2018
# Tweet collected at Thu Aug 23 19:24:55 +0000 2018
# Tweet collected at Thu Aug 23 19:24:57 +0000 2018
# Tweet collected at Thu Aug 23 19:25:00 +0000 2018
# Tweet collected at Thu Aug 23 19:25:00 +0000 2018
# Tweet collected at Thu Aug 23 19:25:01 +0000 2018
# Tweet collected at Thu Aug 23 19:25:02 +0000 2018
# Tweet collected at Thu Aug 23 19:25:02 +0000 2018
# Tweet collected at Thu Aug 23 19:25:02 +0000 2018
# Tweet collected at Thu Aug 23 19:25:03 +0000 2018
# Tweet collected at Thu Aug 23 19:25:03 +0000 2018
# Tweet collected at Thu Aug 23 19:25:04 +0000 2018
# Tweet collected at Thu Aug 23 19:25:08 +0000 2018
# Tweet collected at Thu Aug 23 19:25:08 +0000 2018
# Tweet collected at Thu Aug 23 19:25:11 +0000 2018
# Tweet collected at Thu Aug 23 19:25:11 +0000 2018
# Tweet collected at Thu Aug 23 19:25:10 +0000 2018
# Tweet collected at Thu Aug 23 19:25:11 +0000 2018
# Tweet collected at Thu Aug 23 19:25:13 +0000 2018
# Tweet collected at Thu Aug 23 19:25:14 +0000 2018
# Tweet collected at Thu Aug 23 19:25:17 +0000 2018
# Tweet collected at Thu Aug 23 19:25:18 +0000 2018
# Tweet collected at Thu Aug 23 19:25:19 +0000 2018
# Tweet collected at Thu Aug 23 19:25:22 +0000 2018
# Tweet collected at Thu Aug 23 19:25:29 +0000 2018
# Tweet collected at Thu Aug 23 19:25:32 +0000 2018
# Tweet collected at Thu Aug 23 19:25:33 +0000 2018
# Tweet collected at Thu Aug 23 19:25:35 +0000 2018
# Tweet collected at Thu Aug 23 19:25:36 +0000 2018
# Tweet collected at Thu Aug 23 19:25:36 +0000 2018
# Tweet collected at Thu Aug 23 19:25:39 +0000 2018
# Tweet collected at Thu Aug 23 19:25:40 +0000 2018
# Tweet collected at Thu Aug 23 19:25:44 +0000 2018
# Tweet collected at Thu Aug 23 19:25:44 +0000 2018
# Tweet collected at Thu Aug 23 19:25:46 +0000 2018
# Tweet collected at Thu Aug 23 19:25:46 +0000 2018
# Tweet collected at Thu Aug 23 19:25:46 +0000 2018
# Tweet collected at Thu Aug 23 19:25:46 +0000 2018
# Tweet collected at Thu Aug 23 19:25:52 +0000 2018
# Tweet collected at Thu Aug 23 19:25:53 +0000 2018
# Tweet collected at Thu Aug 23 19:25:55 +0000 2018
# Tweet collected at Thu Aug 23 19:25:57 +0000 2018
# Tweet collected at Thu Aug 23 19:25:57 +0000 2018
# Tweet collected at Thu Aug 23 19:25:59 +0000 2018
# Tweet collected at Thu Aug 23 19:25:59 +0000 2018
# Tweet collected at Thu Aug 23 19:26:00 +0000 2018
# Tweet collected at Thu Aug 23 19:26:00 +0000 2018
# Tweet collected at Thu Aug 23 19:26:02 +0000 2018
# Tweet collected at Thu Aug 23 19:26:04 +0000 2018
# Tweet collected at Thu Aug 23 19:26:04 +0000 2018
# Tweet collected at Thu Aug 23 19:26:04 +0000 2018
# Tweet collected at Thu Aug 23 19:26:05 +0000 2018
# Tweet collected at Thu Aug 23 19:26:05 +0000 2018
# Tweet collected at Thu Aug 23 19:26:11 +0000 2018
# Tweet collected at Thu Aug 23 19:26:11 +0000 2018
# Tweet collected at Thu Aug 23 19:26:11 +0000 2018
# Tweet collected at Thu Aug 23 19:26:12 +0000 2018
# Tweet collected at Thu Aug 23 19:26:15 +0000 2018
# Tweet collected at Thu Aug 23 19:26:16 +0000 2018
# Tweet collected at Thu Aug 23 19:26:18 +0000 2018
# Tweet collected at Thu Aug 23 19:26:18 +0000 2018
# Tweet collected at Thu Aug 23 19:26:19 +0000 2018
# Tweet collected at Thu Aug 23 19:26:19 +0000 2018
# Tweet collected at Thu Aug 23 19:26:19 +0000 2018
# Tweet collected at Thu Aug 23 19:26:23 +0000 2018
# Tweet collected at Thu Aug 23 19:26:28 +0000 2018
# Tweet collected at Thu Aug 23 19:26:29 +0000 2018
# Tweet collected at Thu Aug 23 19:26:29 +0000 2018
# Tweet collected at Thu Aug 23 19:26:31 +0000 2018
# Tweet collected at Thu Aug 23 19:26:33 +0000 2018
# Tweet collected at Thu Aug 23 19:26:38 +0000 2018
# Tweet collected at Thu Aug 23 19:26:39 +0000 2018
# Tweet collected at Thu Aug 23 19:26:45 +0000 2018
# Tweet collected at Thu Aug 23 19:26:46 +0000 2018
# Tweet collected at Thu Aug 23 19:26:46 +0000 2018
# Tweet collected at Thu Aug 23 19:26:47 +0000 2018
# Tweet collected at Thu Aug 23 19:26:48 +0000 2018
# Tweet collected at Thu Aug 23 19:26:48 +0000 2018
# Tweet collected at Thu Aug 23 19:26:49 +0000 2018
# Tweet collected at Thu Aug 23 19:26:50 +0000 2018
# Tweet collected at Thu Aug 23 19:26:56 +0000 2018
# Tweet collected at Thu Aug 23 19:26:56 +0000 2018
# Tweet collected at Thu Aug 23 19:26:58 +0000 2018
# Tweet collected at Thu Aug 23 19:27:00 +0000 2018
# Tweet collected at Thu Aug 23 19:27:00 +0000 2018
# Tweet collected at Thu Aug 23 19:27:03 +0000 2018
# Tweet collected at Thu Aug 23 19:27:06 +0000 2018
# Tweet collected at Thu Aug 23 19:27:10 +0000 2018
# Tweet collected at Thu Aug 23 19:27:10 +0000 2018
# Tweet collected at Thu Aug 23 19:27:13 +0000 2018
# Tweet collected at Thu Aug 23 19:27:16 +0000 2018
# Tweet collected at Thu Aug 23 19:27:17 +0000 2018
# Tweet collected at Thu Aug 23 19:27:17 +0000 2018
# Tweet collected at Thu Aug 23 19:27:17 +0000 2018
# Tweet collected at Thu Aug 23 19:27:19 +0000 2018
# Tweet collected at Thu Aug 23 19:27:20 +0000 2018
# Tweet collected at Thu Aug 23 19:27:24 +0000 2018
# Tweet collected at Thu Aug 23 19:27:26 +0000 2018
# Tweet collected at Thu Aug 23 19:27:34 +0000 2018
# Tweet collected at Thu Aug 23 19:27:34 +0000 2018
# Tweet collected at Thu Aug 23 19:27:36 +0000 2018
# Tweet collected at Thu Aug 23 19:27:38 +0000 2018
# Tweet collected at Thu Aug 23 19:27:38 +0000 2018
# Tweet collected at Thu Aug 23 19:27:38 +0000 2018
# Tweet collected at Thu Aug 23 19:27:40 +0000 2018
# Tweet collected at Thu Aug 23 19:27:41 +0000 2018
# Tweet collected at Thu Aug 23 19:27:43 +0000 2018
# Tweet collected at Thu Aug 23 19:27:48 +0000 2018
# Tweet collected at Thu Aug 23 19:27:50 +0000 2018
# Tweet collected at Thu Aug 23 19:28:00 +0000 2018
# Tweet collected at Thu Aug 23 19:28:01 +0000 2018
# Tweet collected at Thu Aug 23 19:28:05 +0000 2018
# Tweet collected at Thu Aug 23 19:28:06 +0000 2018
# Tweet collected at Thu Aug 23 19:28:06 +0000 2018
# Tweet collected at Thu Aug 23 19:28:07 +0000 2018
# Tweet collected at Thu Aug 23 19:28:08 +0000 2018
# Tweet collected at Thu Aug 23 19:28:09 +0000 2018
# Tweet collected at Thu Aug 23 19:28:10 +0000 2018
# Tweet collected at Thu Aug 23 19:28:10 +0000 2018
# Tweet collected at Thu Aug 23 19:28:12 +0000 2018
# Tweet collected at Thu Aug 23 19:28:13 +0000 2018
# Tweet collected at Thu Aug 23 19:28:13 +0000 2018
# Tweet collected at Thu Aug 23 19:28:15 +0000 2018
# Tweet collected at Thu Aug 23 19:28:18 +0000 2018
# Tweet collected at Thu Aug 23 19:28:20 +0000 2018
# Tweet collected at Thu Aug 23 19:28:26 +0000 2018
# Tweet collected at Thu Aug 23 19:28:26 +0000 2018
# Tweet collected at Thu Aug 23 19:28:26 +0000 2018
# Tweet collected at Thu Aug 23 19:28:28 +0000 2018
# Tweet collected at Thu Aug 23 19:28:29 +0000 2018
# Tweet collected at Thu Aug 23 19:28:30 +0000 2018
# Tweet collected at Thu Aug 23 19:28:33 +0000 2018
# Tweet collected at Thu Aug 23 19:28:36 +0000 2018
# Tweet collected at Thu Aug 23 19:28:36 +0000 2018
# Tweet collected at Thu Aug 23 19:28:37 +0000 2018
# Tweet collected at Thu Aug 23 19:28:39 +0000 2018
# Tweet collected at Thu Aug 23 19:28:39 +0000 2018
# Tweet collected at Thu Aug 23 19:28:41 +0000 2018
# Tweet collected at Thu Aug 23 19:28:43 +0000 2018
# Tweet collected at Thu Aug 23 19:28:45 +0000 2018
# Tweet collected at Thu Aug 23 19:28:50 +0000 2018
# Tweet collected at Thu Aug 23 19:28:52 +0000 2018
# Tweet collected at Thu Aug 23 19:28:53 +0000 2018
# Tweet collected at Thu Aug 23 19:28:55 +0000 2018
# Tweet collected at Thu Aug 23 19:28:55 +0000 2018
# Tweet collected at Thu Aug 23 19:28:55 +0000 2018
# Tweet collected at Thu Aug 23 19:28:58 +0000 2018
# Tweet collected at Thu Aug 23 19:28:59 +0000 2018
# Tweet collected at Thu Aug 23 19:29:02 +0000 2018
# Tweet collected at Thu Aug 23 19:29:03 +0000 2018
# Tweet collected at Thu Aug 23 19:29:06 +0000 2018
# Tweet collected at Thu Aug 23 19:29:07 +0000 2018
# Tweet collected at Thu Aug 23 19:29:07 +0000 2018
# Tweet collected at Thu Aug 23 19:29:08 +0000 2018
# Tweet collected at Thu Aug 23 19:29:11 +0000 2018
# Tweet collected at Thu Aug 23 19:29:11 +0000 2018
# Tweet collected at Thu Aug 23 19:29:11 +0000 2018
# Tweet collected at Thu Aug 23 19:29:12 +0000 2018
# Tweet collected at Thu Aug 23 19:29:13 +0000 2018
# Tweet collected at Thu Aug 23 19:29:15 +0000 2018
# Tweet collected at Thu Aug 23 19:29:20 +0000 2018
# Tweet collected at Thu Aug 23 19:29:21 +0000 2018
# Tweet collected at Thu Aug 23 19:29:24 +0000 2018
# Tweet collected at Thu Aug 23 19:29:28 +0000 2018
# Tweet collected at Thu Aug 23 19:29:28 +0000 2018
# Tweet collected at Thu Aug 23 19:29:29 +0000 2018
# Tweet collected at Thu Aug 23 19:29:30 +0000 2018
# Tweet collected at Thu Aug 23 19:29:32 +0000 2018
# Tweet collected at Thu Aug 23 19:29:33 +0000 2018
# Tweet collected at Thu Aug 23 19:29:35 +0000 2018
# Tweet collected at Thu Aug 23 19:29:35 +0000 2018
# Tweet collected at Thu Aug 23 19:29:37 +0000 2018
# Tweet collected at Thu Aug 23 19:29:39 +0000 2018
# Tweet collected at Thu Aug 23 19:29:40 +0000 2018
# Tweet collected at Thu Aug 23 19:29:41 +0000 2018
# Tweet collected at Thu Aug 23 19:29:41 +0000 2018
# Tweet collected at Thu Aug 23 19:29:42 +0000 2018
# Tweet collected at Thu Aug 23 19:29:42 +0000 2018
# Tweet collected at Thu Aug 23 19:29:42 +0000 2018
# Tweet collected at Thu Aug 23 19:29:44 +0000 2018
# Tweet collected at Thu Aug 23 19:29:45 +0000 2018
# Tweet collected at Thu Aug 23 19:29:46 +0000 2018
# Tweet collected at Thu Aug 23 19:29:46 +0000 2018
# Tweet collected at Thu Aug 23 19:29:48 +0000 2018
# Tweet collected at Thu Aug 23 19:29:49 +0000 2018
# Tweet collected at Thu Aug 23 19:29:49 +0000 2018
# Tweet collected at Thu Aug 23 19:29:54 +0000 2018
# Tweet collected at Thu Aug 23 19:29:55 +0000 2018
# Tweet collected at Thu Aug 23 19:29:56 +0000 2018
# Tweet collected at Thu Aug 23 19:29:58 +0000 2018
# Tweet collected at Thu Aug 23 19:29:59 +0000 2018
# Tweet collected at Thu Aug 23 19:30:00 +0000 2018
# Tweet collected at Thu Aug 23 19:30:00 +0000 2018
# Tweet collected at Thu Aug 23 19:30:00 +0000 2018
# Tweet collected at Thu Aug 23 19:30:00 +0000 2018
# Tweet collected at Thu Aug 23 19:30:01 +0000 2018
# Tweet collected at Thu Aug 23 19:30:02 +0000 2018
# Tweet collected at Thu Aug 23 19:30:02 +0000 2018
# Tweet collected at Thu Aug 23 19:30:04 +0000 2018
# Tweet collected at Thu Aug 23 19:30:04 +0000 2018
# Tweet collected at Thu Aug 23 19:30:05 +0000 2018
# Tweet collected at Thu Aug 23 19:30:05 +0000 2018
# Tweet collected at Thu Aug 23 19:30:05 +0000 2018
# Tweet collected at Thu Aug 23 19:30:06 +0000 2018
# Tweet collected at Thu Aug 23 19:30:07 +0000 2018
# Tweet collected at Thu Aug 23 19:30:08 +0000 2018
# Tweet collected at Thu Aug 23 19:30:09 +0000 2018
# Tweet collected at Thu Aug 23 19:30:09 +0000 2018
# Tweet collected at Thu Aug 23 19:30:09 +0000 2018
# Tweet collected at Thu Aug 23 19:30:10 +0000 2018
# Tweet collected at Thu Aug 23 19:30:11 +0000 2018
# Tweet collected at Thu Aug 23 19:30:11 +0000 2018
# Tweet collected at Thu Aug 23 19:30:11 +0000 2018
# Tweet collected at Thu Aug 23 19:30:12 +0000 2018
# Tweet collected at Thu Aug 23 19:30:12 +0000 2018
# Tweet collected at Thu Aug 23 19:30:13 +0000 2018
# Tweet collected at Thu Aug 23 19:30:13 +0000 2018
# Tweet collected at Thu Aug 23 19:30:13 +0000 2018
# Tweet collected at Thu Aug 23 19:30:14 +0000 2018
# Tweet collected at Thu Aug 23 19:30:14 +0000 2018
# Tweet collected at Thu Aug 23 19:30:14 +0000 2018
# Tweet collected at Thu Aug 23 19:30:15 +0000 2018
# Tweet collected at Thu Aug 23 19:30:15 +0000 2018
# Tweet collected at Thu Aug 23 19:30:15 +0000 2018
# Tweet collected at Thu Aug 23 19:30:16 +0000 2018
# Tweet collected at Thu Aug 23 19:30:17 +0000 2018
# Tweet collected at Thu Aug 23 19:30:18 +0000 2018
# Tweet collected at Thu Aug 23 19:30:18 +0000 2018
# Tweet collected at Thu Aug 23 19:30:18 +0000 2018
# Tweet collected at Thu Aug 23 19:30:19 +0000 2018
# Tweet collected at Thu Aug 23 19:30:19 +0000 2018
# Tweet collected at Thu Aug 23 19:30:19 +0000 2018
# Tweet collected at Thu Aug 23 19:30:20 +0000 2018
# Tweet collected at Thu Aug 23 19:30:20 +0000 2018
# Tweet collected at Thu Aug 23 19:30:20 +0000 2018
# Tweet collected at Thu Aug 23 19:30:21 +0000 2018
# Tweet collected at Thu Aug 23 19:30:21 +0000 2018
# Tweet collected at Thu Aug 23 19:30:21 +0000 2018
# Tweet collected at Thu Aug 23 19:30:21 +0000 2018
# Tweet collected at Thu Aug 23 19:30:22 +0000 2018
# Tweet collected at Thu Aug 23 19:30:22 +0000 2018
# Tweet collected at Thu Aug 23 19:30:22 +0000 2018
# Tweet collected at Thu Aug 23 19:30:22 +0000 2018
# Tweet collected at Thu Aug 23 19:30:23 +0000 2018
# Tweet collected at Thu Aug 23 19:30:24 +0000 2018
# Tweet collected at Thu Aug 23 19:30:25 +0000 2018
# Tweet collected at Thu Aug 23 19:30:25 +0000 2018
# Tweet collected at Thu Aug 23 19:30:26 +0000 2018
# Tweet collected at Thu Aug 23 19:30:28 +0000 2018
# Tweet collected at Thu Aug 23 19:30:28 +0000 2018
# Tweet collected at Thu Aug 23 19:30:29 +0000 2018
# Tweet collected at Thu Aug 23 19:30:29 +0000 2018
# Tweet collected at Thu Aug 23 19:30:30 +0000 2018
# Tweet collected at Thu Aug 23 19:30:30 +0000 2018
# Tweet collected at Thu Aug 23 19:30:30 +0000 2018
# Tweet collected at Thu Aug 23 19:30:32 +0000 2018
# Tweet collected at Thu Aug 23 19:30:32 +0000 2018
# Tweet collected at Thu Aug 23 19:30:33 +0000 2018
# Tweet collected at Thu Aug 23 19:30:33 +0000 2018
# Tweet collected at Thu Aug 23 19:30:34 +0000 2018
# Tweet collected at Thu Aug 23 19:30:35 +0000 2018
# Tweet collected at Thu Aug 23 19:30:36 +0000 2018
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-ea2eb9c1c4ae> in <module>()
#      56 streamer = tweepy.Stream(auth=auth, listener=listener)
#      57 print("Tracking: " + str(WORDS))
# ---> 58 streamer.filter(track=WORDS)
#      59
#      60
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding)
#     426         self.session.params = {'delimited': 'length'}
#     427         self.host = 'stream.twitter.com'
# --> 428         self._start(async)
#     429
#     430     def sitestream(self, follow, stall_warnings=False,
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     344             self._thread.start()
#     345         else:
# --> 346             self._run()
#     347
#     348     def on_closed(self, resp):
#
# C:\apps\python36\python-3.6.3.amd64\lib\site-packages\tweepy\streaming.py in _run(self)
#     284             # call a handler first so that the exception can be logged.
#     285             self.listener.on_exception(exception)
# --> 286             raise
#     287
#     288     def _data(self, data):
#
# RuntimeError: No active exception to reraise
